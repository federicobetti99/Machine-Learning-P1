# %%
# Useful starting lines
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import math
import random
# %load_ext autoreload
# %autoreload 2

# %%
# Our libraries
from proj1_helpers import *
from proj1_input_man import *
from proj1_linear_model import *
from proj1_ridge_regress import *
from proj1_logistic import *

# %% [markdown]
# ## Load the training data into feature matrix, class labels, and event ids:

# %%
DATA_TRAIN_PATH = '../data/train.csv' # train data path here 
y, tX, ids = load_csv_data(DATA_TRAIN_PATH)

# %%
print(tX.shape)
# Out:
# (250000, 30)

# %% [markdown]
# ### Exploratory data analysis

# %%
one_indeces = np.where(y==1)[0]
minus_one_indeces = np.where(y==-1)[0]

# %%
fig, ax = plt.subplots(6,5,figsize= (12,10), sharey = False, sharex = False)
plt.style.use('seaborn-deep')
for i in range(tX.shape[1]):
    sbplt = ax[i%6, math.floor(i/6)]
    sbplt.hist([tX[minus_one_indeces,i], tX[one_indeces,i]],bins = 20, label = ['-1', '1'])
    sbplt.legend(loc='upper right', prop={'size': 6})
    sbplt.set_title('column: {}'.format(i))
    
fig.tight_layout()

# %% [markdown]
# ### Changing the labels to {0,1}

# %%
# change the array from -1 1 to 0 1
# label simplification
# y == 0 non detected Boson, y == 1 detected Boson
y_ = np.array([0 if l == -1 else 1 for l in y])

# %% [markdown]
# # All of the following parts are the same for the test set, should be functions
#
# # less code = better code (in this case)

# %% [markdown]
# ### Dividing the features by the number of jets

# %%
tX_0, tX_1, tX_2, tX_3 = alternative_split_to_Jet_Num(tX)

# %% [markdown]
# ### Dividing also the output by the type of particle

# %%
y_0, y_1, y_2, y_3 = alternative_split_labels_to_Jet_Num(y_, tX)

# %% [markdown]
# ### Adding a column of zeros and ones to detect whether the mass has been measured or not

# %%
# take the indices where the mass is not calculated, add the column which has 0 in those indices
# and 1 everywhere else for all matrices 0,1,2_3
tX_0 = find_mass(tX_0)
tX_1 = find_mass(tX_1)
# tX_2_3 = find_mass(tX_2_3)
tX_2 = find_mass(tX_2)
tX_3 = find_mass(tX_3)

# %% [markdown]
# ### Throwing away the outliers from the training data

# %%
tX_0, col_to_delete_0 = fix_array(tX_0, 0)
tX_1, col_to_delete_1 = fix_array(tX_1, 1)
tX_2, _ = fix_array(tX_2, 2)
tX_3, _ = fix_array(tX_3, 3)
# Out:
# [5, 6, 7, 13, 23, 24, 25, 26, 27, 28, 29]
# [5, 6, 7, 13, 26, 27, 28]
# []
# []

# %% [markdown]
# ### Now we substitute the -999 values with the median

# %%
tX_0, column_median_0 = fix_median(tX_0)
tX_1, column_median_1 = fix_median(tX_1)
tX_2, column_median_2 = fix_median(tX_2)
tX_3, column_median_3 = fix_median(tX_3)

# %% [markdown]
# ### Now we standardize the data

# %%
tX_3[:,1:], mean_3, std_3 = standardize(tX_3[:,1:])
tX_2[:,1:], mean_2, std_2 = standardize(tX_2[:,1:]) #we standardize everything a part from the column added manually
tX_0[:,1:], mean_0, std_0 = standardize(tX_0[:,1:])
tX_1[:,1:], mean_1, std_1 = standardize(tX_1[:,1:])

# %% [markdown]
# ### We insert the column for the bias term

# %%
tX_tilda_0 = np.insert(tX_0, 0, np.ones(tX_0.shape[0]), axis=1)
tX_tilda_1 = np.insert(tX_1, 0, np.ones(tX_1.shape[0]), axis=1)
tX_tilda_2 = np.insert(tX_2, 0, np.ones(tX_2.shape[0]), axis=1)
tX_tilda_3 = np.insert(tX_3, 0, np.ones(tX_3.shape[0]), axis=1)

# %% [markdown]
# ## Do your thing crazy machine learning thing here :) ...

# %% [markdown]
# ## The following cells of code aim at finetuning the hyperparameters of the code

# %% [markdown]
# ### Calculate the optimal degree for gradient descent

# %%
degree_opt_0_GD = finetune_GD(tX_tilda_0, y_0)
degree_opt_1_GD = finetune_GD(tX_tilda_1, y_1)
degree_opt_2_GD = finetune_GD(tX_tilda_2, y_2)
degree_opt_3_GD = finetune_GD(tX_tilda_3, y_3)
#degree_opt_2_3_GD = finetune_GD(tX_tilda_2_3, y_2_3)
# Out:
# /home/john/Documents/MachineLearning/Machine-Learning-P1/project1/scripts/proj1_linear_model.py:19: RuntimeWarning: invalid value encountered in matmul
#   gradient = -(1/N) * (tx.T) @ (e) # calculate the gradient
# /home/john/Documents/MachineLearning/Machine-Learning-P1/project1/scripts/proj1_linear_model.py:38: RuntimeWarning: invalid value encountered in subtract
#   w = w - gamma * gradient # conduct a step of gradient descent
# /home/john/Documents/MachineLearning/Machine-Learning-P1/project1/scripts/proj1_linear_model.py:11: RuntimeWarning: overflow encountered in matmul
#   e = y - tx @ w # e = error vector (truth - prediction)
# /home/john/Documents/MachineLearning/Machine-Learning-P1/project1/scripts/proj1_linear_model.py:18: RuntimeWarning: overflow encountered in matmul
#   e = y - tx @ w # e = error vector (truth - prediction)
# [0.8183001  0.82694771 0.25513452 0.25513452]
# [2]
# [0.73121067 0.77632054 0.7937687  0.35734551]
# [3]
# ...

# %%
# This cell takes a long time to execute, the hyperparameters found are:
# degree =2 for tX_tilda_0 with an accuracy of 0.82694771 on the validation set
# degree =3 for tX_tilda_1 with an accuracy of 0.7937687 on the validation set
# degree =3 for tX_tilda_2_3 with an accuracy of 0.81856907 on the validation set

# %%
w_GD_0 = optimal_weights_GD(tX_tilda_0,y_0,degree_opt_0_GD)
w_GD_1 = optimal_weights_GD(tX_tilda_1,y_1,degree_opt_1_GD)
w_GD_2 = optimal_weights_GD(tX_tilda_2,y_2,degree_opt_2_GD)
w_GD_3 = optimal_weights_GD(tX_tilda_3,y_3,degree_opt_3_GD)
#w_GD_2_3 = optimal_weights_GD(tX_tilda_2_3,y_2_3,degree_opt_2_3_GD,lambda_opt_2_3_GD)

# %% [markdown]
# ### Calculate the optimal degree for stochastic gradient descent for feature augmentation

# %%
degree_opt_0_SGD = finetune_SGD(tX_tilda_0, y_0)
degree_opt_1_SGD = finetune_SGD(tX_tilda_1, y_1)
degree_opt_2_SGD = finetune_SGD(tX_tilda_2, y_2)
degree_opt_3_SGD = finetune_SGD(tX_tilda_3, y_3)
# Out:
# [0.8037473  0.66650653 0.50210185 0.45086676]
# [1]
# [0.70247859 0.66977458 0.52160064 0.5434592 ]
# [1]
# [0.75458552 0.75206448 0.48229316 0.45845244]
# [1]
# [0.73420863 0.69269987 0.542366   0.4653041 ]
# [1]

# %%
w_SGD_0 = optimal_weights_SGD(tX_tilda_0,y_0,degree_opt_0_SGD)
w_SGD_1 = optimal_weights_SGD(tX_tilda_1,y_1,degree_opt_1_SGD)
w_SGD_2 = optimal_weights_SGD(tX_tilda_2,y_2,degree_opt_2_SGD)
w_SGD_3 = optimal_weights_SGD(tX_tilda_3,y_3,degree_opt_3_SGD)

# %% [markdown]
# ### Calculate the wieghts for the least squares method

# %%
w_LS_0 = least_squares(y_0,tX_0)
w_LS_1 = least_squares(y_1,tX_1)
w_LS_2 = least_squares(y_2,tX_2)
w_LS_3 = least_squares(y_3,tX_3)

# %% [markdown]
# ### Calculate the optimal lambda for ridge regression and the optimal degree for feature augmentation

# %%
lambda_opt_0_ridge, degree_opt_0_ridge = finetune_ridge(tX_tilda_0, y_0, degrees=np.array([2]), lambdas = random_interval(10e-7,10e-5,10), crossing=True)
lambda_opt_1_ridge, degree_opt_1_ridge = finetune_ridge(tX_tilda_1, y_1, degrees= np.array([2]), lambdas = random_interval(10e-7,10e-5,10), crossing=True)
lambda_opt_2_ridge, degree_opt_2_ridge = finetune_ridge(tX_tilda_2, y_2, degrees=np.array([2]), lambdas = random_interval(10e-7,10e-5,10), crossing=True)
lambda_opt_3_ridge, degree_opt_3_ridge = finetune_ridge(tX_tilda_3, y_3, degrees=np.array([2]), lambdas = random_interval(10e-7,10e-5,10), crossing=True)
# Out:
# (array([0, 1, 8], dtype=int64), array([0, 0, 0], dtype=int64))
# [[0.83603243]
#  [0.83603243]
#  [0.83601241]
#  [0.83599239]
#  [0.8360024 ]
#  [0.8360024 ]
#  [0.8360024 ]
#  [0.83602242]
#  [0.83597238]
#  [0.83591232]
#  [0.83564208]
#  [0.83462116]
#  [0.83302973]
#  [0.83047743]]
# [1.e-05] [2]
# (array([6]), array([0]))
# [[0.7996389 ]
#  [0.79966469]
#  [0.7996389 ]
#  [0.7996389 ]
#  [0.799626  ]
#  [0.79956152]
#  [0.79958731]
#  [0.79979365]
#  [0.79992262]
#  [0.79912303]
#  [0.79567965]
#  [0.78839309]]
# [0.00464159] [2]
# (array([6]), array([0]))
# [[0.83533499]
#  [0.83537469]
#  [0.83533499]
#  [0.83539454]
#  [0.83539454]
#  [0.83535484]
#  [0.83539454]
#  [0.83535484]
#  [0.83537469]
#  [0.83537469]]
# [7.24495921e-05 7.36095644e-05] [2 2]
# (array([2, 5, 6, 7], dtype=int64), array([0, 0, 0, 0], dtype=int64))
# [[0.82436823]
#  [0.82436823]
#  [0.82441336]
#  [0.8243231 ]
#  [0.8243231 ]
#  [0.82441336]
#  [0.82441336]
#  [0.82441336]
#  [0.82436823]
# ...

# %%
# to check
print(lambda_opt_0_ridge, degree_opt_0_ridge)
print(lambda_opt_1_ridge, degree_opt_1_ridge)
print(lambda_opt_2_ridge, degree_opt_2_ridge)
print(lambda_opt_3_ridge, degree_opt_3_ridge)
# Out:
# 1e-05 2
# 0.004641588833612777 2
# 0.004641588833612777 2
# 1e-05 2

# %%
#Summarizing the best parameters found are
# lambda = 0.00316228 and degree=6 for tX_tilda_0 with a validation accuracy of 0.83847463
# [0.00558459] [6] gives accuracy = 0.83814433 for tX_tilda_0
# lambda = 0.00316228 and degree= 6 for tX_tilda_1 with a validation accuracy of 0.80354656
# lambda = 0.0047263 and degree = 6 for tX_tilda_3 gives 0.83759025 approximately
# lambda = 0.00546996 and degree = 5 for tX_tilda_2 gives 0.82747395
# lambda=1e-5 and degree=6 for tX_tilda_2_3 with a validation accuracy of 0.83021781

# %% [markdown]
# ### Get the optimal weights with the calculated hyper parameters

# %%
w_ridge_0_model_1 = optimal_weights_ridge(tX_tilda_0, y_0, degree=2, lambda_=1e-05, crossing =True)
w_ridge_1_model_1 = optimal_weights_ridge(tX_tilda_1, y_1, degree=2, lambda_=0.00464159, crossing=True)
w_ridge_2_model_1 = optimal_weights_ridge(tX_tilda_2, y_2, degree=2, lambda_=0.00464159, crossing =True)
w_ridge_3_model_1 = optimal_weights_ridge(tX_tilda_3, y_3, degree=2, lambda_=2.78255940e-05, crossing=True)

w_ridge_0_model_2 = optimal_weights_ridge(tX_tilda_0, y_0, degree=2, lambda_=5.58459201e-06, crossing =True)
w_ridge_1_model_2 = optimal_weights_ridge(tX_tilda_1, y_1, degree=2, lambda_=3.55553621e-05, crossing=True)
w_ridge_2_model_2 = optimal_weights_ridge(tX_tilda_2, y_2, degree=2, lambda_=7.24495921e-05, crossing =True)
w_ridge_3_model_2 = optimal_weights_ridge(tX_tilda_3, y_3, degree=2, lambda_=3.97155601e-05, crossing=True)

# %% [markdown]
# ### Calculate the optimal lambda for logistic regression and the optimal degree for feature augmentation

# %%
lambda_opt_0_logistic, degree_opt_0_logistic = finetune_logistic(tX_tilda_0, y_0, 1.7783e-04, np.array([2]) , random_interval(3, 10, 6), 4, True)
lambda_opt_1_logistic, degree_opt_1_logistic = finetune_logistic(tX_tilda_1, y_1, 3.16228e-03, np.array([2]), random_interval(3, 10, 6), 4, True)
lambda_opt_2_logistic, degree_opt_2_logistic = finetune_logistic(tX_tilda_2, y_2, 1.7783e-04, np.array([2]), random_interval(3, 10, 6), 4, True)
lambda_opt_3_logistic, degree_opt_3_logistic = finetune_logistic(tX_tilda_3, y_3, 1.7783e-04, np.array([2]), random_interval(3, 10, 6), 4, True)
# Out:
# [7.38712314] [2]
# 0.8258567539434702
# [9.38146586] [2]
# 0.7968637160837718
# [6.44744181] [2]
# 0.8328569159917422
# [5.08512828] [2]
# 0.8324309691391446

# %%
w_logistic_0  = optimal_weights_logistic(tX_tilda_0,y_0,1.7783e-04, degree_opt_0_logistic, lambda_opt_0_logistic, False)
w_logistic_1  = optimal_weights_logistic(tX_tilda_1,y_1,1.7783e-04, degree_opt_1_logistic, lambda_opt_1_logistic, True)
w_logistic_2  = optimal_weights_logistic(tX_tilda_2,y_2,1.7783e-04, degree_opt_2_logistic, lambda_opt_2_logistic, True)
w_logistic_3  = optimal_weights_logistic(tX_tilda_3,y_3,1.7783e-04, degree_opt_3_logistic, lambda_opt_3_logistic, True)

# %%
### Optimal values for logistic regression with feature crossing expansion of order 2 expanding also the bias term and the mass 
### for tX_tilda_0 lambda = 0.03162278 and degree = 2 with accuracy 0.8195411962527024
### for tX_tilda_1 lambda = 2.11944285 and degree = 2 with accuracy 0.7975343031053337
### for tX_tilda_2 lambda = 0.02154435 and degree = 2 with accuracy 0.8323606479275846
### for tX_tilda_3 lambda = 0.46415888 and degree = 2 with accuracy 0.8326565601876917

### Optimal values for logistic regression with feature crossing expansion of order 2 not expanding bias and mass
### for tX_tilda_0 lambda = 3.16227766 and degree = 2 with accuracy 0.824855873163882
### for tX_tilda_1 lambda = 1 and degree = 2 with accuracy 0.797585886722377
### for tX_tilda_2 lambda = 10 and degree = 2 with accuracy 0.830757393997142
### for tX_tilda_3 lambda = 10 and degree = 2 with accuracy 0.831573723154665

### Optimal values for logistic regression with feature crossing expansion of order 2 not expanding only the bias
### for tX_tilda_0 lambda = 0.1 and degree = 2 with accuracy 0.8224937945391945
### for tX_tilda_1 lambda = 1 and degree = 2 with accuracy 0.7975600949138554
### for tX_tilda_2 lambda = 10 and degree = 2 with accuracy 0.8321025885342226
### for tX_tilda_3 lambda = 10 and degree = 2 with accuracy 0.8334686879624617


### Best logistic regression models for each one of the four matrices
### for tX_tilda_0 without crossing feature expansion, normal expansion of degree = 2 and lambda = 1.95096 accuracy = 0.827668
### for tX_tilda_1 with crossing feature expansion expanding the mass, degree = 2 and lambda = 1 accuracy = 0.797585886722377
### for tX_tilda_2 with crossing feature expansion expanding the mass, degree = 2 and lambda = 10 accuracy = 0.832102588
### for tX_tilda_3 with crossing feature expansion expanding the mass, degree = 2 and lambda = 10 accuracy = 0.83346868


### SECOND MODEL FOR LOGISTIC REGRESSION CONSIDERING ONLY CROSSING EXPANSION ALSO OF THE MASS TERM
### for tX_tilda_0 lambda = 7.61288349 and degree = 2 with accuracy 0.8219232924973978
### for tX_tilda_1 lambda = 9.38146586 and degree = 2 with accuracy 0.7968637160837718
### for tX_tilda_2 lambda = 6.44744181 and degree = 2 with accuracy 0.8328569159917422
### for tX_tilda_3 lambda = 5.08512828 and degree = 2 with accuracy 0.8324309691391446 

### THIRD MODEL FOR THE ENSAMBLE
### for tX_tilda_0 lambda = 4.6733269 and degree = 2 with accuracy 0.8243954680118504
### for tX_tilda_1 lambda = 3.76372083 and degree = 2 with accuracy 0.797044258743423
### for tX_tilda_2 lambda = 3.93993349 and degree = 2 with accuracy 0.8328966174368747
### for tX_tilda_3 lambda = 5.12458757 and degree = 2 with accuracy 0.8323407327197258

### best results on the best run on Aicrowd
### lambda = 1 and degree = 2 for tX_tilda_0
### lambda = 1.5 and degree = 3 for tX_tilda_1
### lambda = 0 and degree = 2 for tX_tilda_2_3

# %%
#Summarizing the best parameters found are
# lambda=1.95096 and degree=2 for tX_tilda_0 with a validation accuracy of 0.827668 #lambda =9.64683289, acc=0.82664
# lambda=1.6672 and degree=2 for tX_tilda_1 with a validation accuracy of 0.79229 #lamda = 13.00571 acc = 0.792466 gamma = 0.0004
# lambda=0.6835 and degree=2 for tX_tilda_2_3 with a validation accuracy of 0.8151
# lambda = 10 and degree = 2 for tX_tilda_2 gives an accuracy 0.8153088 
# lambda = 0.001 and degree = 2 for tX_tilda_3 gives an accuracy 0.8231366

# %%
# we will store in a dictionary for each predictor the parameters of the predictor, the first element of the list will be the lambda and the second
# will be the degree.
## NO CROSSING EXPANSION IN MODEL_2 PARAMETERS 0

params_0 = {'model_1':[2, 4.6733269], 'model_2':[2, 1.95], 'model_3': [2, 7.61288349]}
params_1 = {'model_1':[2, 3.76372083], 'model_2':[2, 1.00], 'model_3': [2, 9.38146586]}
params_2 = {'model_1':[2, 3.93993349], 'model_2':[2, 10.0], 'model_3': [2, 6.44744181]}
params_3 = {'model_1':[2, 5.12458757], 'model_2':[2, 10.0], 'model_3': [2, 5.08512828]}

# %% [markdown]
# ### Get the optimal weights with the calculated hyper parameters

# %%
#we now compute the weights for each model and we store in a dictionary
gamma = 0.00017783
#print(params_0['model_1'][0],params_0['model_1'][1])
#w_logistic_0_model_1 = optimal_weights_logistic(tX_tilda_0, y_0, gamma,  params_0['model_1'][0], params_0['model_1'][1], True)
#w_logistic_1_model_1 = optimal_weights_logistic(tX_tilda_1, y_1, gamma,  params_1['model_1'][0], params_1['model_1'][1], True)
#w_logistic_2_model_1 = optimal_weights_logistic(tX_tilda_2, y_2, gamma,  params_2['model_1'][0], params_2['model_1'][1], True)
#w_logistic_3_model_1 = optimal_weights_logistic(tX_tilda_3, y_3,gamma,  params_3['model_1'][0], params_3['model_1'][1], True)

#w_logistic_0_model_2 = optimal_weights_logistic(tX_tilda_0, y_0, gamma, params_0['model_2'][0], params_0['model_2'][1], False)
#w_logistic_1_model_2 = optimal_weights_logistic(tX_tilda_1, y_1, gamma, params_1['model_2'][0], params_1['model_2'][1], True)
#w_logistic_2_model_2 = optimal_weights_logistic(tX_tilda_2, y_2, gamma, params_2['model_2'][0], params_2['model_2'][1], True)
#w_logistic_3_model_2 = optimal_weights_logistic(tX_tilda_3, y_3, gamma, params_3['model_2'][0], params_3['model_2'][1], True)

w_logistic_0_model_3 = optimal_weights_logistic(tX_tilda_0, y_0, gamma, params_0['model_3'][0], params_0['model_3'][1], True)
w_logistic_1_model_3 = optimal_weights_logistic(tX_tilda_1, y_1, gamma, params_1['model_3'][0], params_1['model_3'][1], True)
w_logistic_2_model_3 = optimal_weights_logistic(tX_tilda_2, y_2, gamma, params_2['model_3'][0], params_2['model_3'][1], True)
w_logistic_3_model_3 = optimal_weights_logistic(tX_tilda_3, y_3, gamma, params_3['model_3'][0], params_3['model_3'][1], True)

# %% [markdown]
# ### calculate the optimal lambda for logistic regression with batch

# %%
#lambda_opt_0_logistic_batch,degree_opt_0_logistic_batch = finetune_batch_logistic(tX_tilda_0, y_0, gamma = 1.7783e-04, degrees =np.arange(1, 4) , lambdas=random_interval(0.8, 1.5, 5) )

# %% [markdown]
# # Generate predictions and save ouput in csv format for submission:

# %%
# open the test file
DATA_TEST_PATH = '../data/test.csv' # TODO: download train data and supply path here 
_, tX_test, ids_test = load_csv_data(DATA_TEST_PATH)

# %%
print(tX_test.shape)
# Out:
# (568238, 30)

# %% [markdown]
# We will now format the tX_test as we did for tX_train

# %% [markdown]
# ### we split the test into the three subgroups

# %%
tX_test_0, tX_test_1, tX_test_2, tX_test_3 = alternative_split_to_Jet_Num(tX_test)

# %% [markdown]
# ### Adding a column of zeros and ones to detect whether the mass has been measured or not
# This should be done prior to splitting it is the same procedure and just wastes space

# %%
# take the indices where the mass is not calculated, add the column which has 0 in those indices
# and 1 everywhere else for all matrices 0,1,2_3
tX_test_0 = find_mass(tX_test_0)
tX_test_1 = find_mass(tX_test_1)
tX_test_2 = find_mass(tX_test_2)
tX_test_3 = find_mass(tX_test_3)

# %% [markdown]
# ### We drop the same columns we have dropped for the X training

# %%
# tX_test_0 = fix_array(tX_test_0, 0)
# print(tX_test_0.shape)
# tX_test_1 = fix_array(tX_test_1, 1)
# print(tX_test_1.shape)

# %%
tX_test_0 = np.delete(tX_test_0, col_to_delete_0, axis=1)
tX_test_1 = np.delete(tX_test_1, col_to_delete_1, axis=1)

# %% [markdown]
# ### Now we substitute the -999 values with the median
# This should also be done with a function it is the same thing repeated thrice

# %%
tX_test_0 = fix_median_test(tX_test_0, column_median_0)
tX_test_1 = fix_median_test(tX_test_1, column_median_1)
tX_test_2 = fix_median_test(tX_test_2, column_median_2)
tX_test_3 = fix_median_test(tX_test_3, column_median_3)

# %%
print(tX_test_0.shape)
#print(w_logistic_0.shape)
# Out:
# (227458, 19)

# %% [markdown]
# ### We standardize the test set using the mean and the standard deviation of the training

# %%
print(tX_test_0.shape)
# Out:
# (227458, 19)

# %%
print(tX_0.shape)
# Out:
# (99913, 19)

# %%
# standardize the data in the test set
# should have used the same function both here and on the training part same process this is reduntant
def standardize_test(x, mean, std):
    """Standardize the test set."""
    x = x - mean 
    x = x / std
    return x

# %%
tX_test_0[:,1:] = standardize_test(tX_test_0[:,1:], mean_0, std_0)  #we standardize everything a part from the column added manually
tX_test_1[:,1:] = standardize_test(tX_test_1[:,1:], mean_1, std_1)  #we standardize everything a part from the column added manually
tX_test_2[:,1:] = standardize_test(tX_test_2[:,1:], mean_2, std_2) #we standardize everything a part from the column added manually
tX_test_3[:,1:] = standardize_test(tX_test_3[:,1:], mean_3, std_3)

# %% [markdown]
# ### We insert the column for the bias term

# %%
tX_tilda_test_0 = np.insert(tX_test_0, 0, np.ones(tX_test_0.shape[0]), axis=1) #the first column now is all ones and is used for bias
tX_tilda_test_1 = np.insert(tX_test_1, 0, np.ones(tX_test_1.shape[0]), axis=1) #the first column now is all ones and is used for bias
tX_tilda_test_2 = np.insert(tX_test_2, 0, np.ones(tX_test_2.shape[0]), axis=1) #the first column now is all ones and is used for bias
tX_tilda_test_3 = np.insert(tX_test_3, 0, np.ones(tX_test_3.shape[0]), axis=1)

# %% [markdown]
# ### We make the predictions with GD

# %%
predictions_GD_0 = predict_GD(tX_tilda_test_0,w_GD_0,degree_opt_0_GD)
predictions_GD_1 = predict_GD(tX_tilda_test_1,w_GD_1,degree_opt_1_GD)
predictions_GD_2 = predict_GD(tX_tilda_test_2,w_GD_2,degree_opt_2_GD)
predictions_GD_3 = predict_GD(tX_tilda_test_3,w_GD_3,degree_opt_3_GD)

# %% [markdown]
# ### We make predictions with SGD

# %%
predictions_SGD_0 = predict_SGD(tX_tilda_test_0,w_SGD_0,degree_opt_0_SGD)
predictions_SGD_1 = predict_SGD(tX_tilda_test_1,w_SGD_1,degree_opt_1_SGD)
predictions_SGD_2 = predict_SGD(tX_tilda_test_2,w_SGD_2,degree_opt_2_SGD)
predictions_SGD_3 = predict_SGD(tX_tilda_test_3,w_SGD_3,degree_opt_3_SGD)

# %% [markdown]
# ### We make predictions with Least Squares

# %%
predict_LS_0 = tX_test_0 @ w_LS_0
predict_LS_1 = tX_test_1 @ w_LS_1
predict_LS_2 = tX_test_2 @ w_LS_2
predict_LS_3 = tX_test_3 @ w_LS_3

# %% [markdown]
# ### We make the predictions with ridge regression

# %%
predictions_ridge_0 = predict_ridge(tX_tilda_test_0, w_ridge_0, degree=2, crossing=True)
predictions_ridge_1 = predict_ridge(tX_tilda_test_1, w_ridge_1, degree=2, crossing=True)
predictions_ridge_2 = predict_ridge(tX_tilda_test_2, w_ridge_2, degree=2, crossing=True)
predictions_ridge_3 = predict_ridge(tX_tilda_test_3, w_ridge_3, degree=2, crossing=True)

# %% [markdown]
# ### Predictions with logistic regression

# %%
predictions_logistic_0 = predict_logistic(tX_tilda_test_0, w_logistic_0, degree_opt_0_logistic, False)
predictions_logistic_1 = predict_logistic(tX_tilda_test_1, w_logistic_1, degree_opt_1_logistic, True)
predictions_logistic_2 = predict_logistic(tX_tilda_test_2, w_logistic_2, degree_opt_2_logistic, True)
predictions_logistic_3 = predict_logistic(tX_tilda_test_3, w_logistic_3, degree_opt_3_logistic, True)

# %%
predictions_ridge_0_model_1 = predict_ridge(tX_tilda_test_0, w_ridge_0_model_1, 2, True)
predictions_ridge_1_model_1 = predict_ridge(tX_tilda_test_1, w_ridge_1_model_1, 2, True)
predictions_ridge_2_model_1 = predict_ridge(tX_tilda_test_2, w_ridge_2_model_1, 2, True)
predictions_ridge_3_model_1 = predict_ridge(tX_tilda_test_3, w_ridge_3_model_1, 2, True)

predictions_ridge_0_model_2 = predict_ridge(tX_tilda_test_0, w_ridge_0_model_2, 2, True)
predictions_ridge_1_model_2 = predict_ridge(tX_tilda_test_1, w_ridge_1_model_2, 2, True)
predictions_ridge_2_model_2 = predict_ridge(tX_tilda_test_2, w_ridge_2_model_2, 2, True)
predictions_ridge_3_model_2 = predict_ridge(tX_tilda_test_3, w_ridge_3_model_2, 2, True)

predictions_logistic_0_model_3 = predict_logistic(tX_tilda_test_0, w_logistic_0_model_3, 2, True)
predictions_logistic_1_model_3 = predict_logistic(tX_tilda_test_1, w_logistic_1_model_3, 2, True)
predictions_logistic_2_model_3 = predict_logistic(tX_tilda_test_2, w_logistic_2_model_3, 2, True)
predictions_logistic_3_model_3 = predict_logistic(tX_tilda_test_3, w_logistic_3_model_3, 2, True)

# average_predictions_0 = ensemble_predictions(predictions_ridge_0_model_1, predictions_logistic_0_model_2, predictions_logistic_0_model_3)
# average_predictions_1 = ensemble_predictions(predictions_ridge_1_model_1, predictions_logistic_1_model_2, predictions_logistic_1_model_3)
# average_predictions_2 = ensemble_predictions(predictions_ridge_2_model_1, predictions_logistic_2_model_2, predictions_logistic_2_model_3)
# average_predictions_3 = ensemble_predictions(predictions_ridge_3_model_1, predictions_logistic_3_model_2, predictions_logistic_3_model_3)

# %%
def ensemble_predictions(predictions_1, predictions_2, predictions_3):
    average_predictions = predictions_1 + predictions_2 + predictions_3 
    average_predictions = np.array([1 if el >= 1 else -1 for el in average_predictions])
    return average_predictions

# %%
average_predictions_0 = ensemble_predictions(predictions_ridge_0_model_1, predictions_ridge_0_model_2, predictions_logistic_0_model_3)
average_predictions_1 = ensemble_predictions(predictions_ridge_1_model_1, predictions_ridge_1_model_2, predictions_logistic_1_model_3)
average_predictions_2 = ensemble_predictions(predictions_ridge_2_model_1, predictions_ridge_2_model_2, predictions_logistic_2_model_3)
average_predictions_3 = ensemble_predictions(predictions_ridge_3_model_1, predictions_ridge_3_model_2, predictions_logistic_3_model_3)

# %% [markdown]
# Now we have to reconstruct a single vector of predictions

# %% [markdown]
# ### Generate final prediction list and print it in the file

# %%
# final_predictions_GD = create_output(tX_test,predictions_GD_0,predictions_GD_1,predictions_GD_2,predictions_GD_3)

# %%
#final_predictions_ridge = create_output(tX_test,predictions_ridge_0,predictions_ridge_1,predictions_ridge_2, predictions_ridge_3)

# %%
# final_predictions_LS = create_output(tX_test,predictions_LS_0,predictions_LS_1,predictions_LS_2,predictions_LS_3)

# %%
# final_predictions_ridge = create_output(tX_test,predictions_ridge_0,predictions_ridge_1,predictions_ridge_2,predictions_ridge_3)

# %%
# final_predictions_logistic = create_output(tX_test,predictions_logistic_0,predictions_logistic_1,predictions_logistic_2,predictions_logistic_3)

# %%
final_mixed_predictions = create_output(tX_test, average_predictions_0, average_predictions_1, average_predictions_2, average_predictions_3)

# %%
print(final_mixed_predictions)
print(1 / len(final_mixed_predictions) * np.count_nonzero(final_mixed_predictions == 1))
# Out:
# [-1 -1 -1 ...  1 -1 -1]
# 0.27912951967309474

# %%
OUTPUT_PATH_GD = '../data/submission_GD.csv' # name towards GD output
OUTPUT_PATH_SGD = '../data/submission_SGD.csv' # name towards SGD output
OUTPUT_PATH_LS = '../data/submission_LS.csv' # name towards LS output
OUTPUT_PATH_RIDGE = '../data/submission_ridge.csv' # name towards ridge output
OUPUT_PATH_LOGISTIC = '../data/submission_logistic.csv' #name towards logistic output
OUTPUT_PATH_ENSEMBLE= '../data/submission_ensemble.csv' # name towards logistic output 
#create_csv_submission(ids_test, final_predictions_GD, OUTPUT_PATH_GD) # print csv file according to GD results
#create_csv_submission(ids_test, final_predictions_SGD, OUTPUT_PATH_SGD) # print csv file according to SGD results
#create_csv_submission(ids_test, final_predictions_LS, OUTPUT_PATH_LS) # print csv file according to LS results
#create_csv_submission(ids_test, final_predictions_ridge, OUTPUT_PATH_RIDGE) # print csv file according to ridge results
#create_csv_submission(ids_test, final_predictions_logistic, OUTPUT_PATH_LOGISTIC) # print csv file according to logistic results
create_csv_submission(ids_test, final_mixed_predictions, OUTPUT_PATH_ENSEMBLE) # print csv file according to ensemble results
