# %%
# Useful starting lines
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import math
import random
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Load the training data into feature matrix, class labels, and event ids:

# %%
from proj1_helpers import *
DATA_TRAIN_PATH = '../data/train.csv' # train data path here 
y, tX, ids = load_csv_data(DATA_TRAIN_PATH)

# %%
print(tX.shape)
# Out:
# (250000, 30)

# %% [markdown]
# ### Changing the labels to {0,1}

# %%
# y == 0 non detected Boson, y == 1 detected Boson
y_ = np.array([0 if l == -1 else 1 for l in y])

# %% [markdown]
# ### Dividing the features by the number of jets

# %%
# dividing the rows of tX by the number of jets, dropping the column Pri_Jet_Num and adding an extra column of np.ones
zero_indices = []
one_indices = []
two_three_indices = []
zero_indices = np.where(tX[:,22]==0)[0]
one_indices = np.where(tX[:,22]==1)[0]
two_three_indices = np.where(np.logical_or(tX[:,22]==2, tX[:,22]==3))[0]
tX_0 = tX[zero_indices, :]
tX_0 = np.delete(tX_0, 22, axis=1)
tX_1 = tX[one_indices, :]
tX_1 = np.delete(tX_1, 22, axis=1)
tX_2_3 = tX[two_three_indices, :]

# %% [markdown]
# ### Dividing also the output by the type of particle

# %%
y_0 = y_[zero_indices]
y_1 = y_[one_indices]
y_2_3 = y_[two_three_indices]

# %% [markdown]
# ### Adding a column of zeros and ones to detect whether the mass has been measured or not

# %%
# take the indices where the mass is not calculated, add the column which has 0 in those indices
# and 1 everywhere else for all matrices 0,1,2_3
zero_indices_0 = np.where(tX_0[:,1] == -999.)[0]
column_to_add = np.array([0 if i in zero_indices_0 else 1 for i in range(tX_0.shape[0])])
tX_0 = np.insert(tX_0, 0, column_to_add, axis=1)
zero_indices_1 = np.where(tX_1[:,1] == -999.)[0]
column_to_add = np.array([0 if i in zero_indices_1 else 1 for i in range(tX_1.shape[0])])
tX_1 = np.insert(tX_1, 0, column_to_add, axis=1)
zero_indices_2_3 = np.where(tX_2_3[:,1] == -999.)[0]
column_to_add = np.array([0 if i in zero_indices_2_3 else 1 for i in range(tX_2_3.shape[0])])
tX_2_3 = np.insert(tX_2_3, 0, column_to_add, axis=1)

# %% [markdown]
# ### Throwing away the outliers from the training data

# %%
for i in range(1, tX_2_3.shape[1]):
    index_column_valid =np.where(tX_2_3[:,i] != -999.)[0]
    column_25_quantile, column_75_quantile = np.quantile(tX_2_3[index_column_valid,i], 
                                                         np.array([0.25, 0.75]))
    interquantile = column_75_quantile-column_25_quantile
    column_15_quantile, column_85_quantile = np.quantile(tX_2_3[index_column_valid,i], 
                                                         np.array([0.15, 0.85]))
    indices_outliers = np.where((column_15_quantile - 1.5 * interquantile >= tX_2_3[index_column_valid,i])
                                             | (tX_2_3[index_column_valid,i] >= 
                                                column_85_quantile + 1.5 * interquantile))[0]
    #indices_outliers = np.argwhere((tX_tilda_2_3[index_column_valid,i] >= column_85_quantile + 1.5 * interquantile) | 
                                  #(column_15_quantile - 1.5 * interquantile >= tX_tilda_2_3[index_column_valid,i]))
    median = np.median(tX_2_3[index_column_valid, i], axis = 0)
    #print(np.sort(tX_tilda_2_3[index_column_valid[indices_outliers],i]).T)
    #print(np.where(tX_tilda_2_3[indices_outliers,i])==-999.)
    #print(median)
    tX_2_3[index_column_valid[indices_outliers],i] =  median

# %%
col_to_delete_0 = []
for i in range(1, tX_0.shape[1]):
    index_column_valid =np.where(tX_0[:,i] != -999.)[0]
    if len(index_column_valid)==0:
        #we drop the column (we will have to do the same for the test set as well)
        col_to_delete_0.append(i)
    else :
        column_25_quantile, column_75_quantile = np.quantile(tX_0[index_column_valid,i], 
                                                         np.array([0.25, 0.75]))
        interquantile = column_75_quantile-column_25_quantile
        column_15_quantile, column_85_quantile = np.quantile(tX_0[index_column_valid,i], 
                                                         np.array([0.15, 0.85]))
        indices_outliers = np.where((column_15_quantile - 1.5 * interquantile >= tX_0[index_column_valid,i])
                                             | (tX_0[index_column_valid,i] >= 
                                                column_85_quantile + 1.5 * interquantile))[0]
        #indices_outliers = np.argwhere((tX_tilda_2_3[index_column_valid,i] >= column_85_quantile + 1.5 * interquantile) | 
                                  #(column_15_quantile - 1.5 * interquantile >= tX_tilda_2_3[index_column_valid,i]))
        median = np.median(tX_0[index_column_valid, i], axis = 0)
        #print(np.sort(tX_tilda_2_3[index_column_valid[indices_outliers],i]).T)
        #print(np.where(tX_tilda_2_3[indices_outliers,i])==-999.)
        #print(median)
        tX_0[index_column_valid[indices_outliers],i] =  median
col_to_delete_0.append(tX_0.shape[1]-1)
tX_0 = np.delete(tX_0, col_to_delete_0, axis=1)
print(tX_0.shape)
print(col_to_delete_0)
# Out:
# (99913, 19)
# [5, 6, 7, 13, 23, 24, 25, 26, 27, 28, 29]

# %%
col_to_delete_1 = []
for i in range(1, tX_1.shape[1]):
    index_column_valid =np.where(tX_1[:,i] != -999.)[0]
    if len(index_column_valid)==0:
        #we drop the column (we will have to do the same for the test set as well)
        col_to_delete_1.append(i)
    else :
        column_25_quantile, column_75_quantile = np.quantile(tX_1[index_column_valid,i], 
                                                         np.array([0.25, 0.75]))
        interquantile = column_75_quantile-column_25_quantile
        column_15_quantile, column_85_quantile = np.quantile(tX_1[index_column_valid,i], 
                                                         np.array([0.15, 0.85]))
        indices_outliers = np.where((column_15_quantile - 1.5 * interquantile >= tX_1[index_column_valid,i])
                                             | (tX_1[index_column_valid,i] >= 
                                                column_85_quantile + 1.5 * interquantile))[0]
        #indices_outliers = np.argwhere((tX_tilda_2_3[index_column_valid,i] >= column_85_quantile + 1.5 * interquantile) | 
                                  #(column_15_quantile - 1.5 * interquantile >= tX_tilda_2_3[index_column_valid,i]))
        median = np.median(tX_1[index_column_valid, i], axis = 0)
        #print(np.sort(tX_tilda_2_3[index_column_valid[indices_outliers],i]).T)
        #print(np.where(tX_tilda_2_3[indices_outliers,i])==-999.)
        #print(median)
        tX_1[index_column_valid[indices_outliers],i] =  median
tX_1 = np.delete(tX_1, col_to_delete_1, axis=1)
print(col_to_delete_1)
# Out:
# [5, 6, 7, 13, 26, 27, 28]

# %% [markdown]
# ### Now we substitute the -999 values with the median

# %%
for i in range(1, tX_2_3.shape[1]):
    index_column_non_valid =np.where(tX_2_3[:,i] == -999.)[0]
    index_column_valid =np.where(tX_2_3[:,i] != -999.)[0]
    median = np.median(tX_2_3[index_column_valid, i], axis = 0)
    tX_2_3[index_column_non_valid,i] =  median

# %%
for i in range(1, tX_1.shape[1]):
    index_column_non_valid =np.where(tX_1[:,i] == -999.)[0]
    index_column_valid =np.where(tX_1[:,i] != -999.)[0]
    median = np.median(tX_1[index_column_valid, i], axis = 0)
    tX_1[index_column_non_valid,i] =  median

# %%
for i in range(1, tX_0.shape[1]):
    index_column_non_valid =np.where(tX_0[:,i] == -999.)[0]
    index_column_valid =np.where(tX_0[:,i] != -999.)[0]
    median = np.median(tX_0[index_column_valid, i], axis = 0)
    tX_0[index_column_non_valid,i] =  median

# %% [markdown]
# ### Now we standardize the data

# %%
tX_2_3[:,1:], mean_2_3,std_2_3 = standardize(tX_2_3[:,1:]) #we standardize everything a part from the column added manually

# %%
print(tX_2_3)
print(np.count_nonzero(tX_2_3 == -999.))
# Out:
# [[ 1.          0.97351249  0.46588281 ...  0.61614788 -1.36131161
#   -0.70374641]
#  [ 1.         -0.82851663 -0.77157038 ...  0.11608109  1.71034105
#    0.2995537 ]
#  [ 1.          1.3538447  -0.27431587 ...  0.07030726 -1.52202162
#    0.12704911]
#  ...
#  [ 1.          0.04006392  0.02513449 ...  0.25930888  0.22982758
#    0.42357227]
#  [ 1.          0.66304099 -1.0843679  ...  0.29031696 -1.21821366
#   -0.20699627]
#  [ 1.          0.04006392  0.31977857 ... -0.02271698 -0.62490751
#    0.05569682]]
# 0

# %%
print(tX_0)
# Out:
# [[ 1.00000e+00  1.43905e+02  8.14170e+01 ...  3.10820e+01  6.00000e-02
#    8.60620e+01]
#  [ 1.00000e+00  1.75864e+02  1.69150e+01 ...  2.72300e+00 -8.71000e-01
#    5.31310e+01]
#  [ 1.00000e+00  1.05594e+02  5.05590e+01 ...  3.77910e+01  2.40000e-02
#    1.29804e+02]
#  ...
#  [ 1.00000e+00  1.11452e+02  5.81790e+01 ...  4.67370e+01 -8.67000e-01
#    8.04080e+01]
#  [ 1.00000e+00  9.49510e+01  1.93620e+01 ...  1.21500e+01  8.11000e-01
#    1.12718e+02]
#  [ 1.00000e+00  1.11452e+02  7.27560e+01 ...  4.07290e+01 -1.59600e+00
#    9.94050e+01]]

# %%
tX_0[:,1:],mean_0,std_0 = standardize(tX_0[:,1:])

# %%
print(tX_0)
# Out:
# [[ 1.          1.05744907  0.7827665  ...  0.01825038  0.04662815
#   -0.7724943 ]
#  [ 1.          2.14505538 -1.37519852 ... -1.71504715 -0.4674532
#   -1.44727052]
#  [ 1.         -0.24632406 -0.2496121  ...  0.42830338  0.0267496
#    0.12380588]
#  ...
#  [ 1.         -0.0469687   0.00532098 ...  0.97508147 -0.46524447
#   -0.8883482 ]
#  [ 1.         -0.60851918 -1.29333222 ... -1.13887042  0.46131675
#   -0.22629665]
#  [ 1.         -0.0469687   0.49300595 ...  0.60787347 -0.86778508
#   -0.49908812]]

# %%
tX_1[:,1:],mean_1,std_1 = standardize(tX_1[:,1:])

# %%
print(tX_1)
# Out:
# [[ 1.00000000e+00  1.55539992e+00  7.27047143e-01 ...  3.98445313e-01
#    6.45414781e-01 -4.14297220e-01]
#  [ 1.00000000e+00  1.45598722e-03  3.58462301e+00 ...  1.12748232e+00
#   -1.10752634e+00 -4.89864560e-01]
#  [ 1.00000000e+00  1.36261180e+00 -1.05809645e+00 ... -3.92076740e-01
#   -9.40265168e-01 -1.01072441e+00]
#  ...
#  [ 1.00000000e+00  1.45598722e-03  1.01732036e+00 ... -4.67286130e-01
#   -3.80160315e-01  8.39087556e-01]
#  [ 1.00000000e+00  6.75509966e-01  9.95415259e-01 ... -6.76994064e-01
#    1.39533906e+00  5.32418071e-01]
#  [ 1.00000000e+00 -2.21030015e-01  4.74893699e-01 ...  9.88591985e-01
#   -8.30516498e-02 -5.76298292e-01]]

# %% [markdown]
# ### We insert the column for the bias term

# %%
tX_tilda_0 = np.insert(tX_0, 0, np.ones(tX_0.shape[0]), axis=1)
tX_tilda_1 = np.insert(tX_1, 0, np.ones(tX_1.shape[0]), axis=1)
tX_tilda_2_3 = np.insert(tX_2_3, 0, np.ones(tX_2_3.shape[0]), axis=1)

# %%
print(tX_tilda_0)
# Out:
# [[ 1.          1.          1.05744907 ...  0.01825038  0.04662815
#   -0.7724943 ]
#  [ 1.          1.          2.14505538 ... -1.71504715 -0.4674532
#   -1.44727052]
#  [ 1.          1.         -0.24632406 ...  0.42830338  0.0267496
#    0.12380588]
#  ...
#  [ 1.          1.         -0.0469687  ...  0.97508147 -0.46524447
#   -0.8883482 ]
#  [ 1.          1.         -0.60851918 ... -1.13887042  0.46131675
#   -0.22629665]
#  [ 1.          1.         -0.0469687  ...  0.60787347 -0.86778508
#   -0.49908812]]

# %%
# colors = ['red', 'blue']
# x_pos=[]
# x_neg=[]

# for j in range(len(y)):
#  if(y[j]==1):
#       x_pos.insert(0,tX[j])
#    else:
#        x_neg.insert(0,tX[j])
# xpos = np.array(x_pos)
# xneg = np.array(x_neg)
# for i in range(tX.shape[1]):
#  plt.hist(xpos[:,i], alpha = 0.5, color = 'r', bins = 100)
#  plt.hist(xneg[:,i], alpha = 0.5, color = 'b', bins = 100)
#  plt.show()

# %% [markdown]
# ## Do your thing crazy machine learning thing here :) ...

# %%
def compute_loss(y, tx, w):
    N = y.shape[0]
    e = y - tx @ w 
    loss = 1/(2*N) * np.dot(e,e)
    return loss

# %%
def compute_gradient(y, tx, w):
    N = y.shape[0]
    e = y - tx @ w
    gradient = -(1/N) * (tx.T) @ (e)
    return gradient

# %%
def least_squares_GD(y, tx, initial_w, max_iters, gamma):
    ws = [initial_w]
    losses = []
    w = initial_w
    for n_iter in range(max_iters):
        loss = compute_loss(y,tx,w)
        gradient = compute_gradient(y,tx,w)
        w = w - gamma * gradient
        ws.append(w)
        losses.append(loss)
        # print("Gradient Descent({bi}/{ti}): loss={l}, w0={w0}, w1={w1}".format(
        # bi=n_iter, ti=max_iters - 1, l=loss, w0=w[0], w1=w[1]))
    return losses, ws

# %%
def cross_validation_GD(y, x, k_indices, k, degree, gamma = 3.0e-02):
    """return the loss of ridge regression."""
    N = y.shape[0]
    k_fold = k_indices.shape[0]
    list_ = []
    interval = int(N/k_fold)
    for i in range(k_fold):
        if i != k:
            list_.append(i)
    x_training = np.zeros((int((k_fold-1)/k_fold*N), x.shape[1]))
    y_training = np.zeros(int((k_fold-1)/k_fold*N))
    for j in range(len(list_)):
        x_training[interval*(j):interval*(j+1), :] = x[np.array([k_indices[list_[j]]]), :]
    x_testing = x[k_indices[k], :]
    for j in range(len(list_)):
        y_training[interval*(j):interval*(j+1)] = y[np.array([k_indices[list_[j]]])]
    y_testing = y[k_indices[k]]
    x_training_augmented = build_poly(x_training, degree)
    x_testing_augmented = build_poly(x_testing, degree)
    #w_opt_training = ridge_regression(y_training, x_training_augmented, lambda_)
    _,  w_opt_training = least_squares_GD(y_training, x_training_augmented,
                                                        np.zeros(x_training_augmented.shape[1]), 1000, gamma)
    loss_tr = calculate_loss(y_training, x_training_augmented, w_opt_training[-1])
    loss_te = calculate_loss(y_testing, x_testing_augmented, w_opt_training[-1])
    return loss_tr, loss_te

# %%
def compute_stoch_gradient(y, tx, w):
    N = y.shape[0]
    random_number = random.randint(0,N)
    #random_number =1
    xn = tx[random_number,:]
    random_gradient = - np.dot(xn, y[random_number] - np.dot(xn,w))
    return random_gradient

# %%
def least_squares_SGD(y, tx, initial_w, max_iters, gamma):
    ws = [initial_w]
    losses = []
    w = initial_w
    for n_iter in range(max_iters):
        loss = compute_loss(y,tx,w)
        stoch_gradient = compute_stoch_gradient(y,tx,w)
        w = w - gamma * stoch_gradient
        ws.append(w)
        losses.append(loss)
        # print("Gradient Descent({bi}/{ti}): loss={l}, w0={w0}, w1={w1}".format(
        #    bi=n_iter, ti=max_iters - 1, l=loss, w0=w[0], w1=w[1]))
    return losses, ws

# %%
from proj1_helpers import *

def least_squares(y, tx):
    """calculate the least squares solution."""
    forcing_term = np.transpose(tx) @ y
    coefficient_matrix = np.transpose(tx) @ tx
    w = np.linalg.solve(coefficient_matrix, forcing_term)
    return w

def test_your_least_squares(y, tx):
    """compare the solution of the normal equations with the weights returned by gradient descent algorithm."""
    w_least_squares = least_squares(y, tx)
    initial_w = np.zeros(tx.shape[1])
    max_iters = 50
    gamma = 0.7
    losses_gradient_descent, w_gradient_descent = gradient_descent(y, tx, initial_w, max_iters, gamma)
    w = w_gradient_descent[-1]
    err = np.linalg.norm(w_least_squares-w)
    return err

# %%
def ridge_regression(y, tx, lambda_):
    """implement ridge regression."""
    N = tx.shape
    lambda_prime = 2 * N[0] * lambda_
    coefficient_matrix = np.transpose(tx) @ tx + lambda_prime * np.eye(N[1])
    forcing_term = np.transpose(tx) @ y
    w = np.linalg.solve(coefficient_matrix, forcing_term)
    return w

def debug_ridge(y, tx):
    """debugging the ridge regression by setting lambda=0."""
    w_least_squares = least_squares(y, tx)
    w_0 = ridge_regression(y, tx, 0)
    err = np.linalg.norm(w_least_squares-w_0)
    return err

# %%
def sigmoid(t):
    """apply the sigmoid function on t."""
    positive_indices = np.where(t >= 0)[0]
    negative_indices = np.where(t < 0)[0]
    z = np.zeros(len(t))
    z[positive_indices] = 1 / (1+np.exp(-t[positive_indices]))
    z[negative_indices] = np.exp(t[negative_indices]) / (1 + np.exp(t[negative_indices]))
    return z

# %%
def calculate_loss(y, tx, w):
    """compute the loss: negative log likelihood."""
    epsilon = 1.0e-12
    # term1 = sigmoid(tx @ w)
    # term1[y == 0] = 1
    # term2 = 1 - sigmoid(tx @ w)
    # term2[y == 1] = 1
    # summands = np.multiply(y, np.log(term1)) + np.multiply(1 - y, np.log(term2))
    # e = - y * (tx @ w) + np.log(1 + np.exp(tx @ w))
    # return e.sum()
    pos_ind = np.where(tx @ w >=0)[0]
    neg_ind = np.where(tx @ w <0)[0]
    loss_pos = - y[pos_ind] * (tx @ w)[pos_ind] + (tx @ w)[pos_ind] + np.log(1+np.exp(-(tx @ w)[pos_ind]))
    loss_neg = - y[neg_ind] * (tx @ w)[neg_ind] - (tx @ w)[neg_ind] + np.log(1+np.exp((tx @ w)[neg_ind]))
    # loss = - np.sum(y*np.log(sigmoid(tx @ w)+epsilon) + ((1 - y) * np.log(1-sigmoid(tx@w) + epsilon)))
    # return e.sum()
    return loss_pos.sum() + loss_neg.sum()

# %%
def calculate_gradient(y, tx, w):
    """compute the gradient of loss."""
    return np.transpose(tx) @ (sigmoid(tx @ w) - y)

# %%
def learning_by_gradient_descent(y, tx, w_initial, gamma, max_iters):
    """
    Do one step of gradient descent using logistic regression.
    Return the loss and the updated w.
    """
    losses = []
    w = w_initial
    for iter in range(max_iters):
        grad = calculate_gradient(y, tx, w)
        w = w - gamma * grad
        if iter %100 == 0:
            gamma = gamma/2
        loss = calculate_loss(y, tx, w)
        losses.append(loss)
    return losses, w

# %%
losses1, w1 = learning_by_gradient_descent(y_0, tX_tilda_0, np.zeros(tX_tilda_0.shape[1]), 0.8, 10000)
print(losses1)
# Out:
# [5179248944.798144, 4548292501.191404, 3873264747.21586, 3204189882.4289737, 2558766497.952185, 1925840421.0113575, 1358134428.6513941, 806750192.3189367, 2000410682.432268, 1601256172.1407366, 2113524821.0324888, 1606047298.1298404, 1990415844.7863326, 1640858641.9754827, 1934131711.4022741, 1285499978.8239229, 2039587553.53073, 1427677293.0631957, 1887233645.3011723, 1447488537.8697784, 1922910135.0624075, 1269966212.2418594, 1955256377.1863978, 1400327379.5162985, 1845506548.8767402, 1264731822.7936993, 1931658652.60472, 1314650368.8542542, 1862692520.787514, 1330058160.1396096, 1877959970.3375432, 1229045186.878255, 1902392318.7811527, 1308156948.822424, 1844261214.6761906, 1241157611.7496824, 1894851670.6505013, 1255749330.385391, 1860264536.3923934, 1274839497.858362, 1859682719.8045244, 1218658685.3284106, 1880581668.544345, 1258713077.568829, 1850203797.9833395, 1235051327.652052, 1873359564.5703435, 1230356581.4284768, 1859083288.6203346, 1244041475.3119462, 1856766909.6040347, 1220098306.0175045, 1867105792.1078453, 1231961026.60114, 1855972090.5372326, 1230042464.7907495, 1858379883.003287, 1218727526.8907793, 1861762190.087661, 1228383177.0291238, 1857254730.101566, 1222051259.0083282, 1860158108.3698952, 1220116578.8778446, 1858589441.387719, 1223235696.7559175, 1858398873.9334707, 1218854588.4199448, 1858822013.6627657, 1219813127.567595, 1857066247.183061, 1219270818.3619866, 1858478934.766644, 1217907839.0620358, 1858048932.153936, 1218557408.6697712, 1858184218.9895601, 1218007631.335454, 1857623659.3740156, 1216853916.412851, 1858648321.3898296, 1217888005.241971, 1857943355.4563303, 1216851537.8506684, 1858168298.05914, 1216534464.3126922, 1858125875.668396, 1217143280.1293156, 1858043712.5992842, 1215963898.0179276, 1857928972.9718575, 1216515460.433278, 1858127808.2552621, 1216943000.509746, 1857998825.3846254, 1215520797.6106877, 1857198930.9838195, 1215707533.7456686, 1859049694.523571, 1217315817.2481995, 1857364856.1177638, 1125745790.3855321, 944200126.7037269, 662141542.0894874, 623888265.6804897, 542765196.9049829, 1066639938.8083351, 872688728.878017, 1044854652.9094745, 632335881.8773843, 861860413.9694176, 649571080.256373, 981428810.6660107, 578543407.6949754, 926430952.6115094, 621055451.0538659, 936233536.4382356, 636682671.2746578, 935014632.5617651, 593303990.2621491, 943586845.682435, 626939785.2412643, 924314957.9480356, 610477203.7289473, 939691572.108919, 608318269.487753, 930729997.2205715, 618952330.6743699, 928217647.1602719, 603865613.7556918, 936328610.3769706, 613170977.0339847, 928199747.462669, 612721423.0114655, 930881380.4755912, 605416546.2390891, 931676156.7157516, 612312908.9601693, 927577937.8198823, 608182237.4535668, 930870222.5632684, 607916117.4380765, 929317430.424941, 610383416.4336089, 928273501.3008385, 606428601.0859907, 930116995.8931648, 609102400.1341647, 927919382.9587, 608528073.4760014, 929437197.5674391, 607326812.2206681, 929399165.5494884, 609271273.517202, 928165670.7137808, 607504680.113518, 929339224.349415, 608176284.2726083, 928693185.8936846, 608613021.1400387, 928991721.9335793, 607740542.8672402, 928578304.1950184, 607865889.3626766, 929525574.5105095, 608779589.8939065, 928624515.8696117, 607683330.0724051, 928559078.1012169, 607533383.2162838, 929540625.7233571, 608494949.2950689, 928488220.7576932, 607459022.2700671, 928727358.6081303, 607401095.1887784, 929418277.4860147, 608290484.58148, 928571785.6069802, 607641020.634532, 928598807.7356391, 607313937.7246315, 929386695.8922136, 608104848.766564, 928773505.7561433, 607658077.4178171, 928502668.8243848, 607164674.0369027, 929268466.0981069, 608027924.0791512, 928859016.1817883, 607671235.8076867, 928412600.718565, 607001758.9389658, 929084039.6158366, 607842996.7472583, 929021464.4248416, 607693633.5370682, 928354898.9661345, 606911653.3413285, 929250777.8679187, 562338764.4753156, 471218610.9473674, 330626236.46634156, 310540372.20997566, 270510508.27824885, 532053311.32946, 436769061.0695732 ...

# %%
def calculate_hessian(y, tx, w):
    """return the Hessian of the loss function."""
    diag = sigmoid(tx @ w) * (1 - sigmoid(tx @ w))
    D = diag * np.eye(tx.shape[0])
    return np.transpose(tx) @ D @ tx

# %%
def logistic_regression(y, tx, w):
    """return the loss, gradient, and Hessian."""
    grad = calculate_gradient(y, tx, w)
    hess = calculate_hessian(y, tx, w)
    loss = calculate_loss(y, tx, w)
    return loss, grad, hess

# %%
def learning_by_newton_method(y, tx, w, gamma):
    """
    Do one step on Newton's method.
    return the loss and updated w.
    """
    loss, grad, hess = logistic_regression(y, tx, w)
    sol = np.linalg.solve(hess, grad)
    w = w - gamma * sol
    return loss, w

# %%
def penalized_logistic_regression(y, tx, w, lambda_):
    """return the loss, gradient"""
    loss = calculate_loss(y, tx, w) + lambda_*np.linalg.norm(w) ** 2
    grad = calculate_gradient(y, tx, w) + 2*lambda_*w
    hess = calculate_hessian(y, tx, w) + 2*lambda_*np.eye(w.shape[0])
    return loss, grad, hess

# %%
def learning_by_penalized_gradient(y, tx, w_initial, gamma, max_iters, lambda_):
    """
    Do one step of gradient descent, using the penalized logistic regression.
    Return the loss and updated w.
    """
    threshold = 1e-8
    losses = []
    w = w_initial
    for iter in range(max_iters):
        grad = calculate_gradient(y, tx, w) + 2*lambda_*w
        w = w - gamma * grad
        # regularizer = lambda_ / 2 * np.linalg.norm(w) ** 2
        # summing = np.sum(np.log(1+np.exp(tx.dot(w))))
        # y_component = y.T.dot(tx.dot(w)).flatten().flatten()
        # loss = summing - y_component*regularizer
        loss = calculate_loss(y, tx, w) + lambda_*np.linalg.norm(w) ** 2
        losses.append(loss)
        if iter % 25 == 0:
            gamma = gamma / 2
            print("Current iteration={i}, loss={l}".format(i=iter, l=loss))
        # converge criterion
        if len(losses) > 1 and np.abs(losses[-1] - losses[-2]) < threshold:
            break
    return losses, w

# %%
def build_poly(x, degree):
    """polynomial basis functions for input data x, for j=1 up to j=degree."""
    powers = np.arange(1, degree + 1)
    phi = np.column_stack([np.power(x[:,0], exponent) for exponent in powers])
    for i in range(1, x.shape[1]):
        phi_i = np.column_stack([np.power(x[:,i], exponent) for exponent in powers])
        phi = np.column_stack([phi, phi_i])
    return phi

# %%
def build_k_indices(y, k_fold, seed):
    N = y.shape[0]
    np.random.seed(seed)
    interval = int(np.floor(N / k_fold))
    indices = np.random.permutation(N)
    k_indices = [indices[k * interval: (k + 1) * interval]
                 for k in range(k_fold)]
    return np.array(k_indices)

# %%
def cross_validation_ridge(y, x, k_indices, k, lambda_, degree):
    """return the loss of ridge regression."""
    N = y.shape[0]
    k_fold = k_indices.shape[0]
    list_ = []
    interval = int(N/k_fold)
    for i in range(k_fold):
        if i != k:
            list_.append(i)
    x_training = np.zeros((int((k_fold-1)/k_fold*N), x.shape[1]))
    y_training = np.zeros(int((k_fold-1)/k_fold*N))
    for j in range(len(list_)):
        x_training[interval*(j):interval*(j+1), :] = x[np.array([k_indices[list_[j]]]), :]
    x_testing = x[k_indices[k], :]
    for j in range(len(list_)):
        y_training[interval*(j):interval*(j+1)] = y[np.array([k_indices[list_[j]]])]
    y_testing = y[k_indices[k]]
    x_training_augmented = build_poly(x_training, degree)
    x_testing_augmented = build_poly(x_testing, degree)
    w_opt_training = ridge_regression(y_training, x_training_augmented, lambda_)
    loss_tr = compute_loss(y_training, x_training_augmented, w_opt_training)
    loss_te = compute_loss(y_testing, x_testing_augmented, w_opt_training)
    return loss_tr, loss_te

# %%
degrees = np.arange(2, 7)
lambdas = np.logspace(-5,0,15)
k_fold = 5
seed = 1
training_loss = np.zeros((len(lambdas), len(degrees)))
testing_loss = np.zeros((len(lambdas), len(degrees)))
k_indices = build_k_indices(y_0, k_fold, seed)
for index1 in range(len(lambdas)):
    for index2 in range(len(degrees)):
        train_loss = 0
        test_loss = 0
        for k in range(k_fold):
            loss_tr, loss_te = cross_validation_ridge(y_0, tX_tilda_0, k_indices, k,
                                                lambdas[index1], degrees[index2])
            train_loss += loss_tr
            test_loss += loss_te
        training_loss[index1, index2] = train_loss / k_fold
        testing_loss[index1, index2] = test_loss / k_fold
best_result = np.where(testing_loss == np.amin(testing_loss))
print(testing_loss)
lambda_opt, degree_opt = lambdas[best_result[0]],degrees[best_result[1]]
print(lambda_opt, degree_opt)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-44-787d91689e85> in <module>
#      11         test_loss = 0
#      12         for k in range(k_fold):
# ---> 13             loss_tr, loss_te = cross_validation_ridge(y_0, tX_tilda_0, k_indices, k,
#      14                                                 lambdas[index1], degrees[index2])
#      15             train_loss += loss_tr
#
# <ipython-input-43-1d3d0fbebd0a> in cross_validation_ridge(y, x, k_indices, k, lambda_, degree)
#      16         y_training[interval*(j):interval*(j+1)] = y[np.array([k_indices[list_[j]]])]
#      17     y_testing = y[k_indices[k]]
# ---> 18     x_training_augmented = build_poly(x_training, degree)
#      19     x_testing_augmented = build_poly(x_testing, degree)
#      20     w_opt_training = ridge_regression(y_training, x_training_augmented, lambda_)
#
# <ipython-input-41-707968e33a36> in build_poly(x, degree)
#       4     phi = np.column_stack([np.power(x[:,0], exponent) for exponent in powers])
#       5     for i in range(1, x.shape[1]):
# ----> 6         phi_i = np.column_stack([np.power(x[:,i], exponent) for exponent in powers])
#       7         phi = np.column_stack([phi, phi_i])
#       8     return phi
#
# <ipython-input-41-707968e33a36> in <listcomp>(.0)
#       4     phi = np.column_stack([np.power(x[:,0], exponent) for exponent in powers])
#       5     for i in range(1, x.shape[1]):
# ----> 6         phi_i = np.column_stack([np.power(x[:,i], exponent) for exponent in powers])
#       7         phi = np.column_stack([phi, phi_i])
#       8     return phi
#
# KeyboardInterrupt:

# %%
degrees = np.arange(2, 7)
lambdas = np.logspace(-5,0,15)
k_fold = 5
seed = 1
training_loss = np.zeros((len(lambdas), len(degrees)))
testing_loss = np.zeros((len(lambdas), len(degrees)))
k_indices = build_k_indices(y_1, k_fold, seed)
for index1 in range(len(lambdas)):
    for index2 in range(len(degrees)):
        train_loss = 0
        test_loss = 0
        for k in range(k_fold):
            loss_tr, loss_te = cross_validation_ridge(y_1, tX_tilda_1, k_indices, k, 
                                                lambdas[index1], degrees[index2])
            train_loss += loss_tr
            test_loss += loss_te
        training_loss[index1, index2] = train_loss / k_fold
        testing_loss[index1, index2] = test_loss / k_fold
best_result = np.where(testing_loss == np.amin(testing_loss))
print(testing_loss)
lambda_opt, degree_opt = lambdas[best_result[0]], degrees[best_result[1]]
print(lambda_opt, degree_opt)

# %%
degrees = np.arange(2, 7)
lambdas = np.logspace(-5,0,15)
k_fold = 5
seed = 1
training_loss = np.zeros((len(lambdas), len(degrees)))
testing_loss = np.zeros((len(lambdas), len(degrees)))
k_indices = build_k_indices(y_2_3, k_fold, seed)
for index1 in range(len(lambdas)):
    for index2 in range(len(degrees)):
        train_loss = 0
        test_loss = 0
        for k in range(k_fold):
            loss_tr, loss_te = cross_validation_ridge(y_2_3, tX_tilda_2_3, k_indices, k,
                                            lambdas[index1], degrees[index2])
            train_loss += loss_tr
            test_loss += loss_te
        training_loss[index1, index2] = train_loss / k_fold
        testing_loss[index1, index2] = test_loss / k_fold
best_result = np.where(testing_loss == np.amin(testing_loss))
lambda_opt, degree_opt = lambdas[best_result[0]], degrees[best_result[1]]
print(testing_loss)
print(lambda_opt, degree_opt)

# %% [markdown]
# We train the model for ridge regression with the best hyperparameters

# %%
tX_tilda_0_augmented = build_poly(tX_tilda_0, degree = 6)
w_ridge_0 = ridge_regression(y_0, tX_tilda_0_augmented, lambda_= 0.00061054)
#print(w_ridge_0)

# %%
tX_tilda_1_augmented = build_poly(tX_tilda_1, degree=6)
w_ridge_1 = ridge_regression(y_1, tX_tilda_1_augmented, lambda_= 5.17947468e-05)
#print(w_ridge_1)

# %%
tX_tilda_2_3_augmented = build_poly(tX_tilda_2_3, degree=6)
w_ridge_2_3 = ridge_regression(y_2_3, tX_tilda_2_3_augmented, lambda_= 0.00026827)
#print(w_ridge_2_3)

# %% [markdown]
# We will now try with logistic regression

# %%
def cross_validation_logistic(y, x, k_indices, k, lambda_, degree, gamma):
    """return the loss of ridge regression."""
    N = y.shape[0]
    k_fold = k_indices.shape[0]
    list_ = []
    interval = int(N/k_fold)
    for i in range(k_fold):
        if i != k:
            list_.append(i)
    x_training = np.zeros((int((k_fold-1)/k_fold*N), x.shape[1]))
    y_training = np.zeros(int((k_fold-1)/k_fold*N))
    for j in range(len(list_)):
        x_training[interval*(j):interval*(j+1), :] = x[np.array([k_indices[list_[j]]]), :]
    x_testing = x[k_indices[k], :]
    for j in range(len(list_)):
        y_training[interval*(j):interval*(j+1)] = y[np.array([k_indices[list_[j]]])]
    y_testing = y[k_indices[k]]
    x_training_augmented = build_poly(x_training, degree)
    x_testing_augmented = build_poly(x_testing, degree)
    #w_opt_training = ridge_regression(y_training, x_training_augmented, lambda_)
    _,  w_opt_training = learning_by_penalized_gradient(y_training, x_training_augmented,
                                                        np.ones(x_training_augmented.shape[1]), gamma, 1000, lambda_)
    loss_tr = calculate_loss(y_training, x_training_augmented, w_opt_training)
    loss_te = calculate_loss(y_testing, x_testing_augmented, w_opt_training)
    return loss_tr, loss_te

# %% [markdown]
# We perform cross validation in order to find the best parameters degree, lamdba and gamma caracterizing logistic regression

# %%
print(tX_tilda_0)
# Out:
# [[ 1.          1.          1.05744907 ...  0.01825038  0.04662815
#   -0.7724943 ]
#  [ 1.          1.          2.14505538 ... -1.71504715 -0.4674532
#   -1.44727052]
#  [ 1.          1.         -0.24632406 ...  0.42830338  0.0267496
#    0.12380588]
#  ...
#  [ 1.          1.         -0.0469687  ...  0.97508147 -0.46524447
#   -0.8883482 ]
#  [ 1.          1.         -0.60851918 ... -1.13887042  0.46131675
#   -0.22629665]
#  [ 1.          1.         -0.0469687  ...  0.60787347 -0.86778508
#   -0.49908812]]

# %%
# degrees = np.arange(2, 5)
lambdas = np.linspace(0, 3, 5)
degree = 2
# gammas = np.logspace(-5, 0, 5)
gamma = 0.00017783
k_fold = 5
seed = 1
training_loss = np.zeros(len(lambdas))
testing_loss = np.zeros(len(lambdas))
k_indices = build_k_indices(y_0, k_fold, seed)
for index1 in range(len(lambdas)):
    # for index2 in range(len(degrees)):
    #  for index3 in range(len(gammas)):
    train_loss = 0
    test_loss = 0
    for k in range(k_fold):
            loss_tr, loss_te = cross_validation_logistic(y_0, tX_tilda_0, k_indices, k,
                                                    lambdas[index1], degree, gamma)
            train_loss += loss_tr
            test_loss += loss_te
    training_loss[index1] = train_loss / k_fold
    testing_loss[index1] = test_loss / k_fold
best_result = np.where(testing_loss == np.amin(testing_loss))
lambda_opt = lambdas[best_result[0]]
print(lambda_opt)
# Out:
# Current iteration=0, loss=21039050.154922392
# Current iteration=25, loss=984841.4777189632
# Current iteration=50, loss=778278.5443313502
# Current iteration=75, loss=1188836.5812747062
# Current iteration=100, loss=273939.75015508995
# Current iteration=125, loss=242911.33780006418
# Current iteration=150, loss=231537.50693589723
# Current iteration=175, loss=226600.6981856473
# Current iteration=200, loss=224305.98685609986
# Current iteration=225, loss=223200.39693480553
# Current iteration=250, loss=222657.84702895145
# Current iteration=275, loss=222389.11240926015
# Current iteration=300, loss=222255.37587417557
# Current iteration=325, loss=222188.66586371264
# Current iteration=350, loss=222155.3508860206
# Current iteration=375, loss=222138.70309794298
# Current iteration=400, loss=222130.38162838196
# Current iteration=425, loss=222126.22149963162
# Current iteration=450, loss=222124.14158675287
# Current iteration=475, loss=222123.1016681862
# Current iteration=500, loss=222122.58171837084
# Current iteration=525, loss=222122.32174583018
# Current iteration=550, loss=222122.19176015156
# Current iteration=575, loss=222122.12676746026
# Current iteration=600, loss=222122.09427115152
# Current iteration=625, loss=222122.0780230064
# Current iteration=650, loss=222122.06989893614
# Current iteration=675, loss=222122.06583690146
# Current iteration=700, loss=222122.06380588445
# Current iteration=725, loss=222122.06279037573
# Current iteration=750, loss=222122.06228262163
# Current iteration=775, loss=222122.06202874458
# Current iteration=800, loss=222122.06190180598
# Current iteration=825, loss=222122.06183833658
# Current iteration=850, loss=222122.06180660194
# Current iteration=875, loss=222122.0617907347
# Current iteration=900, loss=222122.06178280103
# Current iteration=925, loss=222122.0617788342
# Current iteration=950, loss=222122.06177685078
# Current iteration=975, loss=222122.06177585907
# Current iteration=0, loss=21100494.15585402
# Current iteration=25, loss=1103756.5002577128
# Current iteration=50, loss=1085854.3975497412
# Current iteration=75, loss=790917.7626443537
# Current iteration=100, loss=284741.19298859534
# Current iteration=125, loss=250401.86452948177
# Current iteration=150, loss=237691.82457818434
# Current iteration=175, loss=232171.43025731298
# Current iteration=200, loss=229603.16221404012
# Current iteration=225, loss=228365.15741117654
# Current iteration=250, loss=227757.47912579708
# Current iteration=275, loss=227456.42540723228
# Current iteration=300, loss=227306.59171570564
# Current iteration=325, loss=227231.84827015965
# Current iteration=350, loss=227194.52064647299
# Current iteration=375, loss=227175.86767914833
# Current iteration=400, loss=227166.54387106292
# Current iteration=425, loss=227161.88264214975
# Current iteration=450, loss=227159.55219627864
# Current iteration=475, loss=227158.3870151383
# Current iteration=500, loss=227157.80443501665
# Current iteration=525, loss=227157.5131475679
# Current iteration=550, loss=227157.3675044966
# Current iteration=575, loss=227157.29468312417
# Current iteration=600, loss=227157.25827247882
# Current iteration=625, loss=227157.24006716625
# Current iteration=650, loss=227157.2309645125
# Current iteration=675, loss=227157.22641318635
# Current iteration=700, loss=227157.22413752327
# Current iteration=725, loss=227157.22299969182
# Current iteration=750, loss=227157.22243077605
# Current iteration=775, loss=227157.22214631818
# Current iteration=800, loss=227157.2220040893
# Current iteration=825, loss=227157.22193297488
# Current iteration=850, loss=227157.22189741777
# Current iteration=875, loss=227157.22187963905
# Current iteration=900, loss=227157.22187074964
# Current iteration=925, loss=227157.22186630513
# Current iteration=950, loss=227157.22186408273
# Current iteration=975, loss=227157.22186297167
# Current iteration=0, loss=21009906.91282853
# Current iteration=25, loss=1274995.8902099608
# Current iteration=50, loss=1090412.9937318237
# Current iteration=75, loss=317605.1061584692
# Current iteration=100, loss=293796.9509335384
# Current iteration=125, loss=258000.79105893904
# Current iteration=150, loss=244281.9151926929
# Current iteration=175, loss=238264.4830017096
# Current iteration=200, loss=235450.6235055912
# Current iteration=225, loss=234090.79014536264
# Current iteration=250, loss=233422.4226678544
# Current iteration=275, loss=233091.09738118463
# Current iteration=300, loss=232926.1456965889
# Current iteration=325, loss=232843.84687052947
# Current iteration=350, loss=232802.7417345355
# Current iteration=375, loss=232782.20025080867
# Current iteration=400, loss=232771.932260236
# Current iteration=425, loss=232766.79895072422
# Current iteration=450, loss=232764.2324814186
# Current iteration=475, loss=232762.94928957958
# Current iteration=500, loss=232762.30770436337
# Current iteration=525, loss=232761.98691443107
# Current iteration=550, loss=232761.82652013385
# Current iteration=575, loss=232761.74632315245
# Current iteration=600, loss=232761.7062247037
# Current iteration=625, loss=232761.68617548962
# Current iteration=650, loss=232761.67615088527
# Current iteration=675, loss=232761.67113858374
# Current iteration=700, loss=232761.66863243305
# Current iteration=725, loss=232761.6673793579
# Current iteration=750, loss=232761.66675282028
# Current iteration=775, loss=232761.66643955157
# Current iteration=800, loss=232761.66628291717
# Current iteration=825, loss=232761.6662046
# Current iteration=850, loss=232761.66616544145
# Current iteration=875, loss=232761.66614586202
# Current iteration=900, loss=232761.66613607242
# Current iteration=925, loss=232761.66613117757
# Current iteration=950, loss=232761.66612873014
# Current iteration=975, loss=232761.66612750653
# Current iteration=0, loss=21015135.344191525
# Current iteration=25, loss=982265.7489521827
# Current iteration=50, loss=887672.7708129317
# Current iteration=75, loss=333651.3441677238
# Current iteration=100, loss=290895.5376698028
# Current iteration=125, loss=255771.89497559093
# Current iteration=150, loss=242378.448729755
# Current iteration=175, loss=236512.50654934044
# Current iteration=200, loss=233770.6921447374
# Current iteration=225, loss=232445.76807198982
# Current iteration=250, loss=231794.55920937596
# Current iteration=275, loss=231471.74832387382
# Current iteration=300, loss=231311.03885622468
# Current iteration=325, loss=231230.85964564543
# Current iteration=350, loss=231190.81353194907
# Current iteration=375, loss=231170.80131078407
# Current iteration=400, loss=231160.79791980822
# Current iteration=425, loss=231155.7969293068
# Current iteration=450, loss=231153.29660126823
# Current iteration=475, loss=231152.04647905054
# Current iteration=500, loss=231151.42142839194
# Current iteration=525, loss=231151.10890567518
# Current iteration=550, loss=231150.95264496992
# Current iteration=575, loss=231150.8745147806
# Current iteration=600, loss=231150.83544972673
# Current iteration=625, loss=231150.81591721004
# Current iteration=650, loss=231150.80615095425
# Current iteration=675, loss=231150.80126782696
# Current iteration=700, loss=231150.7988262636
# Current iteration=725, loss=231150.79760548193
# Current iteration=750, loss=231150.79699509105
# Current iteration=775, loss=231150.79668989562
# Current iteration=800, loss=231150.79653729807
# Current iteration=825, loss=231150.79646099926
# Current iteration=850, loss=231150.7964228497
# Current iteration=875, loss=231150.79640377493
# Current iteration=900, loss=231150.79639423743
# Current iteration=925, loss=231150.7963894688
# Current iteration=950, loss=231150.79638708456
# Current iteration=975, loss=231150.7963858924
# Current iteration=0, loss=21010654.511916827
# Current iteration=25, loss=868113.7215756376
# Current iteration=50, loss=970689.5369356327
# Current iteration=75, loss=292811.94348288304
# Current iteration=100, loss=278170.19284415536
# Current iteration=125, loss=245674.8409258597
# Current iteration=150, loss=233748.8819168664
# Current iteration=175, loss=228558.81515694218
# Current iteration=200, loss=226142.17671774834
# Current iteration=225, loss=224976.84625075676
# Current iteration=250, loss=224404.7018241636
# Current iteration=275, loss=224121.24230637556
# Current iteration=300, loss=223980.16404324118
# Current iteration=325, loss=223909.78711218876
# Current iteration=350, loss=223874.63944597464
# Current iteration=375, loss=223857.07580514497
# Current iteration=400, loss=223848.29661584998
# Current iteration=425, loss=223843.90765161865
# Current iteration=450, loss=223841.71332551123
# Current iteration=475, loss=223840.61620145815
# Current iteration=500, loss=223840.06764918164
# Current iteration=525, loss=223839.7933754809
# Current iteration=550, loss=223839.65623923988
# Current iteration=575, loss=223839.58767127173
# Current iteration=600, loss=223839.5533873257
# Current iteration=625, loss=223839.5362453622
# Current iteration=650, loss=223839.5276743829
# Current iteration=675, loss=223839.52338889366
# Current iteration=700, loss=223839.52124614955
# Current iteration=725, loss=223839.52017477725
# Current iteration=750, loss=223839.51963909133
# Current iteration=775, loss=223839.51937124843
# Current iteration=800, loss=223839.51923732692
# Current iteration=825, loss=223839.51917036614
# Current iteration=850, loss=223839.51913688568
# Current iteration=875, loss=223839.51912014547
# Current iteration=900, loss=223839.51911177544
# Current iteration=925, loss=223839.51910759043
# Current iteration=950, loss=223839.51910549772
# Current iteration=975, loss=223839.5191044514
# Current iteration=0, loss=21041237.39057679
# Current iteration=25, loss=1006366.0201108945
# Current iteration=50, loss=1674414.9648537983
# Current iteration=75, loss=774833.8882705042
# Current iteration=100, loss=281565.3747204124
# Current iteration=125, loss=248250.67862927433
# Current iteration=150, loss=235817.18178856806
# Current iteration=175, loss=230433.179356949
# Current iteration=200, loss=227930.9028196981
# Current iteration=225, loss=226725.30711917835
# Current iteration=250, loss=226133.6201152175
# Current iteration=275, loss=225840.54401440817
# Current iteration=300, loss=225694.70015633924
# Current iteration=325, loss=225621.95043968337
# Current iteration=350, loss=225585.61839903996
# Current iteration=375, loss=225567.46292493655
# Current iteration=400, loss=225558.38782026747
# Current iteration=425, loss=225553.85093379262
# Current iteration=450, loss=225551.58265843662
# Current iteration=475, loss=225550.44856187815
# Current iteration=500, loss=225549.88152387863
# Current iteration=525, loss=225549.5980074488
# Current iteration=550, loss=225549.4562498763
# Current iteration=575, loss=225549.3853712507
# Current iteration=600, loss=225549.34993197804
# Current iteration=625, loss=225549.33221235173
# Current iteration=650, loss=225549.3233525411
# Current iteration=675, loss=225549.3189226364
# Current iteration=700, loss=225549.31670768413
# Current iteration=725, loss=225549.315600208
# Current iteration=750, loss=225549.31504647018
# Current iteration=775, loss=225549.31476960122
# Current iteration=800, loss=225549.3146311666
# Current iteration=825, loss=225549.31456194934
# Current iteration=850, loss=225549.31452734052
# Current iteration=875, loss=225549.3145100364
# Current iteration=900, loss=225549.31450138424
# Current iteration=925, loss=225549.31449705822
# Current iteration=950, loss=225549.31449489522
# Current iteration=975, loss=225549.31449381355
# Current iteration=0, loss=21102687.26886801
# Current iteration=25, loss=1128602.4666613797
# Current iteration=50, loss=1098560.0001722218
# Current iteration=75, loss=312628.42498332425
# Current iteration=100, loss=287851.81187641376
# Current iteration=125, loss=252904.18107935885
# Current iteration=150, loss=239773.36200148315
# Current iteration=175, loss=234057.72557554935
# Current iteration=200, loss=231395.39886738107
# Current iteration=225, loss=230111.4315700286
# Current iteration=250, loss=229481.0048255013
# Current iteration=275, loss=229168.64939147022
# Current iteration=300, loss=229013.1775856209
# Current iteration=325, loss=228935.6180137393
# Current iteration=350, loss=228896.88285129523
# Current iteration=375, loss=228877.52624899452
# Current iteration=400, loss=228867.85068629443
# Current iteration=425, loss=228863.01368769683
# Current iteration=450, loss=228860.5953633007
# Current iteration=475, loss=228859.38624380322
# Current iteration=500, loss=228858.7816947294
# Current iteration=525, loss=228858.47942286127
# Current iteration=550, loss=228858.3282875943
# Current iteration=575, loss=228858.25272012764
# Current iteration=600, loss=228858.21493643604
# Current iteration=625, loss=228858.19604460063
# Current iteration=650, loss=228858.1865986856
# Current iteration=675, loss=228858.18187572865
# Current iteration=700, loss=228858.1795142504
# Current iteration=725, loss=228858.17833351143
# Current iteration=750, loss=228858.17774314183
# Current iteration=775, loss=228858.17744795696
# Current iteration=800, loss=228858.17730036456
# Current iteration=825, loss=228858.1772265683
# Current iteration=850, loss=228858.1771896702
# Current iteration=875, loss=228858.17717122126
# Current iteration=900, loss=228858.17716199666
# Current iteration=925, loss=228858.17715738446
# Current iteration=950, loss=228858.1771550784
# Current iteration=975, loss=228858.17715392532
# Current iteration=0, loss=21012087.34643211
# Current iteration=25, loss=1282689.7971079694
# Current iteration=50, loss=1094057.4132156784
# Current iteration=75, loss=313052.6531997637
# Current iteration=100, loss=292075.49781628506
# Current iteration=125, loss=256707.8657177455
# Current iteration=150, loss=243136.54775860184
# Current iteration=175, loss=237192.53545949215
# Current iteration=200, loss=234415.10141843997
# Current iteration=225, loss=233073.36889258947
# Current iteration=250, loss=232414.0086282706
# Current iteration=275, loss=232087.1761603824
# Current iteration=300, loss=231924.47859141772
# Current iteration=325, loss=231843.30985818015
# Current iteration=350, loss=231802.77078410579
# Current iteration=375, loss=231782.512536966
# Current iteration=400, loss=231772.38628181975
# Current iteration=425, loss=231767.3238505129
# Current iteration=450, loss=231764.79282390748
# Current iteration=475, loss=231763.52735770604
# Current iteration=500, loss=231762.89463840693
# Current iteration=525, loss=231762.57828142648
# Current iteration=550, loss=231762.42010360354
# Current iteration=575, loss=231762.34101485886
# Current iteration=600, loss=231762.30147052824
# Current iteration=625, loss=231762.28169837338
# Current iteration=650, loss=231762.27181229848
# Current iteration=675, loss=231762.2668692616
# Current iteration=700, loss=231762.26439774348
# Current iteration=725, loss=231762.26316198424
# Current iteration=750, loss=231762.26254410497
# Current iteration=775, loss=231762.2622351651
# Current iteration=800, loss=231762.26208069507
# Current iteration=825, loss=231762.26200346023
# Current iteration=850, loss=231762.26196484285
# Current iteration=875, loss=231762.2619455342
# Current iteration=900, loss=231762.26193587968
# Current iteration=925, loss=231762.26193105258
# Current iteration=950, loss=231762.26192863882
# Current iteration=975, loss=231762.261927432
# Current iteration=0, loss=21017318.101867527
# Current iteration=25, loss=1036664.2844215613
# Current iteration=50, loss=2122533.8056416414
# Current iteration=75, loss=609418.0534139272
# Current iteration=100, loss=283824.7860828615
# Current iteration=125, loss=250593.74052887404
# Current iteration=150, loss=238054.72187553937
# Current iteration=175, loss=232568.95169455188
# Current iteration=200, loss=230007.45550835534
# Current iteration=225, loss=228770.5058049235
# Current iteration=250, loss=228162.83100321912
# Current iteration=275, loss=227861.67704107802
# Current iteration=300, loss=227711.76891830357
# Current iteration=325, loss=227636.98005795665
# Current iteration=350, loss=227599.62651069235
# Current iteration=375, loss=227580.96019675324
# Current iteration=400, loss=227571.62959487882
# Current iteration=425, loss=227566.96493152494
# Current iteration=450, loss=227564.63275923318
# Current iteration=475, loss=227563.46671293234
# Current iteration=500, loss=227562.88369974302
# Current iteration=525, loss=227562.59219563866
# Current iteration=550, loss=227562.44644420894
# Current iteration=575, loss=227562.37356864978
# Current iteration=600, loss=227562.33713090912
# Current iteration=625, loss=227562.31891204847
# Current iteration=650, loss=227562.3098026206
# Current iteration=675, loss=227562.3052479072
# Current iteration=700, loss=227562.30297055072
# Current iteration=725, loss=227562.30183187258
# Current iteration=750, loss=227562.3012625334
# Current iteration=775, loss=227562.30097786404
# Current iteration=800, loss=227562.30083552928
# Current iteration=825, loss=227562.30076436195
# Current iteration=850, loss=227562.30072877818
# Current iteration=875, loss=227562.30071098625
# Current iteration=900, loss=227562.30070209052
# Current iteration=925, loss=227562.3006976426
# Current iteration=950, loss=227562.30069541847
# Current iteration=975, loss=227562.3006943065
# Current iteration=0, loss=21012836.78397008
# Current iteration=25, loss=893065.699244907
# Current iteration=50, loss=524309.7918368854
# Current iteration=75, loss=761853.3601023903
# Current iteration=100, loss=274106.37605157064
# Current iteration=125, loss=242511.94621621555
# Current iteration=150, loss=230870.74769149823
# Current iteration=175, loss=225860.36654837552
# Current iteration=200, loss=223538.28406683623
# Current iteration=225, loss=222421.04333825954
# Current iteration=250, loss=221873.11589742117
# Current iteration=275, loss=221601.79731049307
# Current iteration=300, loss=221466.79323423113
# Current iteration=325, loss=221399.4541712645
# Current iteration=350, loss=221365.8252383871
# Current iteration=375, loss=221349.0208762222
# Current iteration=400, loss=221340.62122033906
# Current iteration=425, loss=221336.4220235887
# Current iteration=450, loss=221334.32258299773
# Current iteration=475, loss=221333.2729021467
# Current iteration=500, loss=221332.74807249295
# Current iteration=525, loss=221332.48566105086
# Current iteration=550, loss=221332.35445594598
# Current iteration=575, loss=221332.2888535477
# Current iteration=600, loss=221332.25605238703
# Current iteration=625, loss=221332.2396518164
# Current iteration=650, loss=221332.23145153341
# Current iteration=675, loss=221332.22735139247
# Current iteration=700, loss=221332.2253013222
# Current iteration=725, loss=221332.22427628707
# Current iteration=750, loss=221332.22376376964
# Current iteration=775, loss=221332.22350751096
# Current iteration=800, loss=221332.2233793815
# Current iteration=825, loss=221332.22331531666
# Current iteration=850, loss=221332.2232832844
# Current iteration=875, loss=221332.22326726824
# Current iteration=900, loss=221332.22325925995
# Current iteration=925, loss=221332.2232552558
# Current iteration=950, loss=221332.22325325382
# Current iteration=975, loss=221332.22325225302
# Current iteration=0, loss=21043424.783907864
# Current iteration=25, loss=1027430.8880260428
# Current iteration=50, loss=1597189.61753959
# Current iteration=75, loss=864400.4940800943
# Current iteration=100, loss=280506.0984003338
# Current iteration=125, loss=247117.571488738
# Current iteration=150, loss=234744.1256894419
# Current iteration=175, loss=229402.05034779877
# Current iteration=200, loss=226922.79639500455
# Current iteration=225, loss=225729.16152863204
# Current iteration=250, loss=225143.5874594977
# Current iteration=275, loss=224853.57732815508
# Current iteration=300, loss=224709.26186260328
# Current iteration=325, loss=224637.2762977498
# Current iteration=350, loss=224601.32667639232
# Current iteration=375, loss=224583.36266574005
# Current iteration=400, loss=224574.38331184754
# Current iteration=425, loss=224569.89429765055
# Current iteration=450, loss=224567.64995622568
# Current iteration=475, loss=224566.52782692993
# Current iteration=500, loss=224565.966772636
# Current iteration=525, loss=224565.6862480775
# Current iteration=550, loss=224565.54598644545
# Current iteration=575, loss=224565.47585579116
# Current iteration=600, loss=224565.4407905044
# Current iteration=625, loss=224565.42325787115
# Current iteration=650, loss=224565.41449155708
# Current iteration=675, loss=224565.4101084007
# Current iteration=700, loss=224565.40791682256
# Current iteration=725, loss=224565.40682103354
# Current iteration=750, loss=224565.406273139
# Current iteration=775, loss=224565.40599919177
# Current iteration=800, loss=224565.4058622182
# Current iteration=825, loss=224565.4057937314
# Current iteration=850, loss=224565.40575948806
# Current iteration=875, loss=224565.4057423663
# Current iteration=900, loss=224565.40573380538
# Current iteration=925, loss=224565.405729525
# Current iteration=950, loss=224565.40572738473
# Current iteration=975, loss=224565.40572631467
# Current iteration=0, loss=21104880.539683636
# Current iteration=25, loss=1152912.9915102685
# Current iteration=50, loss=1098182.1718311352
# Current iteration=75, loss=330469.16462293867
# Current iteration=100, loss=289860.5869045932
# Current iteration=125, loss=254256.89693830552
# Current iteration=150, loss=240843.027815697
# Current iteration=175, loss=235008.00101898256
# Current iteration=200, loss=232290.37203769566
# Current iteration=225, loss=230979.70985271398
# Current iteration=250, loss=230336.1804341557
# Current iteration=275, loss=230017.3446410167
# Current iteration=300, loss=229858.65204758215
# Current iteration=325, loss=229779.48767255683
# Current iteration=350, loss=229739.95041509287
# Current iteration=375, loss=229720.19306906324
# Current iteration=400, loss=229710.31718521658
# Current iteration=425, loss=229705.37994048375
# Current iteration=450, loss=229702.91149240235
# Current iteration=475, loss=229701.6773119313
# Current iteration=500, loss=229701.06023258792
# Current iteration=525, loss=229700.7516956393
# Current iteration=550, loss=229700.59742784576
# Current iteration=575, loss=229700.52029411914
# Current iteration=600, loss=229700.48172729838
# Current iteration=625, loss=229700.46244389872
# Current iteration=650, loss=229700.45280220147
# Current iteration=675, loss=229700.44798135353
# Current iteration=700, loss=229700.44557092988
# Current iteration=725, loss=229700.44436571808
# Current iteration=750, loss=229700.44376311215
# Current iteration=775, loss=229700.44346180913
# Current iteration=800, loss=229700.44331115764
# Current iteration=825, loss=229700.44323583186
# Current iteration=850, loss=229700.4431981691
# Current iteration=875, loss=229700.44317933754
# Current iteration=900, loss=229700.4431699218
# Current iteration=925, loss=229700.44316521398
# Current iteration=950, loss=229700.4431628599
# Current iteration=975, loss=229700.4431616831
# Current iteration=0, loss=21014267.93713649
# Current iteration=25, loss=1287575.2280852657
# Current iteration=50, loss=1094753.2913933224
# Current iteration=75, loss=321571.8458297923
# Current iteration=100, loss=290559.825572406
# Current iteration=125, loss=255311.08239226998
# Current iteration=150, loss=241877.18071885474
# Current iteration=175, loss=236008.79526385543
# Current iteration=200, loss=233270.11608195718
# Current iteration=225, loss=231947.82895300782
# Current iteration=250, loss=231298.31720997975
# Current iteration=275, loss=230976.46043357448
# Current iteration=300, loss=230816.24223117155
# Current iteration=325, loss=230736.31061252282
# Current iteration=350, loss=230696.38867429813
# Current iteration=375, loss=230676.438659684
# Current iteration=400, loss=230666.46641067718
# Current iteration=425, loss=230661.48097594848
# Current iteration=450, loss=230658.98842966396
# Current iteration=475, loss=230657.7421992902
# Current iteration=500, loss=230657.11909479526
# Current iteration=525, loss=230656.80754522077
# Current iteration=550, loss=230656.65177110172
# Current iteration=575, loss=230656.57388420927
# Current iteration=600, loss=230656.5349408048
# Current iteration=625, loss=230656.51546911293
# Current iteration=650, loss=230656.50573326965
# Current iteration=675, loss=230656.5008653488
# Current iteration=700, loss=230656.49843138846
# Current iteration=725, loss=230656.49721440833
# Current iteration=750, loss=230656.49660591828
# Current iteration=775, loss=230656.49630167312
# Current iteration=800, loss=230656.49614955075
# Current iteration=825, loss=230656.4960734895
# Current iteration=850, loss=230656.49603545884
# Current iteration=875, loss=230656.49601644353
# Current iteration=900, loss=230656.4960069358
# Current iteration=925, loss=230656.49600218216
# Current iteration=950, loss=230656.49599980513
# Current iteration=975, loss=230656.49599861677
# Current iteration=0, loss=21019501.016559187
# Current iteration=25, loss=1088439.7562322668
# Current iteration=50, loss=914674.6881787912
# Current iteration=75, loss=347303.0074946
# Current iteration=100, loss=297002.638914679
# Current iteration=125, loss=260410.58009043324
# Current iteration=150, loss=246328.9212484235
# Current iteration=175, loss=240133.65012606292
# Current iteration=200, loss=237231.58239646754
# Current iteration=225, loss=235827.71449123535
# Current iteration=250, loss=235137.35209832428
# Current iteration=275, loss=234795.0627867434
# Current iteration=300, loss=234624.63555377352
# Current iteration=325, loss=234539.60126640755
# Current iteration=350, loss=234497.12843250742
# Current iteration=375, loss=234475.9030029098
# Current iteration=400, loss=234465.29303425524
# Current iteration=425, loss=234459.98873637736
# Current iteration=450, loss=234457.33675903987
# Current iteration=475, loss=234456.0108132703
# Current iteration=500, loss=234455.34785110984
# Current iteration=525, loss=234455.01637271087
# Current iteration=550, loss=234454.85063418164
# Current iteration=575, loss=234454.76776508454
# Current iteration=600, loss=234454.72633057798
# Current iteration=625, loss=234454.7056133351
# Current iteration=650, loss=234454.69525471627
# Current iteration=675, loss=234454.69007540765
# Current iteration=700, loss=234454.6874857534
# Current iteration=725, loss=234454.68619092638
# Current iteration=750, loss=234454.68554351263
# Current iteration=775, loss=234454.68521980592
# Current iteration=800, loss=234454.6850579526
# Current iteration=825, loss=234454.6849770258
# Current iteration=850, loss=234454.68493656273
# Current iteration=875, loss=234454.6849163312
# Current iteration=900, loss=234454.68490621535
# Current iteration=925, loss=234454.68490115742
# Current iteration=950, loss=234454.68489862824
# Current iteration=975, loss=234454.6848973637
# Current iteration=0, loss=21015019.213378206
# Current iteration=25, loss=917019.4980259354
# Current iteration=50, loss=1592920.182747448
# Current iteration=75, loss=663172.7483401862
# Current iteration=100, loss=274819.58477252285
# Current iteration=125, loss=242873.10439821504
# Current iteration=150, loss=231162.971821844
# Current iteration=175, loss=226120.30982613983
# Current iteration=200, loss=223782.8475217492
# Current iteration=225, loss=222658.0131103315
# Current iteration=250, loss=222106.34701876817
# Current iteration=275, loss=221833.1730551267
# Current iteration=300, loss=221697.24536037858
# Current iteration=325, loss=221629.4449922966
# Current iteration=350, loss=221595.58571321316
# Current iteration=375, loss=221578.66641907813
# Current iteration=400, loss=221570.20934754965
# Current iteration=425, loss=221565.98145477113
# Current iteration=450, loss=221563.86766958307
# Current iteration=475, loss=221562.81081658823
# Current iteration=500, loss=221562.2823999904
# Current iteration=525, loss=221562.01819416633
# Current iteration=550, loss=221561.88609187308
# Current iteration=575, loss=221561.82004088102
# Current iteration=600, loss=221561.7870154238
# Current iteration=625, loss=221561.77050270472
# Current iteration=650, loss=221561.76224634767
# Current iteration=675, loss=221561.75811816973
# Current iteration=700, loss=221561.7560540808
# Current iteration=725, loss=221561.7550220365
# Current iteration=750, loss=221561.7545060143
# Current iteration=775, loss=221561.7542480031
# Current iteration=800, loss=221561.75411899755
# Current iteration=825, loss=221561.7540544947
# Current iteration=850, loss=221561.75402224352
# Current iteration=875, loss=221561.75400611793
# Current iteration=900, loss=221561.75399805498
# Current iteration=925, loss=221561.7539940235
# Current iteration=950, loss=221561.75399200773
# Current iteration=975, loss=221561.7539909998
# Current iteration=0, loss=21045612.334928405
# Current iteration=25, loss=1047940.4443195397
# Current iteration=50, loss=2352407.6918475768
# Current iteration=75, loss=365831.49509603466
# Current iteration=100, loss=280554.9186309311
# Current iteration=125, loss=246107.0652735717
# Current iteration=150, loss=234004.0384222237
# Current iteration=175, loss=228755.0305788752
# Current iteration=200, loss=226315.03564593886
# Current iteration=225, loss=225139.551540207
# Current iteration=250, loss=224562.68021207058
# Current iteration=275, loss=224276.95597162878
# Current iteration=300, loss=224134.7637841486
# Current iteration=325, loss=224063.83523371516
# Current iteration=350, loss=224028.41273223763
# Current iteration=375, loss=224010.71196642355
# Current iteration=400, loss=224001.86437398967
# Current iteration=425, loss=223997.44124693723
# Current iteration=450, loss=223995.22984658665
# Current iteration=475, loss=223994.12418664896
# Current iteration=500, loss=223993.57136673934
# Current iteration=525, loss=223993.2949592993
# Current iteration=550, loss=223993.15675620796
# Current iteration=575, loss=223993.08765481948
# Current iteration=600, loss=223993.05310416454
# Current iteration=625, loss=223993.03582884689
# Current iteration=650, loss=223993.0271911905
# Current iteration=675, loss=223993.022872363
# Current iteration=700, loss=223993.02071294928
# Current iteration=725, loss=223993.01963324254
# Current iteration=750, loss=223993.01909338927
# Current iteration=775, loss=223993.01882346274
# Current iteration=800, loss=223993.01868849917
# Current iteration=825, loss=223993.0186210174
# Current iteration=850, loss=223993.01858727646
# Current iteration=875, loss=223993.0185704062
# Current iteration=900, loss=223993.0185619709
# Current iteration=925, loss=223993.01855775333
# Current iteration=950, loss=223993.01855564452
# Current iteration=975, loss=223993.0185545902
# Current iteration=0, loss=21107073.968313716
# Current iteration=25, loss=1177179.0550257917
# Current iteration=50, loss=1091042.9149904412
# Current iteration=75, loss=333926.32593866036
# Current iteration=100, loss=290027.8932099498
# Current iteration=125, loss=254284.41335795252
# Current iteration=150, loss=240829.4105028256
# Current iteration=175, loss=234979.84437970218
# Current iteration=200, loss=232256.11590121142
# Current iteration=225, loss=230942.65846631088
# Current iteration=250, loss=230297.78816358102
# Current iteration=275, loss=229978.3024322391
# Current iteration=300, loss=229819.28759128458
# Current iteration=325, loss=229739.96127417605
# Current iteration=350, loss=229700.34333530584
# Current iteration=375, loss=229680.54577087038
# Current iteration=400, loss=229670.64979209207
# Current iteration=425, loss=229665.7025034598
# Current iteration=450, loss=229663.22903432001
# Current iteration=475, loss=229661.9923435426
# Current iteration=500, loss=229661.37400910183
# Current iteration=525, loss=229661.06484461838
# Current iteration=550, loss=229660.91026306088
# Current iteration=575, loss=229660.83297245318
# Current iteration=600, loss=229660.79432719207
# Current iteration=625, loss=229660.77500457226
# Current iteration=650, loss=229660.76534326508
# Current iteration=675, loss=229660.76051261197
# Current iteration=700, loss=229660.75809728546
# Current iteration=725, loss=229660.75688962254
# Current iteration=750, loss=229660.75628579085
# Current iteration=775, loss=229660.75598387505
# Current iteration=800, loss=229660.75583291732
# Current iteration=825, loss=229660.7557574383
# Current iteration=850, loss=229660.75571969888
# Current iteration=875, loss=229660.7557008292
# Current iteration=900, loss=229660.75569139412
# Current iteration=925, loss=229660.75568667683
# Current iteration=950, loss=229660.75568431808
# Current iteration=975, loss=229660.7556831388
# Current iteration=0, loss=21016448.684954472
# Current iteration=25, loss=1289321.6918289184
# Current iteration=50, loss=1092597.842812636
# Current iteration=75, loss=308267.1586115112
# Current iteration=100, loss=292020.46232928085
# Current iteration=125, loss=249957.30474437284
# Current iteration=150, loss=237433.46947432967
# Current iteration=175, loss=231966.30981468727
# Current iteration=200, loss=229417.75073115955
# Current iteration=225, loss=228188.04695811874
# Current iteration=250, loss=227584.13505750534
# Current iteration=275, loss=227284.90289281768
# Current iteration=300, loss=227135.96050985996
# Current iteration=325, loss=227061.65878768123
# Current iteration=350, loss=227024.55005679812
# Current iteration=375, loss=227006.00608732906
# Current iteration=400, loss=226996.73669680176
# Current iteration=425, loss=226992.10265000229
# Current iteration=450, loss=226989.78578870764
# Current iteration=475, loss=226988.6273985852
# Current iteration=500, loss=226988.04821365504
# Current iteration=525, loss=226987.7586237227
# Current iteration=550, loss=226987.61382938977
# Current iteration=575, loss=226987.54143238152
# Current iteration=600, loss=226987.50523391704
# Current iteration=625, loss=226987.48713469467
# Current iteration=650, loss=226987.478085086
# Current iteration=675, loss=226987.4735602821
# Current iteration=700, loss=226987.4712978804
# Current iteration=725, loss=226987.47016667956
# Current iteration=750, loss=226987.46960107918
# Current iteration=775, loss=226987.469318279
# Current iteration=800, loss=226987.46917687883
# Current iteration=825, loss=226987.46910617873
# Current iteration=850, loss=226987.4690708286
# Current iteration=875, loss=226987.46905315373
# Current iteration=900, loss=226987.4690443163
# Current iteration=925, loss=226987.46903989764
# Current iteration=950, loss=226987.4690376882
# Current iteration=975, loss=226987.46903658356
# Current iteration=0, loss=21021684.088279326
# Current iteration=25, loss=1139945.9537870793
# Current iteration=50, loss=994519.5888594592
# Current iteration=75, loss=340141.46515375294
# Current iteration=100, loss=296329.4178135802
# Current iteration=125, loss=259964.77528960345
# Current iteration=150, loss=245965.55035124355
# Current iteration=175, loss=239806.52379928707
# Current iteration=200, loss=236921.6166906359
# Current iteration=225, loss=235526.01455712834
# Current iteration=250, loss=234839.77737765564
# Current iteration=275, loss=234499.54452297857
# Current iteration=300, loss=234330.13879013632
# Current iteration=325, loss=234245.61387741443
# Current iteration=350, loss=234203.39554915548
# Current iteration=375, loss=234182.29734876126
# Current iteration=400, loss=234171.75098402487
# Current iteration=425, loss=234166.47848478262
# Current iteration=450, loss=234163.84240593223
# Current iteration=475, loss=234162.5244091984
# Current iteration=500, loss=234161.86542150413
# Current iteration=525, loss=234161.53593032516
# Current iteration=550, loss=234161.37118540268
# Current iteration=575, loss=234161.28881310823
# Current iteration=600, loss=234161.24762700265
# Current iteration=625, loss=234161.2270339603
# Current iteration=650, loss=234161.21673744178
# Current iteration=675, loss=234161.21158918313
# Current iteration=700, loss=234161.2090150541
# Current iteration=725, loss=234161.2077279897
# Current iteration=750, loss=234161.20708445742
# Current iteration=775, loss=234161.2067626913
# Current iteration=800, loss=234161.20660180837
# Current iteration=825, loss=234161.20652136655
# Current iteration=850, loss=234161.20648114596
# Current iteration=875, loss=234161.20646103533
# Current iteration=900, loss=234161.20645098033
# Current iteration=925, loss=234161.2064459525
# Current iteration=950, loss=234161.20644343866
# Current iteration=975, loss=234161.20644218154
# Current iteration=0, loss=21017201.800154023
# Current iteration=25, loss=944174.66170611
# Current iteration=50, loss=740349.8398698394
# Current iteration=75, loss=321244.8643771534
# Current iteration=100, loss=276873.2559184693
# Current iteration=125, loss=244372.34218047172
# Current iteration=150, loss=232407.58708403094
# Current iteration=175, loss=227240.56564530428
# Current iteration=200, loss=224842.66387186022
# Current iteration=225, loss=223688.12911354625
# Current iteration=250, loss=223121.71977145266
# Current iteration=275, loss=222841.1985053278
# Current iteration=300, loss=222701.6101700834
# Current iteration=325, loss=222631.98162739538
# Current iteration=350, loss=222597.20892488613
# Current iteration=375, loss=222579.83293335553
# Current iteration=400, loss=222571.1475180334
# Current iteration=425, loss=222566.80548668528
# Current iteration=450, loss=222564.63464076977
# Current iteration=475, loss=222563.54925792414
# Current iteration=500, loss=222563.00657652924
# Current iteration=525, loss=222562.7352383387
# Current iteration=550, loss=222562.5995698702
# Current iteration=575, loss=222562.53173579252
# Current iteration=600, loss=222562.49781879294
# Current iteration=625, loss=222562.4808603437
# Current iteration=650, loss=222562.47238117372
# Current iteration=675, loss=222562.46814158923
# Current iteration=700, loss=222562.46602179718
# Current iteration=725, loss=222562.4649619011
# Current iteration=750, loss=222562.4644319532
# Current iteration=775, loss=222562.4641669791
# Current iteration=800, loss=222562.46403449206
# Current iteration=825, loss=222562.46396824875
# Current iteration=850, loss=222562.4639351271
# Current iteration=875, loss=222562.46391856644
# Current iteration=900, loss=222562.46391028576
# Current iteration=925, loss=222562.46390614565
# Current iteration=950, loss=222562.46390407553
# Current iteration=975, loss=222562.46390304054
# Current iteration=0, loss=21047800.043651223
# Current iteration=25, loss=1067847.7850286565
# Current iteration=50, loss=1159858.9723791608
# Current iteration=75, loss=775189.6071059004
# Current iteration=100, loss=279394.7968395126
# Current iteration=125, loss=245479.42427455282
# Current iteration=150, loss=233480.2427958093
# Current iteration=175, loss=228283.1865232802
# Current iteration=200, loss=225868.88455584898
# Current iteration=225, loss=224706.09600037598
# Current iteration=250, loss=224135.56284563002
# Current iteration=275, loss=223852.99784774738
# Current iteration=300, loss=223712.38300809634
# Current iteration=325, loss=223642.24210271018
# Current iteration=350, loss=223607.2132857511
# Current iteration=375, loss=223589.70915155078
# Current iteration=400, loss=223580.95965005527
# Current iteration=425, loss=223576.58554061045
# Current iteration=450, loss=223574.39864620147
# Current iteration=475, loss=223573.30523907382
# Current iteration=500, loss=223572.75854552898
# Current iteration=525, loss=223572.48520126133
# Current iteration=550, loss=223572.34852975365
# Current iteration=575, loss=223572.28019415637
# Current iteration=600, loss=223572.24602639687
# Current iteration=625, loss=223572.22894252688
# Current iteration=650, loss=223572.22040059435
# Current iteration=675, loss=223572.21612962868
# Current iteration=700, loss=223572.21399414618
# Current iteration=725, loss=223572.2129264046
# Current iteration=750, loss=223572.21239253404
# Current iteration=775, loss=223572.21212559877
# Current iteration=800, loss=223572.21199213108
# Current iteration=825, loss=223572.21192539742
# Current iteration=850, loss=223572.21189203035
# Current iteration=875, loss=223572.21187534693
# Current iteration=900, loss=223572.21186700513
# Current iteration=925, loss=223572.21186283432
# Current iteration=950, loss=223572.2118607489
# Current iteration=975, loss=223572.2118597061
# Current iteration=0, loss=21109267.554771047
# Current iteration=25, loss=1201802.798235999
# Current iteration=50, loss=1084152.6594788567
# Current iteration=75, loss=335098.60149950295
# Current iteration=100, loss=289718.149358041
# Current iteration=125, loss=253969.47791556988
# Current iteration=150, loss=240531.1467469291
# Current iteration=175, loss=234692.96051076613
# Current iteration=200, loss=231975.456037196
# Current iteration=225, loss=230665.23426844
# Current iteration=250, loss=230022.02620868877
# Current iteration=275, loss=229703.36343546267
# Current iteration=300, loss=229544.75888353153
# Current iteration=325, loss=229465.6375138326
# Current iteration=350, loss=229426.122232742
# Current iteration=375, loss=229406.37584736777
# Current iteration=400, loss=229396.505476152
# Current iteration=425, loss=229391.57099783252
# Current iteration=450, loss=229389.10393420854
# Current iteration=475, loss=229387.8704462789
# Current iteration=500, loss=229387.2537132844
# Current iteration=525, loss=229386.94534952973
# Current iteration=550, loss=229386.79116833804
# Current iteration=575, loss=229386.7140779136
# Current iteration=600, loss=229386.67553274424
# Current iteration=625, loss=229386.65626017016
# Current iteration=650, loss=229386.64662388587
# Current iteration=675, loss=229386.64180574438
# Current iteration=700, loss=229386.6393966738
# Current iteration=725, loss=229386.63819213846
# Current iteration=750, loss=229386.63758987095
# Current iteration=775, loss=229386.637288737
# Current iteration=800, loss=229386.63713816993
# Current iteration=825, loss=229386.6370628867
# Current iteration=850, loss=229386.63702524506
# Current iteration=875, loss=229386.63700642428
# Current iteration=900, loss=229386.63699701376
# Current iteration=925, loss=229386.63699230843
# Current iteration=950, loss=229386.63698995576
# Current iteration=975, loss=229386.63698877947
# Current iteration=0, loss=21018629.58989886
# Current iteration=25, loss=1287725.9628771509
# Current iteration=50, loss=1088456.3334063275
# Current iteration=75, loss=611605.6497439836
# Current iteration=100, loss=280663.81250473706
# Current iteration=125, loss=248625.2981293137
# Current iteration=150, loss=236243.53914277075
# Current iteration=175, loss=230852.30326830075
# Current iteration=200, loss=228342.25502730647
# Current iteration=225, loss=227131.8209656674
# Current iteration=250, loss=226537.5663598473
# Current iteration=275, loss=226243.1483446928
# Current iteration=300, loss=226096.61251698475
# Current iteration=325, loss=226023.51484166156
# Current iteration=350, loss=225987.0078977391
# Current iteration=375, loss=225968.7648275627
# Current iteration=400, loss=225959.64595116553
# Current iteration=425, loss=225955.08716840213
# Current iteration=450, loss=225952.80793906347
# Current iteration=475, loss=225951.66836490345
# Current iteration=500, loss=225951.09858795066
# Current iteration=525, loss=225950.81370200592
# Current iteration=550, loss=225950.67125966653
# Current iteration=575, loss=225950.60003865501
# Current iteration=600, loss=225950.56442818893
# Current iteration=625, loss=225950.5466229657
# Current iteration=650, loss=225950.5377203566
# Current iteration=675, loss=225950.53326905274
# Current iteration=700, loss=225950.53104340084
# Current iteration=725, loss=225950.52993057496
# Current iteration=750, loss=225950.52937416203
# Current iteration=775, loss=225950.5290959555
# Current iteration=800, loss=225950.5289568524
# Current iteration=825, loss=225950.52888730096
# Current iteration=850, loss=225950.52885252502
# Current iteration=875, loss=225950.52883513705
# Current iteration=900, loss=225950.52882644313
# Current iteration=925, loss=225950.52882209624
# Current iteration=950, loss=225950.52881992265
# Current iteration=975, loss=225950.52881883585
# Current iteration=0, loss=21023867.31704074
# Current iteration=25, loss=1190079.7859229497
# Current iteration=50, loss=1010967.9801311047
# Current iteration=75, loss=332790.4872550642
# Current iteration=100, loss=295829.2700517624
# Current iteration=125, loss=259720.96319076352
# Current iteration=150, loss=245783.63003014942
# Current iteration=175, loss=239647.48660488185
# Current iteration=200, loss=236772.64927968234
# Current iteration=225, loss=235381.79738212752
# Current iteration=250, loss=234697.88938333665
# Current iteration=275, loss=234358.78627678144
# Current iteration=300, loss=234189.93951387706
# Current iteration=325, loss=234105.69299345513
# Current iteration=350, loss=234063.61360170005
# Current iteration=375, loss=234042.58493812766
# Current iteration=400, loss=234032.0733367581
# Current iteration=425, loss=234026.81821546462
# Current iteration=450, loss=234024.19082465526
# Current iteration=475, loss=234022.87717170862
# Current iteration=500, loss=234022.22035584965
# Current iteration=525, loss=234021.8919505737
# Current iteration=550, loss=234021.7277485991
# Current iteration=575, loss=234021.6456477776
# Current iteration=600, loss=234021.60459740835
# Current iteration=625, loss=234021.58407223414
# Current iteration=650, loss=234021.57380964962
# Current iteration=675, loss=234021.56867835796
# Current iteration=700, loss=234021.56611271226
# Current iteration=725, loss=234021.56482988945
# Current iteration=750, loss=234021.56418847808
# Current iteration=775, loss=234021.56386777238
# Current iteration=800, loss=234021.56370741973
# Current iteration=825, loss=234021.56362724342
# Current iteration=850, loss=234021.56358715505
# Current iteration=875, loss=234021.56356711104
# Current iteration=900, loss=234021.56355708872
# Current iteration=925, loss=234021.5635520779
# Current iteration=950, loss=234021.56354957222
# Current iteration=975, loss=234021.56354831965
# Current iteration=0, loss=21019384.54431033
# Current iteration=25, loss=973559.6678353193
# Current iteration=50, loss=645583.7329737426
# Current iteration=75, loss=713202.5018276104
# Current iteration=100, loss=282296.8077520264
# Current iteration=125, loss=248495.00703879417
# Current iteration=150, loss=235886.5497336879
# Current iteration=175, loss=230414.9312251585
# Current iteration=200, loss=227869.27374902426
# Current iteration=225, loss=226642.08950878927
# Current iteration=250, loss=226039.68229337045
# Current iteration=275, loss=225741.27390653573
# Current iteration=300, loss=225592.76221995044
# Current iteration=325, loss=225518.6766059907
# Current iteration=350, loss=225481.67719739024
# Current iteration=375, loss=225463.18811411943
# Current iteration=400, loss=225453.94621817212
# Current iteration=425, loss=225449.32593152023
# Current iteration=450, loss=225447.01595351225
# Current iteration=475, loss=225445.86100583622
# Current iteration=500, loss=225445.28354232994
# Current iteration=525, loss=225444.99481315975
# Current iteration=550, loss=225444.85044922028
# Current iteration=575, loss=225444.77826741207
# Current iteration=600, loss=225444.7421765483
# Current iteration=625, loss=225444.72413112654
# Current iteration=650, loss=225444.71510841826
# Current iteration=675, loss=225444.71059706467
# Current iteration=700, loss=225444.70834138797
# Current iteration=725, loss=225444.70721354964
# Current iteration=750, loss=225444.7066496307
# Current iteration=775, loss=225444.7063676711
# Current iteration=800, loss=225444.70622669123
# Current iteration=825, loss=225444.70615620137
# Current iteration=850, loss=225444.70612095643
# Current iteration=875, loss=225444.70610333397
# Current iteration=900, loss=225444.7060945226
# Current iteration=925, loss=225444.70609011693
# Current iteration=950, loss=225444.7060879143
# Current iteration=975, loss=225444.70608681295
# [0.75]

# %%
print(np.logspace(-2,0,5))

# %%
# degrees = np.arange(2, 5)
lambdas = np.linspace(0, 3, 5)
degree = 2
# gammas = np.logspace(-5, 0, 5)
k_fold = 5
gamma = 0.00316228
seed = 1
training_loss = np.zeros(len(lambdas))
testing_loss = np.zeros(len(lambdas))
k_indices = build_k_indices(y_1, k_fold, seed)
for index1 in range(len(lambdas)):
    # for index2 in range(len(degrees)):
    #  for index3 in range(len(gammas)):
    train_loss = 0
    test_loss = 0
    for k in range(k_fold):
        loss_tr, loss_te = cross_validation_logistic(y_1, tX_tilda_1, k_indices, k,
                                            lambdas[index1], degree, gamma)
        train_loss += loss_tr
        test_loss += loss_te
    training_loss[index1] = train_loss / k_fold
    testing_loss[index1] = test_loss / k_fold
best_result = np.where(testing_loss == np.amin(testing_loss))
lambda_opt = lambdas[best_result[0]]
print(lambda_opt)
# Out:
# Current iteration=0, loss=273267123.61131126
# Current iteration=25, loss=44125887.461864695
# Current iteration=50, loss=17506863.1337279
# Current iteration=75, loss=3981775.879560408
# Current iteration=100, loss=3994052.851587348
# Current iteration=125, loss=3410118.594701222
# Current iteration=150, loss=3159312.6756089884
# Current iteration=175, loss=3040971.936198583
# Current iteration=200, loss=2983261.4529766627
# Current iteration=225, loss=2954763.6332311025
# Current iteration=250, loss=2940605.1364359437
# Current iteration=275, loss=2933548.7571841036
# Current iteration=300, loss=2930026.2143532108
# Current iteration=325, loss=2928266.3711855
# Current iteration=350, loss=2927386.791871916
# Current iteration=375, loss=2926947.0865175594
# Current iteration=400, loss=2926727.2550107967
# Current iteration=425, loss=2926617.345234049
# Current iteration=450, loss=2926562.3916626503
# Current iteration=475, loss=2926534.9152061883
# Current iteration=500, loss=2926521.177060268
# Current iteration=525, loss=2926514.3080078852
# Current iteration=550, loss=2926510.873486837
# Current iteration=575, loss=2926509.1562276008
# Current iteration=600, loss=2926508.2975983033
# Current iteration=625, loss=2926507.868283735
# Current iteration=650, loss=2926507.6536264694
# Current iteration=675, loss=2926507.5462978445
# Current iteration=700, loss=2926507.4926335313
# Current iteration=725, loss=2926507.465801377
# Current iteration=750, loss=2926507.4523852947
# Current iteration=775, loss=2926507.4456772585
# Current iteration=800, loss=2926507.4423232377
# Current iteration=825, loss=2926507.4406462302
# Current iteration=850, loss=2926507.4398077247
# Current iteration=875, loss=2926507.439388471
# Current iteration=900, loss=2926507.439178847
# Current iteration=925, loss=2926507.4390740325
# Current iteration=950, loss=2926507.4390216274
# Current iteration=975, loss=2926507.4389954256
# Current iteration=0, loss=273003052.6044182
# Current iteration=25, loss=44032292.212854885
# Current iteration=50, loss=6533811.953139507
# Current iteration=75, loss=12479374.840386964
# Current iteration=100, loss=3952051.7393671516
# Current iteration=125, loss=3373527.080606584
# Current iteration=150, loss=3126041.0991934957
# Current iteration=175, loss=3009262.773942491
# Current iteration=200, loss=2952457.5603588424
# Current iteration=225, loss=2924416.721806349
# Current iteration=250, loss=2910483.1935772183
# Current iteration=275, loss=2903537.4492971506
# Current iteration=300, loss=2900069.691614612
# Current iteration=325, loss=2898337.1175006162
# Current iteration=350, loss=2897471.155868321
# Current iteration=375, loss=2897038.2521515624
# Current iteration=400, loss=2896821.8194631417
# Current iteration=425, loss=2896713.6084338897
# Current iteration=450, loss=2896659.5042584417
# Current iteration=475, loss=2896632.4524700996
# Current iteration=500, loss=2896618.926650772
# Current iteration=525, loss=2896612.163759818
# Current iteration=550, loss=2896608.7823190177
# Current iteration=575, loss=2896607.091599788
# Current iteration=600, loss=2896606.246240464
# Current iteration=625, loss=2896605.823560877
# Current iteration=650, loss=2896605.6122211018
# Current iteration=675, loss=2896605.506551218
# Current iteration=700, loss=2896605.453716281
# Current iteration=725, loss=2896605.427298808
# Current iteration=750, loss=2896605.4140900704
# Current iteration=775, loss=2896605.4074857067
# Current iteration=800, loss=2896605.4041835195
# Current iteration=825, loss=2896605.4025324294
# Current iteration=850, loss=2896605.4017068846
# Current iteration=875, loss=2896605.4012941113
# Current iteration=900, loss=2896605.401087724
# Current iteration=925, loss=2896605.4009845327
# Current iteration=950, loss=2896605.4009329355
# Current iteration=975, loss=2896605.4009071374
# Current iteration=0, loss=273054126.6061992
# Current iteration=25, loss=43995755.834741555
# Current iteration=50, loss=6427927.014415575
# Current iteration=75, loss=11725933.599935982
# Current iteration=100, loss=4118473.0514785955
# Current iteration=125, loss=3483484.64174774
# Current iteration=150, loss=3217487.66447796
# Current iteration=175, loss=3094183.797989743
# Current iteration=200, loss=3034482.506992103
# Current iteration=225, loss=3005040.336479722
# Current iteration=250, loss=2990412.8186830385
# Current iteration=275, loss=2983121.7857234315
# Current iteration=300, loss=2979481.865003723
# Current iteration=325, loss=2977663.285057998
# Current iteration=350, loss=2976754.341541656
# Current iteration=375, loss=2976299.964700261
# Current iteration=400, loss=2976072.79709379
# Current iteration=425, loss=2975959.218839239
# Current iteration=450, loss=2975902.431716004
# Current iteration=475, loss=2975874.03847925
# Current iteration=500, loss=2975859.8419420877
# Current iteration=525, loss=2975852.743693809
# Current iteration=550, loss=2975849.194574747
# Current iteration=575, loss=2975847.420016483
# Current iteration=600, loss=2975846.5327376686
# Current iteration=625, loss=2975846.0890983413
# Current iteration=650, loss=2975845.8672786998
# Current iteration=675, loss=2975845.756368884
# Current iteration=700, loss=2975845.700913976
# Current iteration=725, loss=2975845.6731865234
# Current iteration=750, loss=2975845.6593227964
# Current iteration=775, loss=2975845.6523909313
# Current iteration=800, loss=2975845.648925
# Current iteration=825, loss=2975845.6471920367
# Current iteration=850, loss=2975845.646325549
# Current iteration=875, loss=2975845.6458923114
# Current iteration=900, loss=2975845.645675687
# Current iteration=925, loss=2975845.6455673757
# Current iteration=950, loss=2975845.6455132226
# Current iteration=975, loss=2975845.6454861467
# Current iteration=0, loss=273435438.2927917
# Current iteration=25, loss=44591082.130768895
# Current iteration=50, loss=6561143.321550809
# Current iteration=75, loss=10779053.635736503
# Current iteration=100, loss=4230785.6030218145
# Current iteration=125, loss=3593597.743579013
# Current iteration=150, loss=3324546.1021150253
# Current iteration=175, loss=3199902.000328279
# Current iteration=200, loss=3139735.143771701
# Current iteration=225, loss=3110121.1962468815
# Current iteration=250, loss=3095424.577792917
# Current iteration=275, loss=3088103.0870607113
# Current iteration=300, loss=3084448.8565989444
# Current iteration=325, loss=3082623.3657056736
# Current iteration=350, loss=3081711.0219408725
# Current iteration=375, loss=3081254.9512640033
# Current iteration=400, loss=3081026.942611285
# Current iteration=425, loss=3080912.946370741
# Current iteration=450, loss=3080855.950072556
# Current iteration=475, loss=3080827.4523106203
# Current iteration=500, loss=3080813.2035264354
# Current iteration=525, loss=3080806.079158538
# Current iteration=550, loss=3080802.5169806373
# Current iteration=575, loss=3080800.735893201
# Current iteration=600, loss=3080799.84534986
# Current iteration=625, loss=3080799.4000782836
# Current iteration=650, loss=3080799.1774425213
# Current iteration=675, loss=3080799.0661246465
# Current iteration=700, loss=3080799.0104657044
# Current iteration=725, loss=3080798.982636241
# Current iteration=750, loss=3080798.968721505
# Current iteration=775, loss=3080798.9617641405
# Current iteration=800, loss=3080798.9582854556
# Current iteration=825, loss=3080798.956546111
# Current iteration=850, loss=3080798.9556764415
# Current iteration=875, loss=3080798.9552416042
# Current iteration=900, loss=3080798.955024189
# Current iteration=925, loss=3080798.9549154807
# Current iteration=950, loss=3080798.9548611217
# Current iteration=975, loss=3080798.954833945
# Current iteration=0, loss=274058556.4440166
# Current iteration=25, loss=44510503.426922165
# Current iteration=50, loss=6478417.408775408
# Current iteration=75, loss=13314134.206484886
# Current iteration=100, loss=4034212.788181355
# Current iteration=125, loss=3424759.9258127734
# Current iteration=150, loss=3166902.2699575596
# Current iteration=175, loss=3046201.9661511397
# Current iteration=200, loss=2987476.309674669
# Current iteration=225, loss=2958512.6195238316
# Current iteration=250, loss=2944132.964365251
# Current iteration=275, loss=2936968.8182060854
# Current iteration=300, loss=2933393.1996468795
# Current iteration=325, loss=2931606.990779783
# Current iteration=350, loss=2930714.286385884
# Current iteration=375, loss=2930268.0383445695
# Current iteration=400, loss=2930044.94119276
# Current iteration=425, loss=2929933.3987009944
# Current iteration=450, loss=2929877.628976144
# Current iteration=475, loss=2929849.744493977
# Current iteration=500, loss=2929835.8023479586
# Current iteration=525, loss=2929828.8312987154
# Current iteration=550, loss=2929825.345780035
# Current iteration=575, loss=2929823.60302218
# Current iteration=600, loss=2929822.731643624
# Current iteration=625, loss=2929822.2959544393
# Current iteration=650, loss=2929822.0781098707
# Current iteration=675, loss=2929821.9691875894
# Current iteration=700, loss=2929821.9147264496
# Current iteration=725, loss=2929821.887495884
# Current iteration=750, loss=2929821.8738806
# Current iteration=775, loss=2929821.867072959
# Current iteration=800, loss=2929821.8636691375
# Current iteration=825, loss=2929821.861967227
# Current iteration=850, loss=2929821.8611162705
# Current iteration=875, loss=2929821.8606907907
# Current iteration=900, loss=2929821.860478055
# Current iteration=925, loss=2929821.8603716837
# Current iteration=950, loss=2929821.860318498
# Current iteration=975, loss=2929821.8602919066
# Current iteration=0, loss=273597625.69190985
# Current iteration=25, loss=44674710.346698396
# Current iteration=50, loss=30258024.300814305
# Current iteration=75, loss=5385761.605711504
# Current iteration=100, loss=3814663.881242929
# Current iteration=125, loss=3218896.3796002655
# Current iteration=150, loss=2963322.652807291
# Current iteration=175, loss=2843027.9637222886
# Current iteration=200, loss=2784461.3294287715
# Current iteration=225, loss=2755567.071347532
# Current iteration=250, loss=2741216.426035758
# Current iteration=275, loss=2734065.1750883404
# Current iteration=300, loss=2730495.5629490265
# Current iteration=325, loss=2728712.234920835
# Current iteration=350, loss=2727820.9402440446
# Current iteration=375, loss=2727375.3856754815
# Current iteration=400, loss=2727152.633486205
# Current iteration=425, loss=2727041.262951396
# Current iteration=450, loss=2726985.5790738957
# Current iteration=475, loss=2726957.737482616
# Current iteration=500, loss=2726943.816773842
# Current iteration=525, loss=2726936.8564411714
# Current iteration=550, loss=2726933.3762802654
# Current iteration=575, loss=2726931.6362011703
# Current iteration=600, loss=2726930.7661619605
# Current iteration=625, loss=2726930.3311424414
# Current iteration=650, loss=2726930.1136327046
# Current iteration=675, loss=2726930.00487784
# Current iteration=700, loss=2726929.9505004105
# Current iteration=725, loss=2726929.923311694
# Current iteration=750, loss=2726929.909717337
# Current iteration=775, loss=2726929.902920159
# Current iteration=800, loss=2726929.8995215665
# Current iteration=825, loss=2726929.897822271
# Current iteration=850, loss=2726929.896972629
# Current iteration=875, loss=2726929.896547804
# Current iteration=900, loss=2726929.8963353904
# Current iteration=925, loss=2726929.8962291866
# Current iteration=950, loss=2726929.8961760863
# Current iteration=975, loss=2726929.896149534
# Current iteration=0, loss=273332841.54825634
# Current iteration=25, loss=44548910.602365576
# Current iteration=50, loss=6908774.167368907
# Current iteration=75, loss=9248105.71855206
# Current iteration=100, loss=3569899.496877635
# Current iteration=125, loss=3016564.9384956583
# Current iteration=150, loss=2776052.083494442
# Current iteration=175, loss=2662373.1091166837
# Current iteration=200, loss=2606936.380362504
# Current iteration=225, loss=2579553.4760392867
# Current iteration=250, loss=2565944.879196711
# Current iteration=275, loss=2559161.041491758
# Current iteration=300, loss=2555774.196671644
# Current iteration=325, loss=2554082.051526426
# Current iteration=350, loss=2553236.291957369
# Current iteration=375, loss=2552813.48756388
# Current iteration=400, loss=2552602.1042098063
# Current iteration=425, loss=2552496.4172428017
# Current iteration=450, loss=2552443.5749367266
# Current iteration=475, loss=2552417.1540780365
# Current iteration=500, loss=2552403.9437222765
# Current iteration=525, loss=2552397.3385627936
# Current iteration=550, loss=2552394.0359876505
# Current iteration=575, loss=2552392.3847012282
# Current iteration=600, loss=2552391.5590583053
# Current iteration=625, loss=2552391.146236916
# Current iteration=650, loss=2552390.9398262384
# Current iteration=675, loss=2552390.836620903
# Current iteration=700, loss=2552390.785018235
# Current iteration=725, loss=2552390.7592169032
# Current iteration=750, loss=2552390.746316238
# Current iteration=775, loss=2552390.7398659056
# Current iteration=800, loss=2552390.7366407393
# Current iteration=825, loss=2552390.735028156
# Current iteration=850, loss=2552390.734221861
# Current iteration=875, loss=2552390.7338187145
# Current iteration=900, loss=2552390.7336171423
# Current iteration=925, loss=2552390.7335163546
# Current iteration=950, loss=2552390.733465962
# Current iteration=975, loss=2552390.733440767
# Current iteration=0, loss=273384555.0013715
# Current iteration=25, loss=44554587.84695134
# Current iteration=50, loss=6812433.358643649
# Current iteration=75, loss=5805639.865716047
# Current iteration=100, loss=3500024.319978673
# Current iteration=125, loss=2949872.0892131138
# Current iteration=150, loss=2709562.16022664
# Current iteration=175, loss=2595461.2388428184
# Current iteration=200, loss=2539852.6173711754
# Current iteration=225, loss=2512391.53146704
# Current iteration=250, loss=2498744.5009735045
# Current iteration=275, loss=2491942.0588956033
# Current iteration=300, loss=2488545.9636347345
# Current iteration=325, loss=2486849.1756800013
# Current iteration=350, loss=2486001.1092540026
# Current iteration=375, loss=2485577.1580059547
# Current iteration=400, loss=2485365.202261673
# Current iteration=425, loss=2485259.229179033
# Current iteration=450, loss=2485206.243834965
# Current iteration=475, loss=2485179.7514622286
# Current iteration=500, loss=2485166.5053506824
# Current iteration=525, loss=2485159.8823136142
# Current iteration=550, loss=2485156.570799757
# Current iteration=575, loss=2485154.915043997
# Current iteration=600, loss=2485154.0871664095
# Current iteration=625, loss=2485153.6732276883
# Current iteration=650, loss=2485153.4662583466
# Current iteration=675, loss=2485153.362773681
# Current iteration=700, loss=2485153.3110313495
# Current iteration=725, loss=2485153.285160181
# Current iteration=750, loss=2485153.2722245976
# Current iteration=775, loss=2485153.2657568073
# Current iteration=800, loss=2485153.2625229107
# Current iteration=825, loss=2485153.260905963
# Current iteration=850, loss=2485153.2600974883
# Current iteration=875, loss=2485153.2596932524
# Current iteration=900, loss=2485153.259491132
# Current iteration=925, loss=2485153.2593900715
# Current iteration=950, loss=2485153.259339545
# Current iteration=975, loss=2485153.259314281
# Current iteration=0, loss=273766902.82661563
# Current iteration=25, loss=45109007.30833655
# Current iteration=50, loss=6858202.594053399
# Current iteration=75, loss=6178805.283036161
# Current iteration=100, loss=3503906.298193546
# Current iteration=125, loss=2965788.7235946134
# Current iteration=150, loss=2730436.0600511236
# Current iteration=175, loss=2618488.9165233565
# Current iteration=200, loss=2563772.3465988166
# Current iteration=225, loss=2536714.170776932
# Current iteration=250, loss=2523259.0789813353
# Current iteration=275, loss=2516549.6294949073
# Current iteration=300, loss=2513199.4879287505
# Current iteration=325, loss=2511525.5370154628
# Current iteration=350, loss=2510688.834542329
# Current iteration=375, loss=2510270.553012202
# Current iteration=400, loss=2510061.4295152347
# Current iteration=425, loss=2509956.8724685526
# Current iteration=450, loss=2509904.5952523514
# Current iteration=475, loss=2509878.456911008
# Current iteration=500, loss=2509865.387807026
# Current iteration=525, loss=2509858.853271708
# Current iteration=550, loss=2509855.5860082163
# Current iteration=575, loss=2509853.952377513
# Current iteration=600, loss=2509853.135562422
# Current iteration=625, loss=2509852.7271549413
# Current iteration=650, loss=2509852.5229512164
# Current iteration=675, loss=2509852.4208493563
# Current iteration=700, loss=2509852.369798427
# Current iteration=725, loss=2509852.3442729646
# Current iteration=750, loss=2509852.331510231
# Current iteration=775, loss=2509852.3251288678
# Current iteration=800, loss=2509852.3219381846
# Current iteration=825, loss=2509852.3203428416
# Current iteration=850, loss=2509852.319545171
# Current iteration=875, loss=2509852.3191463347
# Current iteration=900, loss=2509852.3189469217
# Current iteration=925, loss=2509852.3188472097
# Current iteration=950, loss=2509852.3187973583
# Current iteration=975, loss=2509852.3187724324
# Current iteration=0, loss=274390930.7426062
# Current iteration=25, loss=45056710.22941253
# Current iteration=50, loss=6870075.659537011
# Current iteration=75, loss=11382501.942726493
# Current iteration=100, loss=3566107.694283007
# Current iteration=125, loss=3001233.7881028396
# Current iteration=150, loss=2757134.651076068
# Current iteration=175, loss=2642029.923880999
# Current iteration=200, loss=2586113.4849624117
# Current iteration=225, loss=2558537.0823407187
# Current iteration=250, loss=2544842.168530725
# Current iteration=275, loss=2538017.6946287905
# Current iteration=300, loss=2534611.2524384684
# Current iteration=325, loss=2532909.5049383333
# Current iteration=350, loss=2532058.992900104
# Current iteration=375, loss=2531633.8243734958
# Current iteration=400, loss=2531421.261765374
# Current iteration=425, loss=2531314.9864848373
# Current iteration=450, loss=2531261.8503799266
# Current iteration=475, loss=2531235.2826657942
# Current iteration=500, loss=2531221.9988933085
# Current iteration=525, loss=2531215.3570282105
# Current iteration=550, loss=2531212.0361009478
# Current iteration=575, loss=2531210.3756386386
# Current iteration=600, loss=2531209.5454078135
# Current iteration=625, loss=2531209.130292484
# Current iteration=650, loss=2531208.92273484
# Current iteration=675, loss=2531208.818956023
# Current iteration=700, loss=2531208.767066617
# Current iteration=725, loss=2531208.7411219133
# Current iteration=750, loss=2531208.728149561
# Current iteration=775, loss=2531208.7216633875
# Current iteration=800, loss=2531208.718420301
# Current iteration=825, loss=2531208.716798756
# Current iteration=850, loss=2531208.715987983
# Current iteration=875, loss=2531208.7155826003
# Current iteration=900, loss=2531208.715379906
# Current iteration=925, loss=2531208.715278557
# Current iteration=950, loss=2531208.715227885
# Current iteration=975, loss=2531208.7152025485
# Current iteration=0, loss=273928172.9599129
# Current iteration=25, loss=45173672.07206468
# Current iteration=50, loss=28429351.149858873
# Current iteration=75, loss=5300952.882107967
# Current iteration=100, loss=3596633.336729041
# Current iteration=125, loss=2992502.6387415943
# Current iteration=150, loss=2735274.784639783
# Current iteration=175, loss=2614442.760161063
# Current iteration=200, loss=2555754.708888164
# Current iteration=225, loss=2526835.168915441
# Current iteration=250, loss=2512480.3086842354
# Current iteration=275, loss=2505329.0717833065
# Current iteration=300, loss=2501759.991336946
# Current iteration=325, loss=2499977.0955546014
# Current iteration=350, loss=2499086.060878207
# Current iteration=375, loss=2498640.64396271
# Current iteration=400, loss=2498417.961057359
# Current iteration=425, loss=2498306.625938854
# Current iteration=450, loss=2498250.959907539
# Current iteration=475, loss=2498223.1272738636
# Current iteration=500, loss=2498209.211052521
# Current iteration=525, loss=2498202.252965724
# Current iteration=550, loss=2498198.7739282935
# Current iteration=575, loss=2498197.034411071
# Current iteration=600, loss=2498196.164652832
# Current iteration=625, loss=2498195.7297738055
# Current iteration=650, loss=2498195.5123343165
# Current iteration=675, loss=2498195.4036145755
# Current iteration=700, loss=2498195.349254708
# Current iteration=725, loss=2498195.3220747737
# Current iteration=750, loss=2498195.308484808
# Current iteration=775, loss=2498195.3016898255
# Current iteration=800, loss=2498195.2982923295
# Current iteration=825, loss=2498195.296593583
# Current iteration=850, loss=2498195.295744214
# Current iteration=875, loss=2498195.2953195293
# Current iteration=900, loss=2498195.2951071835
# Current iteration=925, loss=2498195.295001014
# Current iteration=950, loss=2498195.2949479264
# Current iteration=975, loss=2498195.294921384
# Current iteration=0, loss=273662675.58928853
# Current iteration=25, loss=45108970.39830659
# Current iteration=50, loss=6582884.98123982
# Current iteration=75, loss=14548555.893650126
# Current iteration=100, loss=3549292.300867778
# Current iteration=125, loss=2931116.148512287
# Current iteration=150, loss=2674325.0645983703
# Current iteration=175, loss=2554707.808115587
# Current iteration=200, loss=2496733.7052746257
# Current iteration=225, loss=2468160.3520278833
# Current iteration=250, loss=2453973.6603001184
# Current iteration=275, loss=2446904.879416557
# Current iteration=300, loss=2443376.571184353
# Current iteration=325, loss=2441613.9776450363
# Current iteration=350, loss=2440733.077333373
# Current iteration=375, loss=2440292.726441034
# Current iteration=400, loss=2440072.576695861
# Current iteration=425, loss=2439962.5076125017
# Current iteration=450, loss=2439907.4747139583
# Current iteration=475, loss=2439879.9587351717
# Current iteration=500, loss=2439866.200836224
# Current iteration=525, loss=2439859.3219093615
# Current iteration=550, loss=2439855.8824515827
# Current iteration=575, loss=2439854.1627241066
# Current iteration=600, loss=2439853.302860722
# Current iteration=625, loss=2439852.872929118
# Current iteration=650, loss=2439852.657963339
# Current iteration=675, loss=2439852.550480453
# Current iteration=700, loss=2439852.496739013
# Current iteration=725, loss=2439852.4698682935
# Current iteration=750, loss=2439852.456432934
# Current iteration=775, loss=2439852.4497152525
# Current iteration=800, loss=2439852.4463564134
# Current iteration=825, loss=2439852.444676995
# Current iteration=850, loss=2439852.4438372822
# Current iteration=875, loss=2439852.4434174276
# Current iteration=900, loss=2439852.4432075005
# Current iteration=925, loss=2439852.4431025377
# Current iteration=950, loss=2439852.4430500553
# Current iteration=975, loss=2439852.443023815
# Current iteration=0, loss=273715028.5574677
# Current iteration=25, loss=45053947.22821353
# Current iteration=50, loss=6622147.551663224
# Current iteration=75, loss=10958983.100391958
# Current iteration=100, loss=3714779.293319431
# Current iteration=125, loss=3042821.618901742
# Current iteration=150, loss=2768192.0219109636
# Current iteration=175, loss=2641903.104636345
# Current iteration=200, loss=2580866.991296075
# Current iteration=225, loss=2550810.0646656593
# Current iteration=250, loss=2535896.5300091826
# Current iteration=275, loss=2528468.7945849216
# Current iteration=300, loss=2524762.003900471
# Current iteration=325, loss=2522910.3603087314
# Current iteration=350, loss=2521984.986540169
# Current iteration=375, loss=2521522.409696211
# Current iteration=400, loss=2521291.1484305398
# Current iteration=425, loss=2521175.525018054
# Current iteration=450, loss=2521117.7149787773
# Current iteration=475, loss=2521088.8103758716
# Current iteration=500, loss=2521074.358178601
# Current iteration=525, loss=2521067.132106011
# Current iteration=550, loss=2521063.519076227
# Current iteration=575, loss=2521061.7125629634
# Current iteration=600, loss=2521060.809306739
# Current iteration=625, loss=2521060.3576787272
# Current iteration=650, loss=2521060.1318647475
# Current iteration=675, loss=2521060.0189577662
# Current iteration=700, loss=2521059.9625042765
# Current iteration=725, loss=2521059.934277534
# Current iteration=750, loss=2521059.9201641628
# Current iteration=775, loss=2521059.9131074767
# Current iteration=800, loss=2521059.9095791345
# Current iteration=825, loss=2521059.9078149614
# Current iteration=850, loss=2521059.9069328755
# Current iteration=875, loss=2521059.906491832
# Current iteration=900, loss=2521059.90627131
# Current iteration=925, loss=2521059.906161049
# Current iteration=950, loss=2521059.906105919
# Current iteration=975, loss=2521059.906078352
# Current iteration=0, loss=274098412.66101235
# Current iteration=25, loss=45643072.011603
# Current iteration=50, loss=6783920.216077184
# Current iteration=75, loss=11084982.521709202
# Current iteration=100, loss=3783088.869822797
# Current iteration=125, loss=3113937.489470858
# Current iteration=150, loss=2838384.983829384
# Current iteration=175, loss=2711793.96565319
# Current iteration=200, loss=2650810.4200505237
# Current iteration=225, loss=2620835.5900553633
# Current iteration=250, loss=2605970.4465681654
# Current iteration=275, loss=2598567.636877121
# Current iteration=300, loss=2594873.48569258
# Current iteration=325, loss=2593028.20003669
# Current iteration=350, loss=2592106.005712797
# Current iteration=375, loss=2591645.0159729505
# Current iteration=400, loss=2591414.548275578
# Current iteration=425, loss=2591299.3216541857
# Current iteration=450, loss=2591241.7100184234
# Current iteration=475, loss=2591212.904619214
# Current iteration=500, loss=2591198.5020242683
# Current iteration=525, loss=2591191.3007529597
# Current iteration=550, loss=2591187.7001238465
# Current iteration=575, loss=2591185.899810925
# Current iteration=600, loss=2591184.9996548733
# Current iteration=625, loss=2591184.54957695
# Current iteration=650, loss=2591184.3245380134
# Current iteration=675, loss=2591184.2120185504
# Current iteration=700, loss=2591184.155758818
# Current iteration=725, loss=2591184.127628957
# Current iteration=750, loss=2591184.113564025
# Current iteration=775, loss=2591184.106531561
# Current iteration=800, loss=2591184.103015328
# Current iteration=825, loss=2591184.1012572097
# Current iteration=850, loss=2591184.1003781524
# Current iteration=875, loss=2591184.0999386227
# Current iteration=900, loss=2591184.0997188613
# Current iteration=925, loss=2591184.09960898
# Current iteration=950, loss=2591184.0995540363
# Current iteration=975, loss=2591184.099526566
# Current iteration=0, loss=274723350.3500147
# Current iteration=25, loss=45517049.21023451
# Current iteration=50, loss=6838463.091774247
# Current iteration=75, loss=11066160.571966337
# Current iteration=100, loss=3726781.225038371
# Current iteration=125, loss=3055056.2848550603
# Current iteration=150, loss=2779597.4682334573
# Current iteration=175, loss=2652622.5425049085
# Current iteration=200, loss=2591295.943149551
# Current iteration=225, loss=2561167.8058287073
# Current iteration=250, loss=2546238.2572438777
# Current iteration=275, loss=2538806.6692359033
# Current iteration=300, loss=2535099.2096144217
# Current iteration=325, loss=2533247.552584778
# Current iteration=350, loss=2532322.235062906
# Current iteration=375, loss=2531859.706252635
# Current iteration=400, loss=2531628.4750882336
# Current iteration=425, loss=2531512.867359162
# Current iteration=450, loss=2531455.065576306
# Current iteration=475, loss=2531426.1652138825
# Current iteration=500, loss=2531411.7151553524
# Current iteration=525, loss=2531404.490156757
# Current iteration=550, loss=2531400.8776651276
# Current iteration=575, loss=2531399.0714212293
# Current iteration=600, loss=2531398.1682997593
# Current iteration=625, loss=2531397.7167391446
# Current iteration=650, loss=2531397.490958866
# Current iteration=675, loss=2531397.378068733
# Current iteration=700, loss=2531397.32162367
# Current iteration=725, loss=2531397.2934011365
# Current iteration=750, loss=2531397.2792898733
# Current iteration=775, loss=2531397.27223424
# Current iteration=800, loss=2531397.268706422
# Current iteration=825, loss=2531397.2669425127
# Current iteration=850, loss=2531397.2660605605
# Current iteration=875, loss=2531397.265619583
# Current iteration=900, loss=2531397.265399095
# Current iteration=925, loss=2531397.265288853
# Current iteration=950, loss=2531397.265233729
# Current iteration=975, loss=2531397.2652061675
# Current iteration=0, loss=274258765.4201805
# Current iteration=25, loss=45652578.72669942
# Current iteration=50, loss=20078088.832433894
# Current iteration=75, loss=4514417.279858435
# Current iteration=100, loss=3230002.672855572
# Current iteration=125, loss=2649083.301896001
# Current iteration=150, loss=2401474.9817619137
# Current iteration=175, loss=2285293.4542226214
# Current iteration=200, loss=2229015.4178798273
# Current iteration=225, loss=2201310.7277588663
# Current iteration=250, loss=2187564.2882453245
# Current iteration=275, loss=2180716.5965811824
# Current iteration=300, loss=2177299.0425324733
# Current iteration=325, loss=2175591.8013723185
# Current iteration=350, loss=2174738.5619507357
# Current iteration=375, loss=2174312.0359238856
# Current iteration=400, loss=2174098.797077391
# Current iteration=425, loss=2173992.1835242505
# Current iteration=450, loss=2173938.8782568662
# Current iteration=475, loss=2173912.225985865
# Current iteration=500, loss=2173898.899941031
# Current iteration=525, loss=2173892.23694128
# Current iteration=550, loss=2173888.90544707
# Current iteration=575, loss=2173887.2397013824
# Current iteration=600, loss=2173886.4068288915
# Current iteration=625, loss=2173885.990392735
# Current iteration=650, loss=2173885.7821746804
# Current iteration=675, loss=2173885.6780656567
# Current iteration=700, loss=2173885.6260111458
# Current iteration=725, loss=2173885.5999838943
# Current iteration=750, loss=2173885.586970265
# Current iteration=775, loss=2173885.5804634523
# Current iteration=800, loss=2173885.577210047
# Current iteration=825, loss=2173885.57558334
# Current iteration=850, loss=2173885.574769987
# Current iteration=875, loss=2173885.57436331
# Current iteration=900, loss=2173885.574159974
# Current iteration=925, loss=2173885.574058307
# Current iteration=950, loss=2173885.5740074716
# Current iteration=975, loss=2173885.573982055
# Current iteration=0, loss=273992554.732375
# Current iteration=25, loss=45646203.79797185
# Current iteration=50, loss=23940171.41946597
# Current iteration=75, loss=5218761.523417666
# Current iteration=100, loss=2789430.2273035594
# Current iteration=125, loss=2487683.3639666215
# Current iteration=150, loss=2253414.6369295646
# Current iteration=175, loss=2142757.5066249357
# Current iteration=200, loss=2088851.0967436077
# Current iteration=225, loss=2062234.8315204873
# Current iteration=250, loss=2049009.7428453432
# Current iteration=275, loss=2042417.8839569916
# Current iteration=300, loss=2039127.0876044019
# Current iteration=325, loss=2037482.9459154492
# Current iteration=350, loss=2036661.1821153937
# Current iteration=375, loss=2036250.3808724862
# Current iteration=400, loss=2036044.9996912256
# Current iteration=425, loss=2035942.3143491682
# Current iteration=450, loss=2035890.9728663736
# Current iteration=475, loss=2035865.3024220138
# Current iteration=500, loss=2035852.467274091
# Current iteration=525, loss=2035846.049718694
# Current iteration=550, loss=2035842.8409456362
# Current iteration=575, loss=2035841.2365602679
# Current iteration=600, loss=2035840.434367873
# Current iteration=625, loss=2035840.0332717488
# Current iteration=650, loss=2035839.8327237044
# Current iteration=675, loss=2035839.732449686
# Current iteration=700, loss=2035839.6823126788
# Current iteration=725, loss=2035839.6572441717
# Current iteration=750, loss=2035839.6447099235
# Current iteration=775, loss=2035839.6384427957
# Current iteration=800, loss=2035839.6353092343
# Current iteration=825, loss=2035839.633742451
# Current iteration=850, loss=2035839.6329590594
# Current iteration=875, loss=2035839.6325673643
# Current iteration=900, loss=2035839.6323715176
# Current iteration=925, loss=2035839.6322735948
# Current iteration=950, loss=2035839.6322246343
# Current iteration=975, loss=2035839.6322001514
# Current iteration=0, loss=274045547.27934784
# Current iteration=25, loss=45581868.26606619
# Current iteration=50, loss=32637496.36060493
# Current iteration=75, loss=8264629.103172831
# Current iteration=100, loss=3064168.055363092
# Current iteration=125, loss=2513822.409702066
# Current iteration=150, loss=2271821.901178622
# Current iteration=175, loss=2157990.881447624
# Current iteration=200, loss=2102686.0118134124
# Current iteration=225, loss=2075401.2148783938
# Current iteration=250, loss=2061844.6762008455
# Current iteration=275, loss=2055087.0767124197
# Current iteration=300, loss=2051713.4274809954
# Current iteration=325, loss=2050027.8852776967
# Current iteration=350, loss=2049185.429950602
# Current iteration=375, loss=2048764.281718118
# Current iteration=400, loss=2048553.7268172873
# Current iteration=425, loss=2048448.4541697814
# Current iteration=450, loss=2048395.8190466396
# Current iteration=475, loss=2048369.5017852064
# Current iteration=500, loss=2048356.3432295225
# Current iteration=525, loss=2048349.7639704393
# Current iteration=550, loss=2048346.4743455865
# Current iteration=575, loss=2048344.829534332
# Current iteration=600, loss=2048344.0071289984
# Current iteration=625, loss=2048343.5959264042
# Current iteration=650, loss=2048343.3903251248
# Current iteration=675, loss=2048343.2875244883
# Current iteration=700, loss=2048343.2361241742
# Current iteration=725, loss=2048343.2104240162
# Current iteration=750, loss=2048343.1975739384
# Current iteration=775, loss=2048343.1911488988
# Current iteration=800, loss=2048343.1879363786
# Current iteration=825, loss=2048343.186330116
# Current iteration=850, loss=2048343.1855269845
# Current iteration=875, loss=2048343.185125419
# Current iteration=900, loss=2048343.1849246372
# Current iteration=925, loss=2048343.1848242453
# Current iteration=950, loss=2048343.1847740526
# Current iteration=975, loss=2048343.1847489562
# Current iteration=0, loss=274429967.80084205
# Current iteration=25, loss=46123711.67145325
# Current iteration=50, loss=36370259.94537885
# Current iteration=75, loss=6161142.450346583
# Current iteration=100, loss=2852945.085957114
# Current iteration=125, loss=2475774.918462193
# Current iteration=150, loss=2241897.776458504
# Current iteration=175, loss=2131387.758630893
# Current iteration=200, loss=2077632.0035652246
# Current iteration=225, loss=2051102.5675479104
# Current iteration=250, loss=2037921.026652282
# Current iteration=275, loss=2031350.4652383968
# Current iteration=300, loss=2028070.1598137384
# Current iteration=325, loss=2026431.2460004902
# Current iteration=350, loss=2025612.0936254805
# Current iteration=375, loss=2025202.594024708
# Current iteration=400, loss=2024997.8631990047
# Current iteration=425, loss=2024895.5026964245
# Current iteration=450, loss=2024844.3239243669
# Current iteration=475, loss=2024818.7348259564
# Current iteration=500, loss=2024805.9403486527
# Current iteration=525, loss=2024799.5431279754
# Current iteration=550, loss=2024796.3445221302
# Current iteration=575, loss=2024794.7452203317
# Current iteration=600, loss=2024793.9455697131
# Current iteration=625, loss=2024793.5457444736
# Current iteration=650, loss=2024793.3458318727
# Current iteration=675, loss=2024793.245875577
# Current iteration=700, loss=2024793.1958974302
# Current iteration=725, loss=2024793.170908357
# Current iteration=750, loss=2024793.1584138197
# Current iteration=775, loss=2024793.1521665505
# Current iteration=800, loss=2024793.1490429163
# Current iteration=825, loss=2024793.1474810983
# Current iteration=850, loss=2024793.1467001913
# Current iteration=875, loss=2024793.146309739
# Current iteration=900, loss=2024793.1461145128
# Current iteration=925, loss=2024793.1460168988
# Current iteration=950, loss=2024793.145968092
# Current iteration=975, loss=2024793.1459436875
# Current iteration=0, loss=275055815.27110213
# Current iteration=25, loss=46023573.324878305
# Current iteration=50, loss=6106206.836801541
# Current iteration=75, loss=11194467.748121839
# Current iteration=100, loss=3537557.3632611586
# Current iteration=125, loss=2854249.2725603525
# Current iteration=150, loss=2576944.827877251
# Current iteration=175, loss=2449477.8881955952
# Current iteration=200, loss=2388094.7428650726
# Current iteration=225, loss=2357987.9316116227
# Current iteration=250, loss=2343081.1544921454
# Current iteration=275, loss=2335663.73726121
# Current iteration=300, loss=2331963.826009161
# Current iteration=325, loss=2330116.088137153
# Current iteration=350, loss=2329192.749834507
# Current iteration=375, loss=2328731.2128937077
# Current iteration=400, loss=2328500.477388636
# Current iteration=425, loss=2328385.1178743383
# Current iteration=450, loss=2328327.4401763617
# Current iteration=475, loss=2328298.6018421175
# Current iteration=500, loss=2328284.182803675
# Current iteration=525, loss=2328276.973316624
# Current iteration=550, loss=2328273.36858114
# Current iteration=575, loss=2328271.5662154085
# Current iteration=600, loss=2328270.665033046
# Current iteration=625, loss=2328270.21444199
# Current iteration=650, loss=2328269.9891464924
# Current iteration=675, loss=2328269.8764987527
# Current iteration=700, loss=2328269.8201748854
# Current iteration=725, loss=2328269.792012951
# Current iteration=750, loss=2328269.777931985
# Current iteration=775, loss=2328269.7708915025
# Current iteration=800, loss=2328269.76737126
# Current iteration=825, loss=2328269.76561114
# Current iteration=850, loss=2328269.7647310784
# Current iteration=875, loss=2328269.764291049
# Current iteration=900, loss=2328269.7640710315
# Current iteration=925, loss=2328269.763961028
# Current iteration=950, loss=2328269.763906023
# Current iteration=975, loss=2328269.763878523
# Current iteration=0, loss=274589403.07757264
# Current iteration=25, loss=46202811.91577319
# Current iteration=50, loss=21183931.899582267
# Current iteration=75, loss=4603474.577306258
# Current iteration=100, loss=3064445.8409233256
# Current iteration=125, loss=2475652.8985407157
# Current iteration=150, loss=2226787.903195935
# Current iteration=175, loss=2110571.964443735
# Current iteration=200, loss=2054372.9009537029
# Current iteration=225, loss=2026716.9867476972
# Current iteration=250, loss=2012992.0199308714
# Current iteration=275, loss=2006154.4821022823
# Current iteration=300, loss=2002741.8609831021
# Current iteration=325, loss=2001037.0394133998
# Current iteration=350, loss=2000184.9936896577
# Current iteration=375, loss=1999759.0614184805
# Current iteration=400, loss=1999546.1178273945
# Current iteration=425, loss=1999439.651665112
# Current iteration=450, loss=1999386.4199919284
# Current iteration=475, loss=1999359.8045072816
# Current iteration=500, loss=1999346.4968529392
# Current iteration=525, loss=1999339.843047762
# Current iteration=550, loss=1999336.516150672
# Current iteration=575, loss=1999334.8527035012
# Current iteration=600, loss=1999334.0209802594
# Current iteration=625, loss=1999333.6051187248
# Current iteration=650, loss=1999333.3971879785
# Current iteration=675, loss=1999333.2932226094
# Current iteration=700, loss=1999333.2412399282
# Current iteration=725, loss=1999333.2152485861
# Current iteration=750, loss=1999333.2022529182
# Current iteration=775, loss=1999333.195755082
# Current iteration=800, loss=1999333.1925061634
# Current iteration=825, loss=1999333.1908817051
# Current iteration=850, loss=1999333.1900694754
# Current iteration=875, loss=1999333.1896633613
# Current iteration=900, loss=1999333.1894603055
# Current iteration=925, loss=1999333.189358776
# Current iteration=950, loss=1999333.1893080114
# Current iteration=975, loss=1999333.1892826285
# Current iteration=0, loss=274322478.9823756
# Current iteration=25, loss=46221127.83022399
# Current iteration=50, loss=24596176.836332344
# Current iteration=75, loss=4831495.739298206
# Current iteration=100, loss=3178053.483246461
# Current iteration=125, loss=2572264.4849543534
# Current iteration=150, loss=2317660.389114035
# Current iteration=175, loss=2198704.133730684
# Current iteration=200, loss=2141018.7664982732
# Current iteration=225, loss=2112603.224713292
# Current iteration=250, loss=2098497.559500882
# Current iteration=275, loss=2091469.853188497
# Current iteration=300, loss=2087962.3528284032
# Current iteration=325, loss=2086210.187407861
# Current iteration=350, loss=2085334.498535975
# Current iteration=375, loss=2084896.7482504952
# Current iteration=400, loss=2084677.897896741
# Current iteration=425, loss=2084568.479249018
# Current iteration=450, loss=2084513.7713781951
# Current iteration=475, loss=2084486.41780602
# Current iteration=500, loss=2084472.7411107386
# Current iteration=525, loss=2084465.9027857995
# Current iteration=550, loss=2084462.4836290046
# Current iteration=575, loss=2084460.7740520264
# Current iteration=600, loss=2084459.9192638916
# Current iteration=625, loss=2084459.491869913
# Current iteration=650, loss=2084459.278172946
# Current iteration=675, loss=2084459.1713244661
# Current iteration=700, loss=2084459.1179002263
# Current iteration=725, loss=2084459.0911881106
# Current iteration=750, loss=2084459.0778320497
# Current iteration=775, loss=2084459.07115402
# Current iteration=800, loss=2084459.0678150053
# Current iteration=825, loss=2084459.066145499
# Current iteration=850, loss=2084459.065310748
# Current iteration=875, loss=2084459.0648933721
# Current iteration=900, loss=2084459.064684682
# Current iteration=925, loss=2084459.0645803374
# Current iteration=950, loss=2084459.0645281654
# Current iteration=975, loss=2084459.0645020767
# Current iteration=0, loss=274376111.17187196
# Current iteration=25, loss=46099381.12980496
# Current iteration=50, loss=18407470.35867955
# Current iteration=75, loss=3272717.6678533987
# Current iteration=100, loss=3006957.784430481
# Current iteration=125, loss=2349365.681013518
# Current iteration=150, loss=2105945.397802886
# Current iteration=175, loss=1992032.3471539186
# Current iteration=200, loss=1936754.8204343338
# Current iteration=225, loss=1909488.209360954
# Current iteration=250, loss=1895944.887377342
# Current iteration=275, loss=1889195.6468469847
# Current iteration=300, loss=1885826.5786916313
# Current iteration=325, loss=1884143.4167550297
# Current iteration=350, loss=1883302.1803441932
# Current iteration=375, loss=1882881.6516941893
# Current iteration=400, loss=1882671.408078155
# Current iteration=425, loss=1882566.291446591
# Current iteration=450, loss=1882513.7344248232
# Current iteration=475, loss=1882487.456237431
# Current iteration=500, loss=1882474.3172246052
# Current iteration=525, loss=1882467.7477384103
# Current iteration=550, loss=1882464.463000367
# Current iteration=575, loss=1882462.8206326093
# Current iteration=600, loss=1882461.999449046
# Current iteration=625, loss=1882461.5888573437
# Current iteration=650, loss=1882461.3835615125
# Current iteration=675, loss=1882461.2809136014
# Current iteration=700, loss=1882461.2295896453
# Current iteration=725, loss=1882461.2039276694
# Current iteration=750, loss=1882461.1910966793
# Current iteration=775, loss=1882461.1846811853
# Current iteration=800, loss=1882461.1814734403
# Current iteration=825, loss=1882461.1798695654
# Current iteration=850, loss=1882461.179067631
# Current iteration=875, loss=1882461.1786666596
# Current iteration=900, loss=1882461.1784661761
# Current iteration=925, loss=1882461.178365934
# Current iteration=950, loss=1882461.1783158141
# Current iteration=975, loss=1882461.178290755
# Current iteration=0, loss=274761568.2509646
# Current iteration=25, loss=46716808.35425935
# Current iteration=50, loss=16752939.535525963
# Current iteration=75, loss=3961376.0326289567
# Current iteration=100, loss=3434523.8822787954
# Current iteration=125, loss=2742726.2547652153
# Current iteration=150, loss=2463338.217456525
# Current iteration=175, loss=2335803.928363933
# Current iteration=200, loss=2274478.852772744
# Current iteration=225, loss=2244352.2317670016
# Current iteration=250, loss=2229415.9522055434
# Current iteration=275, loss=2221978.9960634545
# Current iteration=300, loss=2218268.116023454
# Current iteration=325, loss=2216414.574622019
# Current iteration=350, loss=2215488.2817484206
# Current iteration=375, loss=2215025.2552556596
# Current iteration=400, loss=2214793.770482853
# Current iteration=425, loss=2214678.0352131235
# Current iteration=450, loss=2214620.1693572123
# Current iteration=475, loss=2214591.2368739685
# Current iteration=500, loss=2214576.770743521
# Current iteration=525, loss=2214569.537706091
# Current iteration=550, loss=2214565.921194324
# Current iteration=575, loss=2214564.112940178
# Current iteration=600, loss=2214563.208813539
# Current iteration=625, loss=2214562.756750328
# Current iteration=650, loss=2214562.530718749
# Current iteration=675, loss=2214562.4177029664
# Current iteration=700, loss=2214562.361195075
# Current iteration=725, loss=2214562.3329411303
# Current iteration=750, loss=2214562.318814161
# Current iteration=775, loss=2214562.3117506774
# Current iteration=800, loss=2214562.308218934
# Current iteration=825, loss=2214562.3064530594
# Current iteration=850, loss=2214562.3055701246
# Current iteration=875, loss=2214562.305128654
# Current iteration=900, loss=2214562.3049079217
# Current iteration=925, loss=2214562.3047975553
# Current iteration=950, loss=2214562.3047423703
# Current iteration=975, loss=2214562.3047147775
# Current iteration=0, loss=275388325.51072854
# Current iteration=25, loss=46611524.34033506
# Current iteration=50, loss=25907927.236359585
# Current iteration=75, loss=11526184.279970134
# Current iteration=100, loss=3361412.8308068663
# Current iteration=125, loss=2669007.3056563274
# Current iteration=150, loss=2390847.196867126
# Current iteration=175, loss=2263442.163275649
# Current iteration=200, loss=2202288.301922153
# Current iteration=225, loss=2172337.7857498634
# Current iteration=250, loss=2157512.0119654867
# Current iteration=275, loss=2150135.326085901
# Current iteration=300, loss=2146456.170731504
# Current iteration=325, loss=2144618.8243851904
# Current iteration=350, loss=2143700.7151408503
# Current iteration=375, loss=2143241.8019015626
# Current iteration=400, loss=2143012.379946386
# Current iteration=425, loss=2142897.6786345784
# Current iteration=450, loss=2142840.3300864953
# Current iteration=475, loss=2142811.6564098937
# Current iteration=500, loss=2142797.3197284173
# Current iteration=525, loss=2142790.1514206086
# Current iteration=550, loss=2142786.567274936
# Current iteration=575, loss=2142784.775204158
# Current iteration=600, loss=2142783.8791692834
# Current iteration=625, loss=2142783.431151975
# Current iteration=650, loss=2142783.2071433524
# Current iteration=675, loss=2142783.0951390476
# Current iteration=700, loss=2142783.0391368987
# Current iteration=725, loss=2142783.011135825
# Current iteration=750, loss=2142782.99713529
# Current iteration=775, loss=2142782.9901350224
# Current iteration=800, loss=2142782.9866348878
# Current iteration=825, loss=2142782.984884822
# Current iteration=850, loss=2142782.984009785
# Current iteration=875, loss=2142782.9835722703
# Current iteration=900, loss=2142782.9833535114
# Current iteration=925, loss=2142782.98324413
# Current iteration=950, loss=2142782.9831894385
# Current iteration=975, loss=2142782.983162097
# [3.] [1] [0.00017783]

# %%
# for degrees in range (2, 6) and lambdas in (0, 1) the best results are respectively the lower and the upper bound
# so now we go on with looking for the best parameters in degree \in {1,2} and lambda in [1, 2] hoping to get for lambda an
# internal optimal point 
# degrees = np.arange(2, 5)
lambdas = np.linspace(0, 3, 5)
degree = 2
# gammas = np.logspace(-5, 0, 5)
gamma = 0.0017783
k_fold = 5
seed = 1
training_loss = np.zeros((len(lambdas), len(degrees), len(gammas)))
testing_loss = np.zeros((len(lambdas), len(degrees), len(gammas)))
k_indices = build_k_indices(y_2_3, k_fold, seed)
for index1 in range(len(lambdas)):
    # for index2 in range(len(degrees)):
    #   for index3 in range(len(gammas)):
    train_loss = 0
    test_loss = 0
    for k in range(k_fold):
            loss_tr, loss_te = cross_validation_logistic(y_2_3, tX_tilda_2_3, k_indices, k,
                                            lambdas[index1], degree, gamma)
            train_loss += loss_tr
            test_loss += loss_te
    training_loss[index1] = train_loss / k_fold
    testing_loss[index1] = test_loss / k_fold
best_result = np.where(testing_loss == np.amin(testing_loss))
lambda_opt = lambdas[best_result[0]]
print(lambda_opt)
# Out:
# Current iteration=0, loss=158505624.53907633
# Current iteration=25, loss=6357233.2979824
# Current iteration=50, loss=5144190.323673397
# Current iteration=75, loss=3667294.7999277893
# Current iteration=100, loss=3040592.940880635
# Current iteration=125, loss=2755572.3345021666
# Current iteration=150, loss=2621164.4213775583
# Current iteration=175, loss=2555954.596440154
# Current iteration=200, loss=2523987.2084299945
# Current iteration=225, loss=2508190.993306246
# Current iteration=250, loss=2500330.877798271
# Current iteration=275, loss=2496409.1177166114
# Current iteration=300, loss=2494450.240827481
# Current iteration=325, loss=2493471.256790984
# Current iteration=350, loss=2492981.880282477
# Current iteration=375, loss=2492737.2186027346
# Current iteration=400, loss=2492614.894385363
# Current iteration=425, loss=2492553.7339297077
# Current iteration=450, loss=2492523.154114815
# Current iteration=475, loss=2492507.864310563
# Current iteration=500, loss=2492500.219434231
# Current iteration=525, loss=2492496.397002514
# Current iteration=550, loss=2492494.4857882666
# Current iteration=575, loss=2492493.5301815458
# Current iteration=600, loss=2492493.052378287
# Current iteration=625, loss=2492492.813476682
# Current iteration=650, loss=2492492.694025885
# Current iteration=675, loss=2492492.634300491
# Current iteration=700, loss=2492492.6044377903
# Current iteration=725, loss=2492492.589506442
# Current iteration=750, loss=2492492.5820407686
# Current iteration=775, loss=2492492.578307931
# Current iteration=800, loss=2492492.576441513
# Current iteration=825, loss=2492492.575508303
# Current iteration=850, loss=2492492.5750416974
# Current iteration=875, loss=2492492.574808396
# Current iteration=900, loss=2492492.574691744
# Current iteration=925, loss=2492492.574633418
# Current iteration=950, loss=2492492.574604254
# Current iteration=975, loss=2492492.574589676
# Current iteration=0, loss=158468214.7671536
# Current iteration=25, loss=6331747.463034468
# Current iteration=50, loss=5214699.560417448
# Current iteration=75, loss=3732869.49348694
# Current iteration=100, loss=3101358.4573278124
# Current iteration=125, loss=2813805.86353311
# Current iteration=150, loss=2677828.5622129194
# Current iteration=175, loss=2611729.503554717
# Current iteration=200, loss=2579363.861059078
# Current iteration=225, loss=2563378.790640714
# Current iteration=250, loss=2555433.6667268383
# Current iteration=275, loss=2551472.3122354783
# Current iteration=300, loss=2549494.3087238693
# Current iteration=325, loss=2548505.9184541483
# Current iteration=350, loss=2548011.865338229
# Current iteration=375, loss=2547764.8782789363
# Current iteration=400, loss=2547641.393384882
# Current iteration=425, loss=2547579.65306834
# Current iteration=450, loss=2547548.7835006863
# Current iteration=475, loss=2547533.348849066
# Current iteration=500, loss=2547525.631556291
# Current iteration=525, loss=2547521.77291816
# Current iteration=550, loss=2547519.8436011584
# Current iteration=575, loss=2547518.8789431737
# Current iteration=600, loss=2547518.3966143103
# Current iteration=625, loss=2547518.1554499106
# Current iteration=650, loss=2547518.0348677165
# Current iteration=675, loss=2547517.9745766222
# Current iteration=700, loss=2547517.944431075
# Current iteration=725, loss=2547517.929358301
# Current iteration=750, loss=2547517.921821916
# Current iteration=775, loss=2547517.918053721
# Current iteration=800, loss=2547517.916169627
# Current iteration=825, loss=2547517.915227579
# Current iteration=850, loss=2547517.9147565556
# Current iteration=875, loss=2547517.9145210446
# Current iteration=900, loss=2547517.9144032877
# Current iteration=925, loss=2547517.9143444095
# Current iteration=950, loss=2547517.914314973
# Current iteration=975, loss=2547517.914300254
# Current iteration=0, loss=158635067.6409244
# Current iteration=25, loss=6368932.671445592
# Current iteration=50, loss=5155760.057915364
# Current iteration=75, loss=3679587.7240674044
# Current iteration=100, loss=3041223.588062905
# Current iteration=125, loss=2752985.797611625
# Current iteration=150, loss=2617182.955531691
# Current iteration=175, loss=2551553.573755467
# Current iteration=200, loss=2519251.71132012
# Current iteration=225, loss=2503258.4866386456
# Current iteration=250, loss=2495301.438801729
# Current iteration=275, loss=2491333.019233329
# Current iteration=300, loss=2489351.092531107
# Current iteration=325, loss=2488360.7174673453
# Current iteration=350, loss=2487865.673075957
# Current iteration=375, loss=2487618.1903519267
# Current iteration=400, loss=2487494.4577421537
# Current iteration=425, loss=2487432.5935634268
# Current iteration=450, loss=2487401.662005475
# Current iteration=475, loss=2487386.196359337
# Current iteration=500, loss=2487378.4635694735
# Current iteration=525, loss=2487374.5971828443
# Current iteration=550, loss=2487372.663991604
# Current iteration=575, loss=2487371.6973965038
# Current iteration=600, loss=2487371.2140990826
# Current iteration=625, loss=2487370.9724504068
# Current iteration=650, loss=2487370.8516260763
# Current iteration=675, loss=2487370.7912139115
# Current iteration=700, loss=2487370.7610078286
# Current iteration=725, loss=2487370.7459047893
# Current iteration=750, loss=2487370.738353271
# Current iteration=775, loss=2487370.7345775077
# Current iteration=800, loss=2487370.732689628
# Current iteration=825, loss=2487370.7317456864
# Current iteration=850, loss=2487370.731273717
# Current iteration=875, loss=2487370.7310377327
# Current iteration=900, loss=2487370.730919742
# Current iteration=925, loss=2487370.730860745
# Current iteration=950, loss=2487370.730831248
# Current iteration=975, loss=2487370.730816501
# Current iteration=0, loss=158175275.0927192
# Current iteration=25, loss=6304925.138011438
# Current iteration=50, loss=5098070.820777213
# Current iteration=75, loss=3631711.9944606544
# Current iteration=100, loss=2999565.1809240673
# Current iteration=125, loss=2711422.2938463166
# Current iteration=150, loss=2575651.4645447955
# Current iteration=175, loss=2510244.7364617726
# Current iteration=200, loss=2478206.3959221677
# Current iteration=225, loss=2462339.8847379372
# Current iteration=250, loss=2454444.436671676
# Current iteration=275, loss=2450505.7573914053
# Current iteration=300, loss=2448538.7096436773
# Current iteration=325, loss=2447555.7607901953
# Current iteration=350, loss=2447064.426909031
# Current iteration=375, loss=2446818.7951477706
# Current iteration=400, loss=2446695.987988668
# Current iteration=425, loss=2446634.5865892344
# Current iteration=450, loss=2446603.8864345117
# Current iteration=475, loss=2446588.536493394
# Current iteration=500, loss=2446580.861556897
# Current iteration=525, loss=2446577.0240971628
# Current iteration=550, loss=2446575.105369424
# Current iteration=575, loss=2446574.146006088
# Current iteration=600, loss=2446573.666324552
# Current iteration=625, loss=2446573.4264838165
# Current iteration=650, loss=2446573.3065634584
# Current iteration=675, loss=2446573.246603282
# Current iteration=700, loss=2446573.2166231936
# Current iteration=725, loss=2446573.20163315
# Current iteration=750, loss=2446573.1941381283
# Current iteration=775, loss=2446573.190390617
# Current iteration=800, loss=2446573.188516861
# Current iteration=825, loss=2446573.1875799834
# Current iteration=850, loss=2446573.187111545
# Current iteration=875, loss=2446573.1868773242
# Current iteration=900, loss=2446573.1867602174
# Current iteration=925, loss=2446573.1867016586
# Current iteration=950, loss=2446573.186672383
# Current iteration=975, loss=2446573.1866577445
# Current iteration=0, loss=158393650.38631058
# Current iteration=25, loss=6361029.61891474
# Current iteration=50, loss=5098777.770525454
# Current iteration=75, loss=3587548.53406651
# Current iteration=100, loss=2959509.316570094
# Current iteration=125, loss=2675473.4052281794
# Current iteration=150, loss=2542547.7967213294
# Current iteration=175, loss=2478247.0881691566
# Current iteration=200, loss=2446622.447532375
# Current iteration=225, loss=2430919.6291778074
# Current iteration=250, loss=2423095.8650944927
# Current iteration=275, loss=2419191.517443556
# Current iteration=300, loss=2417241.2927898364
# Current iteration=325, loss=2416266.6915227524
# Current iteration=350, loss=2415779.5227228133
# Current iteration=375, loss=2415535.970944962
# Current iteration=400, loss=2415414.203009277
# Current iteration=425, loss=2415353.321359372
# Current iteration=450, loss=2415322.881064332
# Current iteration=475, loss=2415307.6610416137
# Current iteration=500, loss=2415300.0510614635
# Current iteration=525, loss=2415296.2460791925
# Current iteration=550, loss=2415294.343590008
# Current iteration=575, loss=2415293.3923459034
# Current iteration=600, loss=2415292.916723972
# Current iteration=625, loss=2415292.678913035
# Current iteration=650, loss=2415292.560007578
# Current iteration=675, loss=2415292.500554846
# Current iteration=700, loss=2415292.4708284833
# Current iteration=725, loss=2415292.455965304
# Current iteration=750, loss=2415292.4485337115
# Current iteration=775, loss=2415292.4448179165
# Current iteration=800, loss=2415292.442960021
# Current iteration=825, loss=2415292.442031072
# Current iteration=850, loss=2415292.441566597
# Current iteration=875, loss=2415292.441334359
# Current iteration=900, loss=2415292.4412182425
# Current iteration=925, loss=2415292.44116018
# Current iteration=950, loss=2415292.4411311513
# Current iteration=975, loss=2415292.441116637
# Current iteration=0, loss=158598225.4532211
# Current iteration=25, loss=6349856.1338375565
# Current iteration=50, loss=4967968.437690465
# Current iteration=75, loss=3470609.3398635495
# Current iteration=100, loss=2838960.529032198
# Current iteration=125, loss=2554706.065660764
# Current iteration=150, loss=2421387.997155554
# Current iteration=175, loss=2357304.754184303
# Current iteration=200, loss=2325787.6483953483
# Current iteration=225, loss=2310201.2659818963
# Current iteration=250, loss=2302462.9866775307
# Current iteration=275, loss=2298608.91666947
# Current iteration=300, loss=2296685.637899765
# Current iteration=325, loss=2295724.9763593604
# Current iteration=350, loss=2295244.886605344
# Current iteration=375, loss=2295004.9141345704
# Current iteration=400, loss=2294884.942760792
# Current iteration=425, loss=2294824.9606658653
# Current iteration=450, loss=2294794.9705165327
# Current iteration=475, loss=2294779.975666415
# Current iteration=500, loss=2294772.478297497
# Current iteration=525, loss=2294768.729627072
# Current iteration=550, loss=2294766.855295368
# Current iteration=575, loss=2294765.918130394
# Current iteration=600, loss=2294765.449548125
# Current iteration=625, loss=2294765.2152570486
# Current iteration=650, loss=2294765.098111521
# Current iteration=675, loss=2294765.039538764
# Current iteration=700, loss=2294765.010252386
# Current iteration=725, loss=2294764.9956091945
# Current iteration=750, loss=2294764.988287602
# Current iteration=775, loss=2294764.9846268017
# Current iteration=800, loss=2294764.982796404
# Current iteration=825, loss=2294764.9818812055
# Current iteration=850, loss=2294764.9814236043
# Current iteration=875, loss=2294764.9811948063
# Current iteration=900, loss=2294764.981080405
# Current iteration=925, loss=2294764.981023204
# Current iteration=950, loss=2294764.9809946064
# Current iteration=975, loss=2294764.980980304
# Current iteration=0, loss=158560995.86817282
# Current iteration=25, loss=6325203.3669534875
# Current iteration=50, loss=5048810.791376347
# Current iteration=75, loss=3535647.271603251
# Current iteration=100, loss=2899702.0809104317
# Current iteration=125, loss=2611769.295072902
# Current iteration=150, loss=2476536.058478401
# Current iteration=175, loss=2411715.559940254
# Current iteration=200, loss=2379815.8383179153
# Current iteration=225, loss=2363995.9125348735
# Current iteration=250, loss=2356126.231410258
# Current iteration=275, loss=2352201.8775113556
# Current iteration=300, loss=2350242.3004238857
# Current iteration=325, loss=2349263.15130897
# Current iteration=350, loss=2348773.749019564
# Current iteration=375, loss=2348529.0883476827
# Current iteration=400, loss=2348406.767546877
# Current iteration=425, loss=2348345.609528618
# Current iteration=450, loss=2348315.0311148167
# Current iteration=475, loss=2348299.742056722
# Current iteration=500, loss=2348292.0975648724
# Current iteration=525, loss=2348288.275328248
# Current iteration=550, loss=2348286.36421226
# Current iteration=575, loss=2348285.408654847
# Current iteration=600, loss=2348284.930876287
# Current iteration=625, loss=2348284.691987043
# Current iteration=650, loss=2348284.57254243
# Current iteration=675, loss=2348284.5128201265
# Current iteration=700, loss=2348284.4829589776
# Current iteration=725, loss=2348284.468028399
# Current iteration=750, loss=2348284.46056311
# Current iteration=775, loss=2348284.4568304666
# Current iteration=800, loss=2348284.4549641456
# Current iteration=825, loss=2348284.4540309827
# Current iteration=850, loss=2348284.4535644017
# Current iteration=875, loss=2348284.453331112
# Current iteration=900, loss=2348284.453214466
# Current iteration=925, loss=2348284.4531561434
# Current iteration=950, loss=2348284.4531269856
# Current iteration=975, loss=2348284.4531124076
# Current iteration=0, loss=158727937.4128258
# Current iteration=25, loss=6358011.724265254
# Current iteration=50, loss=4981123.36827094
# Current iteration=75, loss=3479458.4756533927
# Current iteration=100, loss=2837756.2722654818
# Current iteration=125, loss=2550473.3835733114
# Current iteration=150, loss=2416075.251440023
# Current iteration=175, loss=2351336.779321915
# Current iteration=200, loss=2319573.3864903366
# Current iteration=225, loss=2303816.692375767
# Current iteration=250, loss=2295969.338724251
# Current iteration=275, loss=2292053.891209044
# Current iteration=300, loss=2290098.3418540074
# Current iteration=325, loss=2289121.0995636564
# Current iteration=350, loss=2288632.6111640567
# Current iteration=375, loss=2288388.4010597295
# Current iteration=400, loss=2288266.3043425526
# Current iteration=425, loss=2288205.2580972174
# Current iteration=450, loss=2288174.7355164583
# Current iteration=475, loss=2288159.4743566643
# Current iteration=500, loss=2288151.8438094193
# Current iteration=525, loss=2288148.0285439603
# Current iteration=550, loss=2288146.120913272
# Current iteration=575, loss=2288145.167098438
# Current iteration=600, loss=2288144.69019115
# Current iteration=625, loss=2288144.4517375366
# Current iteration=650, loss=2288144.3325107363
# Current iteration=675, loss=2288144.272897338
# Current iteration=700, loss=2288144.24309064
# Current iteration=725, loss=2288144.228187291
# Current iteration=750, loss=2288144.2207356147
# Current iteration=775, loss=2288144.217009781
# Current iteration=800, loss=2288144.2151468587
# Current iteration=825, loss=2288144.2142153997
# Current iteration=850, loss=2288144.213749672
# Current iteration=875, loss=2288144.213516809
# Current iteration=900, loss=2288144.2134003765
# Current iteration=925, loss=2288144.21334216
# Current iteration=950, loss=2288144.2133130515
# Current iteration=975, loss=2288144.2132984977
# Current iteration=0, loss=158267709.81457016
# Current iteration=25, loss=6298716.006259563
# Current iteration=50, loss=4937801.397477454
# Current iteration=75, loss=3437134.711233355
# Current iteration=100, loss=2799555.0277328393
# Current iteration=125, loss=2512142.2653154763
# Current iteration=150, loss=2378229.334206587
# Current iteration=175, loss=2313957.3575191223
# Current iteration=200, loss=2282376.491194399
# Current iteration=225, loss=2266685.9736641087
# Current iteration=250, loss=2258865.835403556
# Current iteration=275, loss=2254962.6928698123
# Current iteration=300, loss=2253013.05411056
# Current iteration=325, loss=2252038.758472534
# Current iteration=350, loss=2251551.741589274
# Current iteration=375, loss=2251308.266085407
# Current iteration=400, loss=2251186.536150683
# Current iteration=425, loss=2251125.673143018
# Current iteration=450, loss=2251095.242129785
# Current iteration=475, loss=2251080.0267459014
# Current iteration=500, loss=2251072.4190846547
# Current iteration=525, loss=2251068.615261706
# Current iteration=550, loss=2251066.7133521503
# Current iteration=575, loss=2251065.7623978527
# Current iteration=600, loss=2251065.286920823
# Current iteration=625, loss=2251065.0491823414
# Current iteration=650, loss=2251064.9303131043
# Current iteration=675, loss=2251064.8708784874
# Current iteration=700, loss=2251064.8411611808
# Current iteration=725, loss=2251064.8263025284
# Current iteration=750, loss=2251064.8188732006
# Current iteration=775, loss=2251064.8151585385
# Current iteration=800, loss=2251064.8133012103
# Current iteration=825, loss=2251064.812372542
# Current iteration=850, loss=2251064.8119082088
# Current iteration=875, loss=2251064.8116760445
# Current iteration=900, loss=2251064.811559963
# Current iteration=925, loss=2251064.8115019216
# Current iteration=950, loss=2251064.811472901
# Current iteration=975, loss=2251064.811458387
# Current iteration=0, loss=158486069.240826
# Current iteration=25, loss=6352840.23088122
# Current iteration=50, loss=4927899.393113914
# Current iteration=75, loss=3392823.7775837686
# Current iteration=100, loss=2760759.315612245
# Current iteration=125, loss=2478537.0745632383
# Current iteration=150, loss=2346924.1855829586
# Current iteration=175, loss=2283294.8186318967
# Current iteration=200, loss=2252230.8565009893
# Current iteration=225, loss=2236918.83511895
# Current iteration=250, loss=2229317.486657351
# Current iteration=275, loss=2225529.98936998
# Current iteration=300, loss=2223639.5270636077
# Current iteration=325, loss=2222695.089565139
# Current iteration=350, loss=2222223.056887255
# Current iteration=375, loss=2221987.088519297
# Current iteration=400, loss=2221869.1157469233
# Current iteration=425, loss=2221810.1322100298
# Current iteration=450, loss=2221780.6411534543
# Current iteration=475, loss=2221765.895803078
# Current iteration=500, loss=2221758.5231723604
# Current iteration=525, loss=2221754.8368681185
# Current iteration=550, loss=2221752.993718777
# Current iteration=575, loss=2221752.0721448003
# Current iteration=600, loss=2221751.6113579855
# Current iteration=625, loss=2221751.380964623
# Current iteration=650, loss=2221751.2657679506
# Current iteration=675, loss=2221751.2081696186
# Current iteration=700, loss=2221751.179370454
# Current iteration=725, loss=2221751.16497087
# Current iteration=750, loss=2221751.1577710793
# Current iteration=775, loss=2221751.154171185
# Current iteration=800, loss=2221751.1523712366
# Current iteration=825, loss=2221751.151471265
# Current iteration=850, loss=2221751.151021275
# Current iteration=875, loss=2221751.150796283
# Current iteration=900, loss=2221751.150683787
# Current iteration=925, loss=2221751.1506275367
# Current iteration=950, loss=2221751.150599411
# Current iteration=975, loss=2221751.1505853524
# Current iteration=0, loss=158690841.13421887
# Current iteration=25, loss=6342946.438871058
# Current iteration=50, loss=4779363.490851891
# Current iteration=75, loss=3281969.7152719437
# Current iteration=100, loss=2647984.3856694032
# Current iteration=125, loss=2365162.155201646
# Current iteration=150, loss=2233918.2036687126
# Current iteration=175, loss=2171217.8999969508
# Current iteration=200, loss=2140799.986687437
# Current iteration=225, loss=2125763.990141357
# Current iteration=250, loss=2118282.9005652424
# Current iteration=275, loss=2114551.0601555575
# Current iteration=300, loss=2112687.27629911
# Current iteration=325, loss=2111755.9218458785
# Current iteration=350, loss=2111290.373972574
# Current iteration=375, loss=2111057.637635518
# Current iteration=400, loss=2110941.281425885
# Current iteration=425, loss=2110883.10526791
# Current iteration=450, loss=2110854.0176754645
# Current iteration=475, loss=2110839.474000855
# Current iteration=500, loss=2110832.2021939517
# Current iteration=525, loss=2110828.5662981
# Current iteration=550, loss=2110826.748352074
# Current iteration=575, loss=2110825.839379536
# Current iteration=600, loss=2110825.3848933876
# Current iteration=625, loss=2110825.1576503436
# Current iteration=650, loss=2110825.044028827
# Current iteration=675, loss=2110824.9872180736
# Current iteration=700, loss=2110824.9588126955
# Current iteration=725, loss=2110824.9446100076
# Current iteration=750, loss=2110824.937508662
# Current iteration=775, loss=2110824.93395799
# Current iteration=800, loss=2110824.9321826524
# Current iteration=825, loss=2110824.9312949865
# Current iteration=850, loss=2110824.93085115
# Current iteration=875, loss=2110824.9306292334
# Current iteration=900, loss=2110824.930518277
# Current iteration=925, loss=2110824.9304627962
# Current iteration=950, loss=2110824.9304350563
# Current iteration=975, loss=2110824.930421185
# Current iteration=0, loss=158653791.7368561
# Current iteration=25, loss=6315981.614401274
# Current iteration=50, loss=4884085.901004305
# Current iteration=75, loss=3342488.590169589
# Current iteration=100, loss=2704198.8882747227
# Current iteration=125, loss=2418118.808430104
# Current iteration=150, loss=2285251.9195261253
# Current iteration=175, loss=2221318.6197130713
# Current iteration=200, loss=2189983.7704910906
# Current iteration=225, loss=2174474.044368386
# Current iteration=250, loss=2166761.899725159
# Current iteration=275, loss=2162916.6358693945
# Current iteration=300, loss=2160996.7953878157
# Current iteration=325, loss=2160037.58018837
# Current iteration=350, loss=2159558.1469820803
# Current iteration=375, loss=2159318.4700949723
# Current iteration=400, loss=2159198.641500342
# Current iteration=425, loss=2159138.729664476
# Current iteration=450, loss=2159108.7743618065
# Current iteration=475, loss=2159093.796864276
# Current iteration=500, loss=2159086.3081539595
# Current iteration=525, loss=2159082.563808413
# Current iteration=550, loss=2159080.691638043
# Current iteration=575, loss=2159079.7555534593
# Current iteration=600, loss=2159079.2875113175
# Current iteration=625, loss=2159079.053490282
# Current iteration=650, loss=2159078.936479775
# Current iteration=675, loss=2159078.8779745237
# Current iteration=700, loss=2159078.848721899
# Current iteration=725, loss=2159078.834095586
# Current iteration=750, loss=2159078.8267824277
# Current iteration=775, loss=2159078.823125852
# Current iteration=800, loss=2159078.8212975627
# Current iteration=825, loss=2159078.8203834174
# Current iteration=850, loss=2159078.8199263443
# Current iteration=875, loss=2159078.819697807
# Current iteration=900, loss=2159078.819583541
# Current iteration=925, loss=2159078.819526407
# Current iteration=950, loss=2159078.8194978423
# Current iteration=975, loss=2159078.819483557
# Current iteration=0, loss=158820821.95481956
# Current iteration=25, loss=6349324.410409937
# Current iteration=50, loss=4815295.085567025
# Current iteration=75, loss=3287446.031849873
# Current iteration=100, loss=2644357.1140046194
# Current iteration=125, loss=2359543.02453272
# Current iteration=150, loss=2227156.494621174
# Current iteration=175, loss=2163465.2664765636
# Current iteration=200, loss=2132380.064394381
# Current iteration=225, loss=2117060.3435952896
# Current iteration=250, loss=2109453.194510135
# Current iteration=275, loss=2105662.18393738
# Current iteration=300, loss=2103769.91518389
# Current iteration=325, loss=2102824.5471927584
# Current iteration=350, loss=2102352.055237239
# Current iteration=375, loss=2102115.8536975146
# Current iteration=400, loss=2101997.7640118706
# Current iteration=425, loss=2101938.7219369374
# Current iteration=450, loss=2101909.2015910456
# Current iteration=475, loss=2101894.4415909452
# Current iteration=500, loss=2101887.0616341
# Current iteration=525, loss=2101883.371666478
# Current iteration=550, loss=2101881.5266853673
# Current iteration=575, loss=2101880.6041954868
# Current iteration=600, loss=2101880.1429507146
# Current iteration=625, loss=2101879.912328371
# Current iteration=650, loss=2101879.797017211
# Current iteration=675, loss=2101879.7393616335
# Current iteration=700, loss=2101879.710533846
# Current iteration=725, loss=2101879.6961199483
# Current iteration=750, loss=2101879.688913002
# Current iteration=775, loss=2101879.6853095274
# Current iteration=800, loss=2101879.68350779
# Current iteration=825, loss=2101879.6826069206
# Current iteration=850, loss=2101879.682156489
# Current iteration=875, loss=2101879.681931272
# Current iteration=900, loss=2101879.6818186613
# Current iteration=925, loss=2101879.6817623596
# Current iteration=950, loss=2101879.6817342066
# Current iteration=975, loss=2101879.6817201306
# Current iteration=0, loss=158360159.28411558
# Current iteration=25, loss=6293102.166115094
# Current iteration=50, loss=4791500.585450059
# Current iteration=75, loss=3250353.892762942
# Current iteration=100, loss=2609575.4563836805
# Current iteration=125, loss=2324791.154361027
# Current iteration=150, loss=2193279.65005263
# Current iteration=175, loss=2129785.3871806725
# Current iteration=200, loss=2098770.266158743
# Current iteration=225, loss=2083474.610270373
# Current iteration=250, loss=2075879.0825123545
# Current iteration=275, loss=2072094.446176947
# Current iteration=300, loss=2070205.2686481962
# Current iteration=325, loss=2069261.4465784149
# Current iteration=350, loss=2068789.7296619713
# Current iteration=375, loss=2068553.920303579
# Current iteration=400, loss=2068436.0278172768
# Current iteration=425, loss=2068377.0845260965
# Current iteration=450, loss=2068347.6136182852
# Current iteration=475, loss=2068332.8783487966
# Current iteration=500, loss=2068325.5107601539
# Current iteration=525, loss=2068321.8269773568
# Current iteration=550, loss=2068319.9850888401
# Current iteration=575, loss=2068319.0641453015
# Current iteration=600, loss=2068318.6036737124
# Current iteration=625, loss=2068318.3734379602
# Current iteration=650, loss=2068318.258320099
# Current iteration=675, loss=2068318.2007611685
# Current iteration=700, loss=2068318.1719817035
# Current iteration=725, loss=2068318.1575919744
# Current iteration=750, loss=2068318.150397106
# Current iteration=775, loss=2068318.146799676
# Current iteration=800, loss=2068318.1450009574
# Current iteration=825, loss=2068318.144101598
# Current iteration=850, loss=2068318.1436519183
# Current iteration=875, loss=2068318.1434270795
# Current iteration=900, loss=2068318.1433146591
# Current iteration=925, loss=2068318.1432584503
# Current iteration=950, loss=2068318.143230344
# Current iteration=975, loss=2068318.143216292
# Current iteration=0, loss=158578502.85230502
# Current iteration=25, loss=6346807.988261069
# Current iteration=50, loss=4749625.973131371
# Current iteration=75, loss=3207683.9534139205
# Current iteration=100, loss=2573745.8118656157
# Current iteration=125, loss=2293942.18990691
# Current iteration=150, loss=2164095.0530934366
# Current iteration=175, loss=2102384.408726011
# Current iteration=200, loss=2072238.5342721064
# Current iteration=225, loss=2057310.0685529127
# Current iteration=250, loss=2049882.8745009839
# Current iteration=275, loss=2046178.5130643384
# Current iteration=300, loss=2044328.561120914
# Current iteration=325, loss=2043404.1167965108
# Current iteration=350, loss=2042942.0261391103
# Current iteration=375, loss=2042711.0133047383
# Current iteration=400, loss=2042595.5150040623
# Current iteration=425, loss=2042537.7678819704
# Current iteration=450, loss=2042508.8948278755
# Current iteration=475, loss=2042494.458427552
# Current iteration=500, loss=2042487.24025907
# Current iteration=525, loss=2042483.6311827481
# Current iteration=550, loss=2042481.8266465678
# Current iteration=575, loss=2042480.924378972
# Current iteration=600, loss=2042480.4732452987
# Current iteration=625, loss=2042480.2476784913
# Current iteration=650, loss=2042480.1348950944
# Current iteration=675, loss=2042480.0785033994
# Current iteration=700, loss=2042480.0503075516
# Current iteration=725, loss=2042480.0362096264
# Current iteration=750, loss=2042480.0291606642
# Current iteration=775, loss=2042480.025636184
# Current iteration=800, loss=2042480.023873941
# Current iteration=825, loss=2042480.0229928216
# Current iteration=850, loss=2042480.0225522632
# Current iteration=875, loss=2042480.0223319838
# Current iteration=900, loss=2042480.022221845
# Current iteration=925, loss=2042480.0221667746
# Current iteration=950, loss=2042480.0221392373
# Current iteration=975, loss=2042480.022125469
# Current iteration=0, loss=158783471.5841189
# Current iteration=25, loss=6339025.338812881
# Current iteration=50, loss=4563798.948812551
# Current iteration=75, loss=3103438.084446892
# Current iteration=100, loss=2467379.095815102
# Current iteration=125, loss=2187875.0996607374
# Current iteration=150, loss=2059758.7772678547
# Current iteration=175, loss=1998990.0011232318
# Current iteration=200, loss=1969144.4045738126
# Current iteration=225, loss=1954347.313610205
# Current iteration=250, loss=1946984.4572927714
# Current iteration=275, loss=1943312.914348521
# Current iteration=300, loss=1941479.6447016913
# Current iteration=325, loss=1940563.6264523782
# Current iteration=350, loss=1940105.7765304076
# Current iteration=375, loss=1939876.8944536974
# Current iteration=400, loss=1939762.463239799
# Current iteration=425, loss=1939705.2500566093
# Current iteration=450, loss=1939676.6440712176
# Current iteration=475, loss=1939662.3412301054
# Current iteration=500, loss=1939655.189847449
# Current iteration=525, loss=1939651.614165596
# Current iteration=550, loss=1939649.8263270385
# Current iteration=575, loss=1939648.9324083517
# Current iteration=600, loss=1939648.4854491565
# Current iteration=625, loss=1939648.2619695978
# Current iteration=650, loss=1939648.1502298273
# Current iteration=675, loss=1939648.094359942
# Current iteration=700, loss=1939648.0664250026
# Current iteration=725, loss=1939648.052457532
# Current iteration=750, loss=1939648.0454737984
# Current iteration=775, loss=1939648.0419819304
# Current iteration=800, loss=1939648.040235999
# Current iteration=825, loss=1939648.0393630306
# Current iteration=850, loss=1939648.0389265488
# Current iteration=875, loss=1939648.0387083043
# Current iteration=900, loss=1939648.038599185
# Current iteration=925, loss=1939648.0385446243
# Current iteration=950, loss=1939648.0385173426
# Current iteration=975, loss=1939648.038503703
# Current iteration=0, loss=158746602.37525252
# Current iteration=25, loss=6318423.677790846
# Current iteration=50, loss=4727075.928834043
# Current iteration=75, loss=3162896.089212201
# Current iteration=100, loss=2523674.8853705837
# Current iteration=125, loss=2240397.8244801443
# Current iteration=150, loss=2109703.921571691
# Current iteration=175, loss=2047071.393159979
# Current iteration=200, loss=2016487.9579976215
# Current iteration=225, loss=2001384.9943702803
# Current iteration=250, loss=1993876.180781835
# Current iteration=275, loss=1990131.4093509759
# Current iteration=300, loss=1988261.5701455348
# Current iteration=325, loss=1987327.239094049
# Current iteration=350, loss=1986860.214683925
# Current iteration=375, loss=1986626.739358734
# Current iteration=400, loss=1986510.010543688
# Current iteration=425, loss=1986451.648322424
# Current iteration=450, loss=1986422.4677582732
# Current iteration=475, loss=1986407.8776128066
# Current iteration=500, loss=1986400.5825742257
# Current iteration=525, loss=1986396.935063473
# Current iteration=550, loss=1986395.1113102308
# Current iteration=575, loss=1986394.1994341433
# Current iteration=600, loss=1986393.743496235
# Current iteration=625, loss=1986393.5155273145
# Current iteration=650, loss=1986393.4015428615
# Current iteration=675, loss=1986393.3445506387
# Current iteration=700, loss=1986393.3160545286
# Current iteration=725, loss=1986393.3018064701
# Current iteration=750, loss=1986393.2946824424
# Current iteration=775, loss=1986393.2911204267
# Current iteration=800, loss=1986393.2893394218
# Current iteration=825, loss=1986393.2884489167
# Current iteration=850, loss=1986393.2880036647
# Current iteration=875, loss=1986393.287781038
# Current iteration=900, loss=1986393.2876697266
# Current iteration=925, loss=1986393.2876140717
# Current iteration=950, loss=1986393.28758624
# Current iteration=975, loss=1986393.2875723264
# Current iteration=0, loss=158913721.2689548
# Current iteration=25, loss=6343152.561749645
# Current iteration=50, loss=4657308.2488218425
# Current iteration=75, loss=3105433.1053910614
# Current iteration=100, loss=2462911.1227312335
# Current iteration=125, loss=2181244.20494893
# Current iteration=150, loss=2051390.7429009315
# Current iteration=175, loss=1989718.6903319075
# Current iteration=200, loss=1959620.583840678
# Current iteration=225, loss=1944736.7109668315
# Current iteration=250, loss=1937336.4748381036
# Current iteration=275, loss=1933646.901449441
# Current iteration=300, loss=1931804.7375779578
# Current iteration=325, loss=1930884.3353439036
# Current iteration=350, loss=1930424.2985952105
# Current iteration=375, loss=1930194.3209916546
# Current iteration=400, loss=1930079.3423912253
# Current iteration=425, loss=1930021.8556424186
# Current iteration=450, loss=1929993.1129060022
# Current iteration=475, loss=1929978.7416973067
# Current iteration=500, loss=1929971.5561328395
# Current iteration=525, loss=1929967.9633605762
# Current iteration=550, loss=1929966.166976936
# Current iteration=575, loss=1929965.2687857402
# Current iteration=600, loss=1929964.819690296
# Current iteration=625, loss=1929964.5951426122
# Current iteration=650, loss=1929964.482868783
# Current iteration=675, loss=1929964.4267318696
# Current iteration=700, loss=1929964.3986634149
# Current iteration=725, loss=1929964.3846291834
# Current iteration=750, loss=1929964.3776120697
# Current iteration=775, loss=1929964.374103513
# Current iteration=800, loss=1929964.3723492352
# Current iteration=825, loss=1929964.3714720975
# Current iteration=850, loss=1929964.3710335288
# Current iteration=875, loss=1929964.370814245
# Current iteration=900, loss=1929964.3707045985
# Current iteration=925, loss=1929964.3706497774
# Current iteration=950, loss=1929964.3706223657
# Current iteration=975, loss=1929964.3706086632
# Current iteration=0, loss=158452623.50340465
# Current iteration=25, loss=6287551.948955842
# Current iteration=50, loss=4690693.767875544
# Current iteration=75, loss=3070042.483174648
# Current iteration=100, loss=2429638.74818919
# Current iteration=125, loss=2148701.9361635013
# Current iteration=150, loss=2019349.853975444
# Current iteration=175, loss=1957800.244077424
# Current iteration=200, loss=1927768.804660296
# Current iteration=225, loss=1912899.7803262158
# Current iteration=250, loss=1905500.795828193
# Current iteration=275, loss=1901810.1487078012
# Current iteration=300, loss=1899966.9978159603
# Current iteration=325, loss=1899045.9758178852
# Current iteration=350, loss=1898585.5990037967
# Current iteration=375, loss=1898355.4437363297
# Current iteration=400, loss=1898240.374796275
# Current iteration=425, loss=1898182.8429099568
# Current iteration=450, loss=1898154.0775329485
# Current iteration=475, loss=1898139.6949739787
# Current iteration=500, loss=1898132.5037268784
# Current iteration=525, loss=1898128.9081114242
# Current iteration=550, loss=1898127.1103057216
# Current iteration=575, loss=1898126.211403376
# Current iteration=600, loss=1898125.7619523304
# Current iteration=625, loss=1898125.5372268376
# Current iteration=650, loss=1898125.4248641003
# Current iteration=675, loss=1898125.3686827337
# Current iteration=700, loss=1898125.3405920523
# Current iteration=725, loss=1898125.3265467095
# Current iteration=750, loss=1898125.3195240363
# Current iteration=775, loss=1898125.3160127022
# Current iteration=800, loss=1898125.3142570313
# Current iteration=825, loss=1898125.3133791983
# Current iteration=850, loss=1898125.312940283
# Current iteration=875, loss=1898125.3127208257
# Current iteration=900, loss=1898125.3126110937
# Current iteration=925, loss=1898125.3125562295
# Current iteration=950, loss=1898125.3125287972
# Current iteration=975, loss=1898125.3125150804
# Current iteration=0, loss=158670951.22279683
# Current iteration=25, loss=6337940.9389962265
# Current iteration=50, loss=4541318.990779331
# Current iteration=75, loss=3029332.431075348
# Current iteration=100, loss=2393707.1544192736
# Current iteration=125, loss=2117699.304088811
# Current iteration=150, loss=1991496.6854342096
# Current iteration=175, loss=1931264.6897464225
# Current iteration=200, loss=1901715.8531626961
# Current iteration=225, loss=1887066.2718102657
# Current iteration=250, loss=1879773.1432244484
# Current iteration=275, loss=1876134.3199858202
# Current iteration=300, loss=1874316.83873866
# Current iteration=325, loss=1873408.578567232
# Current iteration=350, loss=1872954.5653375469
# Current iteration=375, loss=1872727.5900072006
# Current iteration=400, loss=1872614.1100153343
# Current iteration=425, loss=1872557.3719059194
# Current iteration=450, loss=1872529.0033020843
# Current iteration=475, loss=1872514.8191128932
# Current iteration=500, loss=1872507.72704648
# Current iteration=525, loss=1872504.1810203188
# Current iteration=550, loss=1872502.4080089997
# Current iteration=575, loss=1872501.5215037803
# Current iteration=600, loss=1872501.0782512801
# Current iteration=625, loss=1872500.856625057
# Current iteration=650, loss=1872500.7458119525
# Current iteration=675, loss=1872500.6904054005
# Current iteration=700, loss=1872500.662702127
# Current iteration=725, loss=1872500.6488504899
# Current iteration=750, loss=1872500.641924671
# Current iteration=775, loss=1872500.6384617619
# Current iteration=800, loss=1872500.6367303098
# Current iteration=825, loss=1872500.6358645791
# Current iteration=850, loss=1872500.6354317167
# Current iteration=875, loss=1872500.6352152845
# Current iteration=900, loss=1872500.6351070702
# Current iteration=925, loss=1872500.6350529622
# Current iteration=950, loss=1872500.6350259073
# Current iteration=975, loss=1872500.6350123796
# Current iteration=0, loss=158876116.80497026
# Current iteration=25, loss=6342012.9990616515
# Current iteration=50, loss=4335599.929323752
# Current iteration=75, loss=2949167.120765361
# Current iteration=100, loss=2298215.460962447
# Current iteration=125, loss=2023202.0820626717
# Current iteration=150, loss=1898874.3654051714
# Current iteration=175, loss=1839202.6158743498
# Current iteration=200, loss=1810073.863940663
# Current iteration=225, loss=1795675.470353003
# Current iteration=250, loss=1788513.5921757193
# Current iteration=275, loss=1784941.826259222
# Current iteration=300, loss=1783158.1622432873
# Current iteration=325, loss=1782266.8811798417
# Current iteration=350, loss=1781821.3776045847
# Current iteration=375, loss=1781598.6601096634
# Current iteration=400, loss=1781487.310672987
# Current iteration=425, loss=1781431.6383321912
# Current iteration=450, loss=1781403.8026815928
# Current iteration=475, loss=1781389.8849862337
# Current iteration=500, loss=1781382.926171038
# Current iteration=525, loss=1781379.4467715614
# Current iteration=550, loss=1781377.7070738531
# Current iteration=575, loss=1781376.8372255063
# Current iteration=600, loss=1781376.40230146
# Current iteration=625, loss=1781376.184839468
# Current iteration=650, loss=1781376.0761084782
# Current iteration=675, loss=1781376.0217429856
# Current iteration=700, loss=1781375.9945602426
# Current iteration=725, loss=1781375.980968871
# Current iteration=750, loss=1781375.9741731824
# Current iteration=775, loss=1781375.970775339
# Current iteration=800, loss=1781375.969076418
# Current iteration=825, loss=1781375.9682269555
# Current iteration=850, loss=1781375.9678022282
# Current iteration=875, loss=1781375.967589863
# Current iteration=900, loss=1781375.9674836828
# Current iteration=925, loss=1781375.9674305911
# Current iteration=950, loss=1781375.9674040466
# Current iteration=975, loss=1781375.9673907738
# Current iteration=0, loss=158839427.78541133
# Current iteration=25, loss=6316089.746810408
# Current iteration=50, loss=4564286.948207087
# Current iteration=75, loss=2987610.020064615
# Current iteration=100, loss=2349162.7697169185
# Current iteration=125, loss=2070132.7891447458
# Current iteration=150, loss=1942352.6707931126
# Current iteration=175, loss=1881498.1276072836
# Current iteration=200, loss=1851783.0995810158
# Current iteration=225, loss=1837121.1770584765
# Current iteration=250, loss=1829835.3706838589
# Current iteration=275, loss=1826202.872865117
# Current iteration=300, loss=1824389.2860953496
# Current iteration=325, loss=1823483.1188806884
# Current iteration=350, loss=1823030.1843161953
# Current iteration=375, loss=1822803.7540251084
# Current iteration=400, loss=1822690.5480481149
# Current iteration=425, loss=1822633.947349435
# Current iteration=450, loss=1822605.6475722603
# Current iteration=475, loss=1822591.4978266777
# Current iteration=500, loss=1822584.4229896332
# Current iteration=525, loss=1822580.8855800468
# Current iteration=550, loss=1822579.1168774879
# Current iteration=575, loss=1822578.2325267668
# Current iteration=600, loss=1822577.7903515466
# Current iteration=625, loss=1822577.5692639719
# Current iteration=650, loss=1822577.458720192
# Current iteration=675, loss=1822577.4034483046
# Current iteration=700, loss=1822577.3758123594
# Current iteration=725, loss=1822577.361994388
# Current iteration=750, loss=1822577.3550854016
# Current iteration=775, loss=1822577.3516309063
# Current iteration=800, loss=1822577.3499036606
# Current iteration=825, loss=1822577.3490400375
# Current iteration=850, loss=1822577.3486082274
# Current iteration=875, loss=1822577.3483923224
# Current iteration=900, loss=1822577.3482843696
# Current iteration=925, loss=1822577.348230393
# Current iteration=950, loss=1822577.348203406
# Current iteration=975, loss=1822577.3481899097
# Current iteration=0, loss=159006635.35728085
# Current iteration=25, loss=6340545.365644486
# Current iteration=50, loss=4525987.820228138
# Current iteration=75, loss=2932093.2220414532
# Current iteration=100, loss=2291629.460514074
# Current iteration=125, loss=2014399.3822116163
# Current iteration=150, loss=1888292.5877016422
# Current iteration=175, loss=1828357.0197070504
# Current iteration=200, loss=1799129.570614346
# Current iteration=225, loss=1784697.1083496162
# Current iteration=250, loss=1777524.7592554474
# Current iteration=275, loss=1773949.6204909098
# Current iteration=300, loss=1772164.6854290257
# Current iteration=325, loss=1771272.8620493042
# Current iteration=350, loss=1770827.1086374486
# Current iteration=375, loss=1770604.2711093961
# Current iteration=400, loss=1770492.8621677274
# Current iteration=425, loss=1770437.1601041562
# Current iteration=450, loss=1770409.3096740062
# Current iteration=475, loss=1770395.3846093183
# Current iteration=500, loss=1770388.4221145683
# Current iteration=525, loss=1770384.9408765913
# Current iteration=550, loss=1770383.2002599523
# Current iteration=575, loss=1770382.32995222
# Current iteration=600, loss=1770381.894798501
# Current iteration=625, loss=1770381.6772216773
# Current iteration=650, loss=1770381.5684332778
# Current iteration=675, loss=1770381.5140390785
# Current iteration=700, loss=1770381.4868419804
# Current iteration=725, loss=1770381.4732434298
# Current iteration=750, loss=1770381.466444154
# Current iteration=775, loss=1770381.4630445146
# Current iteration=800, loss=1770381.4613446966
# Current iteration=825, loss=1770381.46049479
# Current iteration=850, loss=1770381.460069835
# Current iteration=875, loss=1770381.4598573567
# Current iteration=900, loss=1770381.4597511191
# Current iteration=925, loss=1770381.4596979988
# Current iteration=950, loss=1770381.4596714405
# Current iteration=975, loss=1770381.45965816
# Current iteration=0, loss=158545102.4744866
# Current iteration=25, loss=6285663.236932458
# Current iteration=50, loss=4715345.394597139
# Current iteration=75, loss=2871105.3924368536
# Current iteration=100, loss=2260830.4656369546
# Current iteration=125, loss=1984701.6013912505
# Current iteration=150, loss=1858831.9270393949
# Current iteration=175, loss=1798848.9532150906
# Current iteration=200, loss=1769461.798398276
# Current iteration=225, loss=1754915.4991819852
# Current iteration=250, loss=1747680.5057767825
# Current iteration=275, loss=1744072.7666067383
# Current iteration=300, loss=1742271.3865939162
# Current iteration=325, loss=1741371.3021828616
# Current iteration=350, loss=1740921.4084955195
# Current iteration=375, loss=1740696.5052624538
# Current iteration=400, loss=1740584.0639843908
# Current iteration=425, loss=1740527.8455808389
# Current iteration=450, loss=1740499.7369379073
# Current iteration=475, loss=1740485.6827561494
# Current iteration=500, loss=1740478.6557001967
# Current iteration=525, loss=1740475.1421809527
# Current iteration=550, loss=1740473.3854235131
# Current iteration=575, loss=1740472.5070453396
# Current iteration=600, loss=1740472.0678563886
# Current iteration=625, loss=1740471.8482619468
# Current iteration=650, loss=1740471.7384647338
# Current iteration=675, loss=1740471.6835661302
# Current iteration=700, loss=1740471.6561168258
# Current iteration=725, loss=1740471.642392177
# Current iteration=750, loss=1740471.6355298504
# Current iteration=775, loss=1740471.6320986866
# Current iteration=800, loss=1740471.6303831062
# Current iteration=825, loss=1740471.6295253183
# Current iteration=850, loss=1740471.6290964216
# Current iteration=875, loss=1740471.6288819741
# Current iteration=900, loss=1740471.6287747486
# Current iteration=925, loss=1740471.628721138
# Current iteration=950, loss=1740471.6286943345
# Current iteration=975, loss=1740471.6286809298
# Current iteration=0, loss=158763414.35435066
# Current iteration=25, loss=6331522.256650314
# Current iteration=50, loss=4273985.365967261
# Current iteration=75, loss=2897172.593713357
# Current iteration=100, loss=2223436.6593911382
# Current iteration=125, loss=1952666.3944683138
# Current iteration=150, loss=1829867.496014923
# Current iteration=175, loss=1770812.232735124
# Current iteration=200, loss=1741829.1344689163
# Current iteration=225, loss=1727472.2420598834
# Current iteration=250, loss=1720328.0444534074
# Current iteration=275, loss=1716764.688399604
# Current iteration=300, loss=1714985.191426245
# Current iteration=325, loss=1714095.983527175
# Current iteration=350, loss=1713651.512411241
# Current iteration=375, loss=1713429.309776153
# Current iteration=400, loss=1713318.2170368575
# Current iteration=425, loss=1713262.6727039875
# Current iteration=450, loss=1713234.901046776
# Current iteration=475, loss=1713221.0153454798
# Current iteration=500, loss=1713214.0725266596
# Current iteration=525, loss=1713210.6011252066
# Current iteration=550, loss=1713208.8654264694
# Current iteration=575, loss=1713207.9975775979
# Current iteration=600, loss=1713207.5636532872
# Current iteration=625, loss=1713207.3466911626
# Current iteration=650, loss=1713207.238210109
# Current iteration=675, loss=1713207.1839695862
# Current iteration=700, loss=1713207.1568493207
# Current iteration=725, loss=1713207.1432891905
# Current iteration=750, loss=1713207.1365091233
# Current iteration=775, loss=1713207.133119093
# Current iteration=800, loss=1713207.1314240738
# Current iteration=825, loss=1713207.1305765659
# Current iteration=850, loss=1713207.1301528146
# Current iteration=875, loss=1713207.1299409382
# Current iteration=900, loss=1713207.1298350012
# Current iteration=925, loss=1713207.1297820313
# Current iteration=950, loss=1713207.129755543
# Current iteration=975, loss=1713207.1297423008
# [3. 3. 3. 3. 3. 3. 3. 3. 3. 3. 3. 3. 3. 3. 3.]

# %%
tX_tilda_0_augmented = build_poly(tX_tilda_0, degree = 2)
_, w_logistic_0 = learning_by_penalized_gradient(y_0, tX_tilda_0_augmented, np.zeros(tX_tilda_0_augmented.shape[1]), 0.00017783,
                                              1000, lambda_= 1)
# Out:
# Current iteration=0, loss=11953934.476351794
# Current iteration=25, loss=2158248.8743964396
# Current iteration=50, loss=1722482.836902358
# Current iteration=75, loss=363118.27443768654
# Current iteration=100, loss=496359.83224441216
# Current iteration=125, loss=259976.8148791658
# Current iteration=150, loss=250660.28359415938
# Current iteration=175, loss=247461.42959845066
# Current iteration=200, loss=246103.08936854175
# Current iteration=225, loss=245474.6445080386
# Current iteration=250, loss=245172.08603055903
# Current iteration=275, loss=245023.62401411208
# Current iteration=300, loss=244950.0839955155
# Current iteration=325, loss=244913.48553876905
# Current iteration=350, loss=244895.22882598487
# Current iteration=375, loss=244886.11110982095
# Current iteration=400, loss=244881.55489208575
# Current iteration=425, loss=244879.27744473773
# Current iteration=450, loss=244878.13888509176
# Current iteration=475, loss=244877.5696462698
# Current iteration=500, loss=244877.2850371083
# Current iteration=525, loss=244877.14273508982
# Current iteration=550, loss=244877.07158472115
# Current iteration=575, loss=244877.03600969698
# Current iteration=600, loss=244877.0182222249
# Current iteration=625, loss=244877.0093284989
# Current iteration=650, loss=244877.00488163836
# Current iteration=675, loss=244877.00265820872
# Current iteration=700, loss=244877.00154649417
# Current iteration=725, loss=244877.0009906367
# Current iteration=750, loss=244877.00071270796
# Current iteration=775, loss=244877.0005737437
# Current iteration=800, loss=244877.00050426173
# Current iteration=825, loss=244877.0004695205
# Current iteration=850, loss=244877.00045215
# Current iteration=875, loss=244877.00044346473
# Current iteration=900, loss=244877.00043912203
# Current iteration=925, loss=244877.00043695077
# Current iteration=950, loss=244877.000435865
# Current iteration=975, loss=244877.00043532232

# %%
tX_tilda_1_augmented = build_poly(tX_tilda_1, degree = 2)
_, w_logistic_1 = learning_by_penalized_gradient(y_1, tX_tilda_1_augmented, np.zeros(tX_tilda_1_augmented.shape[1]), 0.00316228,
                                              1000, lambda_= 1)
# Out:
# Current iteration=0, loss=97528994.86257344
# Current iteration=25, loss=21448681.301449835
# Current iteration=50, loss=35952517.29871229
# Current iteration=75, loss=7823474.3219228815
# Current iteration=100, loss=5396602.07363074
# Current iteration=125, loss=4527245.881317648
# Current iteration=150, loss=4150793.1954980674
# Current iteration=175, loss=3972898.49236086
# Current iteration=200, loss=3886154.8912532264
# Current iteration=225, loss=3843336.6624230887
# Current iteration=250, loss=3822062.7905500294
# Current iteration=275, loss=3811459.0964384326
# Current iteration=300, loss=3806165.549028915
# Current iteration=325, loss=3803520.877948297
# Current iteration=350, loss=3802199.068186434
# Current iteration=375, loss=3801538.3088100343
# Current iteration=400, loss=3801207.9619047805
# Current iteration=425, loss=3801042.797392721
# Current iteration=450, loss=3800960.217079512
# Current iteration=475, loss=3800918.9274086137
# Current iteration=500, loss=3800898.2826945907
# Current iteration=525, loss=3800887.960367936
# Current iteration=550, loss=3800882.7992121973
# Current iteration=575, loss=3800880.218636226
# Current iteration=600, loss=3800878.928348715
# Current iteration=625, loss=3800878.283205079
# Current iteration=650, loss=3800877.9606332905
# Current iteration=675, loss=3800877.7993474044
# Current iteration=700, loss=3800877.7187044625
# Current iteration=725, loss=3800877.6783829927
# Current iteration=750, loss=3800877.6582222586
# Current iteration=775, loss=3800877.6481418917
# Current iteration=800, loss=3800877.6431017094
# Current iteration=825, loss=3800877.6405816157
# Current iteration=850, loss=3800877.6393215717
# Current iteration=875, loss=3800877.6386915464
# Current iteration=900, loss=3800877.638376538
# Current iteration=925, loss=3800877.6382190287
# Current iteration=950, loss=3800877.6381402765
# Current iteration=975, loss=3800877.6381008974

# %%
tX_tilda_2_3_augmented = build_poly(tX_tilda_2_3, degree = 2)
_, w_logistic_2_3 = learning_by_penalized_gradient(y_2_3, tX_tilda_2_3_augmented, np.zeros(tX_tilda_2_3_augmented.shape[1]),
                                                0.00017783, 1000, lambda_= 1)
# Out:
# Current iteration=0, loss=2453244.116292915
# Current iteration=25, loss=989535.5546252584
# Current iteration=50, loss=806125.0565594207
# Current iteration=75, loss=581981.4053180196
# Current iteration=100, loss=488802.3440732876
# Current iteration=125, loss=447518.271415908
# Current iteration=150, loss=428320.1704786562
# Current iteration=175, loss=419093.0935594835
# Current iteration=200, loss=414573.47664509027
# Current iteration=225, loss=412337.0818380339
# Current iteration=250, loss=411224.6590439237
# Current iteration=275, loss=410669.90052402986
# Current iteration=300, loss=410392.89775151823
# Current iteration=325, loss=410254.4884272579
# Current iteration=350, loss=410185.3061831723
# Current iteration=375, loss=410150.7207928524
# Current iteration=400, loss=410133.4295635018
# Current iteration=425, loss=410124.78436442604
# Current iteration=450, loss=410120.4618575789
# Current iteration=475, loss=410118.30062555155
# Current iteration=500, loss=410117.22001488693
# Current iteration=525, loss=410116.67971089185
# Current iteration=550, loss=410116.4095592287
# Current iteration=575, loss=410116.2744834808
# Current iteration=600, loss=410116.20694562764
# Current iteration=625, loss=410116.17317670654
# Current iteration=650, loss=410116.15629224683
# Current iteration=675, loss=410116.14785001776
# Current iteration=700, loss=410116.1436289033
# Current iteration=725, loss=410116.14151834615
# Current iteration=750, loss=410116.14046306745
# Current iteration=775, loss=410116.13993542775
# Current iteration=800, loss=410116.1396716078
# Current iteration=825, loss=410116.13953969814
# Current iteration=850, loss=410116.1394737431
# Current iteration=875, loss=410116.13944076566
# Current iteration=900, loss=410116.1394242773
# Current iteration=925, loss=410116.1394160328
# Current iteration=950, loss=410116.1394119107
# Current iteration=975, loss=410116.1394098492

# %%
### Generate predictions and save ouput in csv format for submission:

# %%
DATA_TEST_PATH = '../data/test.csv' # TODO: download train data and supply path here 
_, tX_test, ids_test = load_csv_data(DATA_TEST_PATH)

# %%
print(tX_test.shape)
# Out:
# (568238, 30)

# %% [markdown]
# We will now format the tX_test as we did for tX_train

# %% [markdown]
# ### we split the test into the three subgroups

# %%
zero_indices = []
one_indices = []
two_three_indices = []
zero_indices = np.where(tX_test[:,22]==0)[0]
one_indices = np.where(tX_test[:,22]==1)[0]
two_three_indices = np.where(np.logical_or(tX_test[:,22]==2, tX_test[:,22]==3))[0]
tX_test_0 = tX_test[zero_indices, :]
tX_test_0 = np.delete(tX_test_0, 22, axis=1)
tX_test_1 = tX_test[one_indices, :]
tX_test_1 = np.delete(tX_test_1, 22, axis=1)
tX_test_2_3 = tX_test[two_three_indices, :]

# %% [markdown]
# ### Adding a column of zeros and ones to detect whether the mass has been measured or not

# %%
# take the indices where the mass is not calculated, add the column which has 0 in those indices
# and 1 everywhere else for all matrices 0,1,2_3
zero_indices_0 = np.where(tX_test_0[:,1] == -999.)[0]
column_to_add = np.array([0 if i in zero_indices_0 else 1 for i in range(tX_test_0.shape[0])])
tX_test_0 = np.insert(tX_test_0, 0, column_to_add, axis=1)
zero_indices_1 = np.where(tX_test_1[:,1] == -999.)[0]
column_to_add = np.array([0 if i in zero_indices_1 else 1 for i in range(tX_test_1.shape[0])])
tX_test_1 = np.insert(tX_test_1, 0, column_to_add, axis=1)
zero_indices_2_3 = np.where(tX_test_2_3[:,1] == -999.)[0]
column_to_add = np.array([0 if i in zero_indices_2_3 else 1 for i in range(tX_test_2_3.shape[0])])
tX_test_2_3 = np.insert(tX_test_2_3, 0, column_to_add, axis=1)

# %% [markdown]
# ### We drop the same columns we have dropped for the X training

# %%
tX_test_0 = np.delete(tX_test_0, col_to_delete_0, axis=1)
tX_test_1 = np.delete(tX_test_1, col_to_delete_1, axis=1)

# %% [markdown]
# ### Now we substitute the -999 values with the median

# %%
for i in range(1, tX_test_2_3.shape[1]):
    index_column_non_valid =np.where(tX_test_2_3[:,i] == -999.)[0]
    index_column_valid =np.where(tX_test_2_3[:,i] != -999.)[0]
    median = np.median(tX_test_2_3[index_column_valid, i], axis = 0)
    tX_test_2_3[index_column_non_valid,i] =  median

# %%
for i in range(1, tX_test_1.shape[1]):
    index_column_non_valid =np.where(tX_test_1[:,i] == -999.)[0]
    index_column_valid =np.where(tX_test_1[:,i] != -999.)[0]
    median = np.median(tX_test_1[index_column_valid, i], axis = 0)
    tX_test_1[index_column_non_valid,i] =  median

# %%
for i in range(1, tX_test_0.shape[1]):
    index_column_non_valid =np.where(tX_test_0[:,i] == -999.)[0]
    index_column_valid =np.where(tX_test_0[:,i] != -999.)[0]
    median = np.median(tX_test_0[index_column_valid, i], axis = 0)
    tX_test_0[index_column_non_valid,i] =  median

# %% [markdown]
# ### We standardize the test set using the mean and the standard deviation of the training

# %%
print(tX_test_0.shape)
# Out:
# (227458, 19)

# %%
print(tX_0.shape)
# Out:
# (99913, 19)

# %%
def standardize_test(x, mean, std):
    """Standardize the test set."""
    x = x - mean
    x = x / std
    return x

# %%
tX_test_0[:,1:] = standardize_test(tX_test_0[:,1:], mean_0, std_0)
tX_test_1[:,1:] = standardize_test(tX_test_1[:,1:], mean_1, std_1)
tX_test_2_3[:,1:]= standardize_test(tX_test_2_3[:,1:], mean_2_3, std_2_3) #we standardize everything a part from the column added manually

# %% [markdown]
# ### We insert the column for the bias term

# %%
tX_tilda_test_0 = np.insert(tX_test_0, 0, np.ones(tX_test_0.shape[0]), axis=1)
tX_tilda_test_1 = np.insert(tX_test_1, 0, np.ones(tX_test_1.shape[0]), axis=1)
tX_tilda_test_2_3 = np.insert(tX_test_2_3, 0, np.ones(tX_test_2_3.shape[0]), axis=1)

# %% [markdown]
# ### We make the predictions

# %%
tX_tilda_test_2_3_augmented = build_poly(tX_tilda_test_2_3, degree=6)
predictions_ridge_2_3 = tX_tilda_test_2_3_augmented @ w_ridge_2_3
# print(predictions_2_3.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-89-54e7e5ff956c> in <module>
#       1 tX_tilda_test_2_3_augmented = build_poly(tX_tilda_test_2_3, degree=6)
# ----> 2 predictions_ridge_2_3 = tX_tilda_test_2_3_augmented @ w_ridge_2_3
#       3 # print(predictions_2_3.shape)
#
# NameError: name 'w_ridge_2_3' is not defined

# %%
tX_tilda_test_0_augmented = build_poly(tX_tilda_test_0, degree = 6)
predictions_ridge_0 = tX_tilda_test_0_augmented @ w_ridge_0
# print(predictions_0.shape)

# %%
tX_tilda_test_1_augmented = build_poly(tX_tilda_test_1, degree = 6)
predictions_ridge_1 = tX_tilda_test_1_augmented @ w_ridge_1
# print(predictions_1.shape)

# %%
print(len(zero_indices))
print(len(one_indices))
print(len(two_three_indices))
print()

# %%
### Predictions with logistic regression

# %%
tX_tilda_test_2_3_augmented = build_poly(tX_tilda_test_2_3, degree = 2)
predictions_logistic_2_3 = sigmoid(tX_tilda_test_2_3_augmented @ w_logistic_2_3)
# print(predictions_2_3.shape)

# %%
tX_tilda_test_1_augmented = build_poly(tX_tilda_test_1, degree = 2)
predictions_logistic_1 = sigmoid(tX_tilda_test_1_augmented @ w_logistic_1)
# print(predictions_1.shape)

# %%
tX_tilda_test_0_augmented = build_poly(tX_tilda_test_0, degree = 2)
predictions_logistic_0 = sigmoid(tX_tilda_test_0_augmented @ w_logistic_0)
# print(predictions_0.shape)

# %% [markdown]
# Now we have to reconstruct a single vector of predictions

# %%
#jupyter notebook --NotebookApp.iopub_data_rate_limit=1.0e10

# %%
stacked_predictions = np.zeros(len(y.shape[0]))
stacked_predictions[zero_indices] = predictions_logistic_0
stacked_predictions[one_indices] = predictions_logistic_1
stacked_predictions[two_three_indices] = predictions_logistic_2_3
# count_0 = 0
# count_1 = 0
# count_2_3 = 0
# for index_row in range(tX_test.shape[0]):
#  if index_row in zero_indices:
#       stacked_predictions.append(predictions_logistic_0[count_0])
#       count_0 = count_0 + 1
#   elif index_row in one_indices:
#       stacked_predictions.append(predictions_logistic_1[count_1])
#       count_1 = count_1 +1
#   else:
#       stacked_predictions.append(predictions_logistic_2_3[count_2_3])
#       count_2_3 = count_2_3 + 1

# %%
final_predictions = np.array([-1 if el < 0.5 else 1 for el in stacked_predictions])

# %%
print(final_predictions) 
print(1 / len(final_predictions) * np.count_nonzero(final_predictions == 1))
# Out:
# [-1 -1 -1 ...  1 -1 -1]
# 0.2952829624206758

# %%
def predict_labels(weights, tX_test):
    y = np.array(tX_test) @ np.array(weights)
    labels = [1 if l > 0 else -1 for l in y]
    return labels

# %%
OUTPUT_PATH = 'submission.csv' # TODO: fill in desired name of output file for submission
#y_pred = predict_labels(weights, tX_test)
y_pred = final_predictions
create_csv_submission(ids_test, y_pred, OUTPUT_PATH)
